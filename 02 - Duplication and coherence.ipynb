# %% [markdown]
# # Duplication and coherence
#
# ## Overall purpose and objective
# The overall purpose and objective of the cleaning and verification process is to prepare the data for conversion into a SQLite database (Datasette). As such, the data should follow database best practices.
#
# ## Specific purpose of this notebook
# This notebook is for checking duplicates in the data and coherence. Particularly, we want to check for:
# - Possible problematic rows for each table.
# - The companies/agencies in the company and agency lists correspond to companies/agencies in the company data
#
# ## Assumptions
# - Some combinations of fields should be unique
# - The values should be cohrent across tables
#
# ## Why this matters
# - Inserting the data in a proper database and assigning EITI IDs require a high confidence in the data quality to avoid downstream issues. Duplicates and non-coherence of the data decreases this level of confidence.
#
# ## Findings

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Problematic rows due to possible duplication

# %%
# import libraries and data

import pandas as pd
import numpy as np
from os import path
from functools import reduce
from pprint import pprint
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from itertools import combinations

file_dir = "data/consolidated/"
file_dir_old = "data/consolidated/backup/old"

# load the csvs into data frames
df_part_1 = pd.read_csv(path.join(file_dir, "Part 1 - About.csv"))
df_part_3a = pd.read_csv(path.join(file_dir, "Part 3 - Reporting companies' list.csv"))
df_part_3b = pd.read_csv(path.join(file_dir, "Part 3 - Reporting government entities list.csv"))
df_part_3c = pd.read_csv(path.join(file_dir, "Part 3 - Reporting projects' list.csv"))
df_part_4 = pd.read_csv(path.join(file_dir, "Part 4 - Government revenues.csv"))
df_part_5 = pd.read_csv(path.join(file_dir, "Part 5 - Company data.csv"))
# df_part_5 = pd.read_csv(path.join(file_dir, "Part 5 - Company data.csv"), low_memory=False)

df_list = [df_part_1, df_part_3a, df_part_3b, df_part_3c, df_part_4, df_part_5]
df_dict = {"Part 1 - About.csv": df_part_1,
           "Part 3 - Reporting companies' list.csv": df_part_3a,
           "Part 3 - Reporting government entities list.csv": df_part_3b,
           "Part 3 - Reporting projects' list.csv": df_part_3c,
           "Part 4 - Government revenues.csv": df_part_4,
           "Part 5 - Company data.csv": df_part_5
          }

# OPTIONAL COLUMNS
part_3a_opt = ["Stock exchange listing or company website", 
               "Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)"]
part_3b_opt = ["ID number (if applicable)"]
part_5_opt = ["In-kind volume (if applicable)", "Unit (if applicable)", "Comments"]

# only include fields that are non-optional
df_part_1_non_opt = df_part_1.copy()
df_part_3a_non_opt = df_part_3a.copy().drop(columns=part_3a_opt)               
df_part_3b_non_opt = df_part_3b.copy().drop(columns=part_3b_opt)
df_part_3c_non_opt = df_part_3c.copy()
df_part_4_non_opt = df_part_4.copy()
df_part_5_non_opt = df_part_5.copy().drop(columns=part_5_opt)

df_list_non_opt = [df_part_1_non_opt, df_part_3a_non_opt, df_part_3b_non_opt, df_part_3c_non_opt, df_part_4_non_opt, df_part_5_non_opt]
df_dict_non_opt = {"Part 1 - About.csv": df_part_1_non_opt,
           "Part 3 - Reporting companies' list.csv": df_part_3a_non_opt,
           "Part 3 - Reporting government entities list.csv": df_part_3b_non_opt,
           "Part 3 - Reporting projects' list.csv": df_part_3c_non_opt,
           "Part 4 - Government revenues.csv": df_part_4_non_opt,
           "Part 5 - Company data.csv": df_part_5_non_opt
          }

# %%
def get_column_combinations(columns, min_cols_diff):
    '''
    Get unique column combinations that will be used for determining problematic rows (i.e. possible duplicates).

    Parameters:
    - columns (list or iterable): A list of column names or identifiers to be used for forming combinations.
    - min_cols_diff (int): The minimum number of columns to form unique combinations.

    Returns:
    list: A list of tuples representing unique combinations of columns.

    Example:
    >>> columns = ['col1', 'col2', 'col3']
    >>> min_cols_diff = 2
    >>> get_column_combinations(columns, min_cols_diff)
    [('col1', 'col2'), ('col1', 'col3'), ('col2', 'col3')]
    '''

    all_combinations = []
    for x in range(min_cols_diff, len(columns) + 1):
        all_combinations.extend(combinations(columns, x))

    return all_combinations

# TEST: Uncomment lines below and run
# OUTPUT: 4 unique column combinations
# columns = ["Full name of agency", "Agency type", "Total reported"]
# column_combinations = get_column_combinations(columns, 2)
# print(f'There are {len(column_combinations)} combinations:')
# pprint(column_combinations)

# %%
def add_rowid(df):
    '''
    Add a row identifier (rowid) column to the DataFrame.

    Parameters:
    - df (pandas.DataFrame): The input DataFrame.

    Returns:
    pandas.DataFrame: A new DataFrame with an additional 'rowid' column.

    Example:
    >>> data = {'col1': [1, 2, 3], 'col2': ['a', 'b', 'c']}
    >>> df = pd.DataFrame(data)
    >>> add_rowid(df)
       col1 col2  rowid
    0     1    a      0
    1     2    b      1
    2     3    c      2
    '''

    df_rowid = df.copy()
    df_rowid["rowid"] = range(len(df_rowid))

    return df_rowid

# %%
def get_problematic_rows(df, columns, min_cols_diff):
    '''
    Get unique column combinations and find problematic rows (duplicates) based on specified columns.

    Parameters:
    - df (pandas.DataFrame): The input DataFrame.
    - columns (list or iterable): A list of column names or identifiers to be used for forming combinations.
    - min_cols_diff (int): The minimum number of columns to form unique combinations (i.e. minimum numbers of columns of difference to be considered unique).

    Returns:
    pandas.DataFrame: DataFrame containing unique rows among problematic rows.

    Example:
    >>> data = {'col1': [1, 2, 2, 3, 4], 'col2': ['a', 'b', 'b', 'c', 'd']}
    >>> df = pd.DataFrame(data)
    >>> columns_for_combinations = ['col1', 'col2']
    >>> min_cols_diff = 2
    >>> get_problematic_rows(df, columns_for_combinations, min_cols_diff)
       col1 col2
    0     2    b
    '''

    # Step 1: Create a copy of the DataFrame and add rowid
    df_copy = df.copy()
    df_copy['rowid'] = range(len(df_copy))

    # Step 2: Get column combinations
    all_combinations = []
    for x in range(min_cols_diff, len(columns) + 1):
        all_combinations.extend(combinations(columns, x))

    # Step 3: Find problematic rows for each column combination
    problematic_rows = pd.DataFrame()
    for combination in all_combinations:
        duplicated_rows = df_copy[df_copy.duplicated(subset=list(combination), keep=False)]
        problematic_rows = pd.concat([problematic_rows, duplicated_rows], ignore_index=False)

    # Step 4: Get unique rows among problematic rows
    unique_problematic_rows = problematic_rows.drop_duplicates()

    return unique_problematic_rows

# %% [markdown]
# #### Part 3 - Reporting government entities list

# %%
columns = ["Full name of agency", "Agency type", "Total reported"]

redflags_part_3b = get_problematic_rows(df_part_3b, columns, 2)
display(redflags_part_3b)
# Out:
#                                    Full name of agency  \
# 0             Ministry of Finance (Revenue Department)
# 1             Ministry of Finance (Customs Department)
# 2    Ministry of Mines and Petroleum (Revenue Depar...
# 3             National Environmental Protection Agency
# 4                    Ministry of Industry and Commerce
# ..                                                 ...
# 460  Electric energy distribution system operator (...
# 471  Electric Energy Distribution System Operator (...
# 474  Secretaría de Minería (SEMIN), Ministerio de D...
# 524                                              CAPAM
# 543  Société Nationale des Mines et de la Géologie ...
#
#                                        Agency type ID number (if applicable)  \
# 0                                Central goverment            Not applicable
# 1                                Central goverment            Not applicable
# 2                                Central goverment            Not applicable
# 3                                Central goverment            Not applicable
# 4                                Central goverment            Not applicable
# ..                                             ...                       ...
# 460  State-owned enterprises & public corporations                       NaN
# 471  State-owned enterprises & public corporations                       NaN
# 474                             Central government                       NaN
# 524                                          Other                       NaN
# 543  State-owned enterprises & public corporations            Non applicable
#
#     Total reported      Country ISO Code  Year  Start Date    End Date  rowid
# 0       1441453501  Afghanistan      AFG  2018  2017-12-21  2018-12-20      0
# 1       1367722942  Afghanistan      AFG  2018  2017-12-21  2018-12-21      1
# 2    1478934310.56  Afghanistan      AFG  2018  2017-12-21  2018-12-22      2
# 3            34000  Afghanistan      AFG  2018  2017-12-21  2018-12-23      3
# 4              NaN  Afghanistan      AFG  2018  2017-12-21  2018-12-24      4
# ..             ...          ...      ...   ...         ...         ...    ...
# 460            NaN      Albania      ALB  2017  2017-01-01  2017-12-31    460
# 471            NaN      Albania      ALB  2018  2018-01-01  2018-12-31    471
# 474            NaN    Argentina      ARG  2018  2018-01-01  2018-12-31    474
# 524            NaN     Cameroon      CMR  2017  2017-01-01  2017-12-31    524
# 543            NaN         Chad      TCD  2018  2018-01-01  2018-12-31    543
#
# [373 rows x 10 columns]

# %%
redflags_part_3b.groupby('Country').size().reset_index(name='Number of Rows').sort_values(by="Number of Rows", ascending=False)
# Out:
#                          Country  Number of Rows
# 12                         Ghana              80
# 4                   Burkina Faso              28
# 16                    Madagascar              24
# 1                        Albania              22
# 34                        Zambia              18
# 20                      Mongolia              18
# 6                           Chad              17
# 32                       Ukraine              15
# 11                       Germany              15
# 7                  Cote d'Ivoire              14
# 33                United Kingdom              12
# 14                          Iraq              11
# 23                        Norway              10
# 0                    Afghanistan              10
# 9             Dominican Republic               9
# 22                       Nigeria               9
# 25         Republic of the Congo               7
# 26                       Senegal               7
# 3                        Armenia               6
# 31           Trinidad and Tobago               6
# 27                    Seychelles               6
# 18                    Mauritania               5
# 30                          Togo               5
# 5                       Cameroon               4
# 13                        Guyana               3
# 19                        Mexico               2
# 8   Democratic Republic of Congo               2
# 29                      Tanzania               1
# 2                      Argentina               1
# 24                   Philippines               1
# 28                      Suriname               1
# 15                       Liberia               1
# 21                    Mozambique               1
# 10                      Ethiopia               1
# 17                          Mali               1

# %%
redflags_part_3b.groupby('Year').size().reset_index(name='Number of Rows').sort_values(by="Number of Rows", ascending=False)
# Out:
#    Year  Number of Rows
# 1  2018             128
# 0  2017             121
# 2  2019              93
# 3  2020              31

# %%
redflags_part_3b.groupby(["Country", "Year"]).size().reset_index(name='Number of Rows').sort_values(by="Number of Rows", ascending=False).head(15)
# Out:
#          Country  Year  Number of Rows
# 27         Ghana  2019              36
# 25         Ghana  2017              23
# 26         Ghana  2018              21
# 32    Madagascar  2017              12
# 33    Madagascar  2018              12
# 2        Albania  2017              11
# 3        Albania  2018              11
# 8   Burkina Faso  2018               9
# 9   Burkina Faso  2019               9
# 13          Chad  2018               9
# 29          Iraq  2017               8
# 39      Mongolia  2019               8
# 68        Zambia  2019               8
# 40      Mongolia  2020               8
# 10  Burkina Faso  2020               8

# %% [markdown]
# ### Coherence of companies in Part 3 - Reporting companies' list, Part 3 - Reporting government entities list, and Part 3 - Reporting projects list with Part 5 - Company data

# %%
def compare_tables(df1, df2, common_columns_df1, common_columns_df2):
    '''
    Compare two tables based on specified columns.

    Parameters:
    - df1 (pandas.DataFrame): The first DataFrame.
    - df2 (pandas.DataFrame): The second DataFrame.
    - common_columns_df1 (list): Columns used in df1 to find common rows.
    - common_columns_df2 (list): Columns used in df2 to find common rows.

    Returns:
    - common_rows (pandas.DataFrame): Rows common to both DataFrames.
    - unique_rows_df1 (pandas.DataFrame): Rows unique to df1.
    - unique_rows_df2 (pandas.DataFrame): Rows unique to df2.

    Example:
    >>> df1 = pd.DataFrame({'Company': ['A', 'B', 'C'], 'Project name': ['P1', 'P2', 'P3'], 'Country': ['X', 'Y', 'Z'], 'Year': [2020, 2021, 2022]})
    >>> df2 = pd.DataFrame({'Full company name': ['A Corp', 'B Corp', 'D Corp'], 'Company type': ['Type1', 'Type2', 'Type3'], 'Company ID number': [101, 102, 103], 'Country': ['X', 'Y', 'Z'], 'Year': [2020, 2021, 2023]})
    >>> common_cols_df1 = ['Country', 'Year']
    >>> common_cols_df2 = ['Country', 'Year']
    >>> common, unique_df1, unique_df2 = compare_tables(df1, df2, common_cols_df1, common_cols_df2)
    >>> print(common)
      Country  Year
    0       X  2020
    1       Y  2021
    >>> print(unique_df1)
      Company Project name
    2       C           P3
    >>> print(unique_df2)
      Full company name Company type  Company ID number
    2            D Corp       Type3                103
    '''

    # Make copies of the input dataframes
    df1_copy = df1.copy()
    df2_copy = df2.copy()

    # Find common rows
    common_rows = pd.merge(df1_copy, df2_copy, left_on=common_columns_df1, right_on=common_columns_df2, how='inner')

    # Find unique rows in df1
    unique_rows_df1 = df1_copy[~df1_copy.set_index(common_columns_df1).index.isin(common_rows.set_index(common_columns_df1).index)]

    # Find unique rows in df2
    unique_rows_df2 = df2_copy[~df2_copy.set_index(common_columns_df2).index.isin(common_rows.set_index(common_columns_df2).index)]

    return {"in table 1 but not in table 2": unique_rows_df1, 
            "in table 2 but not in table 1": unique_rows_df2,
           "in both tables": common_rows}

# %%
def compare_tables_drop_duplicates(df1, df2, common_columns_df1, common_columns_df2):
    '''
    Compare two tables based on specified columns and drop duplicates.

    Parameters:
    - df1 (pandas.DataFrame): The first DataFrame.
    - df2 (pandas.DataFrame): The second DataFrame.
    - common_columns_df1 (list): Columns used in df1 to find common rows.
    - common_columns_df2 (list): Columns used in df2 to find common rows.

    Returns:
    - common_rows (pandas.DataFrame): Rows common to both DataFrames with duplicates dropped.
    - unique_rows_df1 (pandas.DataFrame): Rows unique to df1 with duplicates dropped.
    - unique_rows_df2 (pandas.DataFrame): Rows unique to df2 with duplicates dropped.

    Example:
    >>> df1 = pd.DataFrame({'Company': ['A', 'B', 'C'], 'Project name': ['P1', 'P2', 'P3'], 'Country': ['X', 'Y', 'Z'], 'Year': [2020, 2021, 2022]})
    >>> df2 = pd.DataFrame({'Full company name': ['A Corp', 'B Corp', 'D Corp'], 'Company type': ['Type1', 'Type2', 'Type3'], 'Company ID number': [101, 102, 103], 'Country': ['X', 'Y', 'Z'], 'Year': [2020, 2021, 2023]})
    >>> common_cols_df1 = ['Country', 'Year']
    >>> common_cols_df2 = ['Country', 'Year']
    >>> common, unique_df1, unique_df2 = compare_tables_drop_duplicates(df1, df2, common_cols_df1, common_cols_df2)
    >>> print(common)
      Country  Year
    0       X  2020
    1       Y  2021
    >>> print(unique_df1)
      Company Project name
    2       C           P3
    >>> print(unique_df2)
      Full company name Company type  Company ID number
    2            D Corp       Type3                103
    '''

    # Find common rows
    common_rows = pd.merge(df1, df2, left_on=common_columns_df1, right_on=common_columns_df2, how='inner')

    # Drop duplicates in common rows
    common_rows = common_rows.drop_duplicates(subset=common_columns_df1)

    # Drop duplicates in unique rows in df1
    unique_rows_df1 = df1[~df1.set_index(common_columns_df1).index.isin(common_rows.set_index(common_columns_df1).index)]
    unique_rows_df1 = unique_rows_df1.drop_duplicates(subset=common_columns_df1)

    # Drop duplicates in unique rows in df2
    unique_rows_df2 = df2[~df2.set_index(common_columns_df2).index.isin(common_rows.set_index(common_columns_df2).index)]
    unique_rows_df2 = unique_rows_df2.drop_duplicates(subset=common_columns_df2)

    return {"in table 1 but not in table 2": unique_rows_df1, 
            "in table 2 but not in table 1": unique_rows_df2,
            "in both tables": common_rows}

# %% [markdown]
# #### Part 3 - Reporting companies' list and Part 5 - Company data

# %%
common_columns_3a5 = ["Full company name"]
common_columns_53a = ["Company"]

for key, data in compare_tables(df_part_3a, df_part_5, common_columns_3a5, common_columns_53a).items():
    print(key)
    display(data)
# Out:
# in table 1 but not in table 2
#                                       Full company name  \
# 7                             Abed Hasan Zadran Limited
# 9        Afghan Shinink Mines Extraction and Processing
# 95    احمد علی ولد خداداد, احمدعلی Ahamd Ali Son of ...
# 131   شرکت استخراج معادن افغان اکتیف لمیتد Afghan Ac...
# 138   شرکت استخراج معادن ذغال سنک افراسیاب Afrasyab ...
# ...                                                 ...
# 3763                     Glencore Exploration (DOB/DOI)
# 3771              Société Nationale de Ciment (SONACIM)
# 3778                                   ARAB CONTRACTORS
# 3781                    Chad construction Materials S.A
# 3787  Société Nationale des Mines et de la Géologie ...
#
#                                        Company type Company ID number  Sector  \
# 7                                           Private        9005801197   Other
# 9                                           Private        9002202316   Other
# 95                                          Private        9001263814   Other
# 131                                         Private        9001353375   Other
# 138                                         Private        9001505461   Other
# ...                                             ...               ...     ...
# 3763                                        Private     Not available     Oil
# 3771  State-owned enterprises & public corporations     Not available  Mining
# 3778                                        Private         600008358  Mining
# 3781                                        Private     Not available  Mining
# 3787  State-owned enterprises & public corporations     Not available  Mining
#
#      Commodities (comma-seperated)  \
# 7                             Coal
# 9                             Talc
# 95              Construction stone
# 131                       Chromite
# 138                           Coal
# ...                            ...
# 3763                           Oil
# 3771                     Quarrying
# 3778                           BTP
# 3781                           BTP
# 3787                           NaN
#
#               Stock exchange listing or company website  \
# 7                                                   NaN
# 9                                                   NaN
# 95                                      Not applicable
# 131                                     Not applicable
# 138                                     Not applicable
# ...                                                 ...
# 3763  https://investir.lesechos.fr/cours/action-glen...
# 3771                                      Not available
# 3778                  https://www.arabcont.com/english/
# 3781                                      Not available
# 3787                                      Not available
#
#      Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 7                                        Not available
# 9                                                   NaN
# 95                                       Not available
# 131                                      Not available
# 138                                      Not available
# ...                                                 ...
# 3763                                      Not available
# 3771                                      Not available
# 3778                                      Not available
# 3781                                      Not available
# 3787                                      Not available
#
#      Payments to Governments Report      Country ISO Code  Year  Start Date  \
# 7                               NaN  Afghanistan      AFG  2018  2017-12-21
# 9                               NaN  Afghanistan      AFG  2018  2017-12-21
# 95                               -   Afghanistan      AFG  2018  2017-12-21
# 131                              -   Afghanistan      AFG  2018  2017-12-21
# 138                              -   Afghanistan      AFG  2018  2017-12-21
# ...                             ...          ...      ...   ...         ...
# 3763                            NaN         Chad      TCD  2018  2018-01-01
# 3771                            NaN         Chad      TCD  2018  2018-01-01
# 3778                            NaN         Chad      TCD  2018  2018-01-01
# 3781                            NaN         Chad      TCD  2018  2018-01-01
# 3787                            NaN         Chad      TCD  2018  2018-01-01
#
#         End Date
# 7     2018-12-24
# 9     2018-12-24
# 95    2018-12-24
# 131   2018-12-24
# 138   2018-12-24
# ...          ...
# 3763  2018-12-31
# 3771  2018-12-31
# 3778  2018-12-31
# 3781  2018-12-31
# 3787  2018-12-31
#
# [315 rows x 13 columns]
# in table 2 but not in table 1
#                                                 Company  \
# 29                           Abid Hassan Zadran Limited
# 30                           Abid Hassan Zadran Limited
# 31                           Abid Hassan Zadran Limited
# 32                           Abid Hassan Zadran Limited
# 37     Afghan Shiinink, Mines Extraction and Processing
# ...                                                 ...
# 31566                         HOUNDE GOLD OPERATION  SA
# 31569                                 ROXGOLD SANU   SA
# 31572                         HOUNDE GOLD OPERATION  SA
# 31575                                    BISSA GOLD  SA
# 31584                        Autres (Secteur artisanal)
#
#                                        Government entity  \
# 29              Ministry of Finance (Customs Department)
# 30              Ministry of Finance (Customs Department)
# 31              Ministry of Finance (Customs Department)
# 32              Ministry of Finance (Customs Department)
# 37              Ministry of Finance (Customs Department)
# ...                                                  ...
# 31566  Direction Générale du Trésor et de la Comptabi...
# 31569  Direction Générale du Trésor et de la Comptabi...
# 31572  Direction Générale du Trésor et de la Comptabi...
# 31575  Direction Générale du Trésor et de la Comptabi...
# 31584                                              CAPAM
#
#                                      Revenue stream name  \
# 29                                           Export Duty
# 30                                  Fixed Tax on Exports
# 31                                  Other Fee on Exports
# 32                                    Penalty on Exports
# 37                                           Export Duty
# ...                                                  ...
# 31566                                   Frais de dossier
# 31569  Remboursements de crédit de TVA (remboursement...
# 31572  Remboursements de crédit de TVA (remboursement...
# 31575  Remboursements de crédit de TVA (remboursement...
# 31584                                   Prélèvement d'Or
#
#       Levied on project (Y/N) Reported by project (Y/N) Project name  \
# 29                         No                        No          NaN
# 30                         No                        No          NaN
# 31                         No                        No          NaN
# 32                         No                        No          NaN
# 37                         No                        No          NaN
# ...                       ...                       ...          ...
# 31566                     Yes                        No           Nc
# 31569                      No                        No          NaN
# 31572                      No                        No          NaN
# 31575                      No                        No          NaN
# 31584                     NaN                       NaN          NaN
#
#       Reporting currency Revenue value Payment made in-kind (Y/N)  \
# 29                   AFN       1192667                        No
# 30                   AFN        143121                        No
# 31                   AFN         25954                        No
# 32                   AFN          6350                        No
# 37                   AFN         35222                        No
# ...                  ...           ...                        ...
# 31566                XOF         10000                        NaN
# 31569                XOF   -3144990000                        NaN
# 31572                XOF   -7884500000                        NaN
# 31575                XOF  -16687770000                        NaN
# 31584                XAF    2276630000                        Yes
#
#       In-kind volume (if applicable) Unit (if applicable) Comments  \
# 29                    Not applicable       Not applicable      NaN
# 30                    Not applicable       Not applicable      NaN
# 31                    Not applicable       Not applicable      NaN
# 32                    Not applicable       Not applicable      NaN
# 37                    Not applicable       Not applicable      NaN
# ...                              ...                  ...      ...
# 31566                            NaN                  NaN     TRUE
# 31569                            NaN                  NaN     TRUE
# 31572                            NaN                  NaN     TRUE
# 31575                            NaN                  NaN     TRUE
# 31584                         0.1231               Tonnes      NaN
#
#             Country ISO Code  Year  Start Date    End Date
# 29      Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 30      Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 31      Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 32      Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 37      Afghanistan      AFG  2018  2017-12-21  2018-12-20
# ...             ...      ...   ...         ...         ...
# 31566  Burkina Faso      BFA  2020  2020-12-01  2020-12-31
# 31569  Burkina Faso      BFA  2020  2020-12-01  2020-12-31
# 31572  Burkina Faso      BFA  2020  2020-12-01  2020-12-31
# 31575  Burkina Faso      BFA  2020  2020-12-01  2020-12-31
# 31584      Cameroon      CMR  2017  2017-01-01  2017-12-31
#
# [2851 rows x 17 columns]
# in both tables
#                                        Full company name Company type  \
# 0                                  Amin Karimzai Campany      Private
# 1      Habib Shahab Talc and Marble exploitation and ...      Private
# 2      Habib Shahab Talc and Marble exploitation and ...      Private
# 3      Habib Shahab Talc and Marble exploitation and ...      Private
# 4      Habib Shahab Talc and Marble exploitation and ...      Private
# ...                                                  ...          ...
# 47432            Société de Raffinage de N’Djamena (SRN)      Private
# 47433            Société de Raffinage de N’Djamena (SRN)      Private
# 47434            Société de Raffinage de N’Djamena (SRN)      Private
# 47435            Société de Raffinage de N’Djamena (SRN)      Private
# 47436            Société de Raffinage de N’Djamena (SRN)      Private
#
#       Company ID number Sector Commodities (comma-seperated)  \
# 0            1007815085  Other                          Talc
# 1            1013655012  Other      Talc, Construction stone
# 2            1013655012  Other      Talc, Construction stone
# 3            1013655012  Other      Talc, Construction stone
# 4            1013655012  Other      Talc, Construction stone
# ...                 ...    ...                           ...
# 47432         600008474  Other                      Refinery
# 47433         600008474  Other                      Refinery
# 47434         600008474  Other                      Refinery
# 47435         600008474  Other                      Refinery
# 47436         600008474  Other                      Refinery
#
#       Stock exchange listing or company website  \
# 0                               Not applicable
# 1                               Not applicable
# 2                               Not applicable
# 3                               Not applicable
# 4                               Not applicable
# ...                                         ...
# 47432                             Not available
# 47433                             Not available
# 47434                             Not available
# 47435                             Not available
# 47436                             Not available
#
#       Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 0                                         Not available
# 1                                         Not available
# 2                                         Not available
# 3                                         Not available
# 4                                         Not available
# ...                                                  ...
# 47432                                      Not available
# 47433                                      Not available
# 47434                                      Not available
# 47435                                      Not available
# 47436                                      Not available
#
#       Payments to Governments Report    Country_x ISO Code_x  ...  \
# 0                             365746  Afghanistan        AFG  ...
# 1                             427491  Afghanistan        AFG  ...
# 2                             427491  Afghanistan        AFG  ...
# 3                             427491  Afghanistan        AFG  ...
# 4                             427491  Afghanistan        AFG  ...
# ...                              ...          ...        ...  ...
# 47432                      189977765         Chad        TCD  ...
# 47433                      189977765         Chad        TCD  ...
# 47434                      189977765         Chad        TCD  ...
# 47435                      189977765         Chad        TCD  ...
# 47436                      189977765         Chad        TCD  ...
#
#        Revenue value Payment made in-kind (Y/N)  \
# 0             365746                         No
# 1                 18                        NaN
# 2             365746                         No
# 3              53675                         No
# 4               8052                         No
# ...              ...                        ...
# 47432       34438339                         No
# 47433      120595199                        Yes
# 47434      187400000                        Yes
# 47435        2068759                         No
# 47436         509006                         No
#
#       In-kind volume (if applicable) Unit (if applicable)  \
# 0                     Not applicable       Not applicable
# 1                                NaN                  NaN
# 2                     Not applicable       Not applicable
# 3                     Not applicable       Not applicable
# 4                     Not applicable       Not applicable
# ...                              ...                  ...
# 47432                            NaN                  NaN
# 47433                        2574070              Barrels
# 47434                        4000000              Barrels
# 47435                 Non applicable       Non applicable
# 47436                 Non applicable       Non applicable
#
#                                                 Comments    Country_y  \
# 0                                             2018-08-28  Afghanistan
# 1                                                    NaN  Afghanistan
# 2                                             2018-08-28  Afghanistan
# 3                                             2018-08-01  Afghanistan
# 4                                             2018-08-01  Afghanistan
# ...                                                  ...          ...
# 47432                                                NaN         Chad
# 47433  Sales of the State's share collected by SHT to...         Chad
# 47434  Ventes à la raffinerie des quotes-part huile d...         Chad
# 47435                                                NaN         Chad
# 47436                                                NaN         Chad
#
#       ISO Code_y Year_y Start Date_y  End Date_y
# 0            AFG   2018   2017-12-21  2018-12-20
# 1            AFG   2018   2017-12-21  2018-12-20
# 2            AFG   2018   2017-12-21  2018-12-20
# 3            AFG   2018   2017-12-21  2018-12-20
# 4            AFG   2018   2017-12-21  2018-12-20
# ...          ...    ...          ...         ...
# 47432        TCD   2017   2017-01-01  2017-12-31
# 47433        TCD   2017   2017-01-01  2017-12-31
# 47434        TCD   2018   2018-01-01  2018-12-31
# 47435        TCD   2018   2018-01-01  2018-12-31
# 47436        TCD   2018   2018-01-01  2018-12-31
#
# [47437 rows x 30 columns]

# %%
print("With duplicate rows removed")

common_columns_3a5 = ["Full company name"]
common_columns_53a = ["Company"]

for key, data in compare_tables_drop_duplicates(df_part_3a, df_part_5, common_columns_3a5, common_columns_53a).items():
    print(key)
    display(data)
# Out:
# With duplicate rows removed
# in table 1 but not in table 2
#                                       Full company name  \
# 7                             Abed Hasan Zadran Limited
# 9        Afghan Shinink Mines Extraction and Processing
# 95    احمد علی ولد خداداد, احمدعلی Ahamd Ali Son of ...
# 131   شرکت استخراج معادن افغان اکتیف لمیتد Afghan Ac...
# 138   شرکت استخراج معادن ذغال سنک افراسیاب Afrasyab ...
# ...                                                 ...
# 3745                                   ARAB CONTRACTORS
# 3748                    Chad construction Materials S.A
# 3754  Société des Hydrocarbures du Tchad Petroleum C...
# 3771              Société Nationale de Ciment (SONACIM)
# 3787  Société Nationale des Mines et de la Géologie ...
#
#                                        Company type Company ID number  Sector  \
# 7                                           Private        9005801197   Other
# 9                                           Private        9002202316   Other
# 95                                          Private        9001263814   Other
# 131                                         Private        9001353375   Other
# 138                                         Private        9001505461   Other
# ...                                             ...               ...     ...
# 3745                                        Private         600008358  Mining
# 3748                                        Private  Not communicated  Mining
# 3754  State-owned enterprises & public corporations     Not available     Oil
# 3771  State-owned enterprises & public corporations     Not available  Mining
# 3787  State-owned enterprises & public corporations     Not available  Mining
#
#      Commodities (comma-seperated) Stock exchange listing or company website  \
# 7                             Coal                                       NaN
# 9                             Talc                                       NaN
# 95              Construction stone                           Not applicable
# 131                       Chromite                           Not applicable
# 138                           Coal                           Not applicable
# ...                            ...                                       ...
# 3745                  Construction         https://www.arabcont.com/english/
# 3748                  Construction                             Not available
# 3754                           Oil                             Not available
# 3771                     Quarrying                             Not available
# 3787                           NaN                             Not available
#
#      Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 7                                        Not available
# 9                                                   NaN
# 95                                       Not available
# 131                                      Not available
# 138                                      Not available
# ...                                                 ...
# 3745                                      Not available
# 3748                                      Not available
# 3754                                      Not available
# 3771                                      Not available
# 3787                                      Not available
#
#      Payments to Governments Report      Country ISO Code  Year  Start Date  \
# 7                               NaN  Afghanistan      AFG  2018  2017-12-21
# 9                               NaN  Afghanistan      AFG  2018  2017-12-21
# 95                               -   Afghanistan      AFG  2018  2017-12-21
# 131                              -   Afghanistan      AFG  2018  2017-12-21
# 138                              -   Afghanistan      AFG  2018  2017-12-21
# ...                             ...          ...      ...   ...         ...
# 3745                            NaN         Chad      TCD  2017  2017-01-01
# 3748                            NaN         Chad      TCD  2017  2017-01-01
# 3754                            NaN         Chad      TCD  2018  2018-01-01
# 3771                            NaN         Chad      TCD  2018  2018-01-01
# 3787                            NaN         Chad      TCD  2018  2018-01-01
#
#         End Date
# 7     2018-12-24
# 9     2018-12-24
# 95    2018-12-24
# 131   2018-12-24
# 138   2018-12-24
# ...          ...
# 3745  2017-12-31
# 3748  2017-12-31
# 3754  2018-12-31
# 3771  2018-12-31
# 3787  2018-12-31
#
# [262 rows x 13 columns]
# in table 2 but not in table 1
#                                                 Company  \
# 29                           Abid Hassan Zadran Limited
# 37     Afghan Shiinink, Mines Extraction and Processing
# 41      Afghan Shinink, Mines Extraction and Processing
# 46                    Afghan Talc Limited Joint Venture
# 92                                 Arif Shahaab Limited
# ...                                                 ...
# 30591                    ESTELAR RESOURCES LIMITED  S.A
# 31078                                    BISSA GOLD  SA
# 31104                         HOUNDE GOLD OPERATION  SA
# 31108                                 ROXGOLD SANU   SA
# 31584                        Autres (Secteur artisanal)
#
#                                        Government entity  \
# 29              Ministry of Finance (Customs Department)
# 37              Ministry of Finance (Customs Department)
# 41              Ministry of Finance (Customs Department)
# 46              Ministry of Finance (Customs Department)
# 92              Ministry of Finance (Customs Department)
# ...                                                  ...
# 30591  Administración Federal de Ingresos Públicos (A...
# 31078                Direction Générale des Impôts (DGI)
# 31104               Direction Générale des Douanes (DGD)
# 31108               Direction Générale des Douanes (DGD)
# 31584                                              CAPAM
#
#                            Revenue stream name Levied on project (Y/N)  \
# 29                                 Export Duty                      No
# 37                                 Export Duty                      No
# 41                                 Export Duty                      No
# 46                                 Export Duty                      No
# 92                                 Export Duty                      No
# ...                                        ...                     ...
# 30591                  Derechos de Exportación                      No
# 31078  Acomptes Provisionnels sur IS (AP - IS)                     Yes
# 31104     Droits de Douane et taxes assimilées                     Yes
# 31108     Droits de Douane et taxes assimilées                     Yes
# 31584                         Prélèvement d'Or                     NaN
#
#       Reported by project (Y/N)   Project name Reporting currency  \
# 29                           No            NaN                AFN
# 37                           No            NaN                AFN
# 41                           No            NaN                AFN
# 46                           No            NaN                AFN
# 92                           No            NaN                AFN
# ...                         ...            ...                ...
# 30591                        No            NaN                ARS
# 31078                       Yes  Bissa Gold SA                XOF
# 31104                       Yes    Hounde Gold                XOF
# 31108                       Yes       Yaramoko                XOF
# 31584                       NaN            NaN                XAF
#
#       Revenue value Payment made in-kind (Y/N) In-kind volume (if applicable)  \
# 29          1192667                        No                  Not applicable
# 37            35222                        No                  Not applicable
# 41            61336                        No                  Not applicable
# 46           316251                        No                  Not applicable
# 92          1085044                        No                  Not applicable
# ...             ...                        ...                            ...
# 30591  323735644.74                         No                            NaN
# 31078    9608091475                         No                            NaN
# 31104    6273544278                         No                            NaN
# 31108     940971519                         No                            NaN
# 31584    2276630000                        Yes                         0.1231
#
#       Unit (if applicable) Comments       Country ISO Code  Year  Start Date  \
# 29          Not applicable      NaN   Afghanistan      AFG  2018  2017-12-21
# 37          Not applicable      NaN   Afghanistan      AFG  2018  2017-12-21
# 41          Not applicable      NaN   Afghanistan      AFG  2018  2017-12-21
# 46          Not applicable      NaN   Afghanistan      AFG  2018  2017-12-21
# 92          Not applicable      NaN   Afghanistan      AFG  2018  2017-12-21
# ...                    ...      ...           ...      ...   ...         ...
# 30591                  NaN      NaN     Argentina      ARG  2018  2018-01-01
# 31078                  NaN      NaN  Burkina Faso      BFA  2018  2018-01-01
# 31104                  NaN      NaN  Burkina Faso      BFA  2018  2018-01-01
# 31108                  NaN      NaN  Burkina Faso      BFA  2018  2018-01-01
# 31584               Tonnes      NaN      Cameroon      CMR  2017  2017-01-01
#
#          End Date
# 29     2018-12-20
# 37     2018-12-20
# 41     2018-12-20
# 46     2018-12-20
# 92     2018-12-20
# ...           ...
# 30591  2018-12-31
# 31078  2018-12-31
# 31104  2018-12-31
# 31108  2018-12-31
# 31584  2017-12-31
#
# [105 rows x 17 columns]
# in both tables
#                                        Full company name Company type  \
# 0                                  Amin Karimzai Campany      Private
# 1      Habib Shahab Talc and Marble exploitation and ...      Private
# 5                                    Abaan Rayan Limited      Private
# 9                                  Abas Ghaznavi Limited      Private
# 17                                           Abdul Fatah      Private
# ...                                                  ...          ...
# 47415                                            MIREDEX      Private
# 47417  Société Nationale de Développement de Minérale...      Private
# 47418                                       Société GMIA      Private
# 47420           Tchad Oil Transportation Company (TOTCO)      Private
# 47425        Cameroun Oil Transportation Company (COTCO)      Private
#
#       Company ID number  Sector Commodities (comma-seperated)  \
# 0            1007815085   Other                          Talc
# 1            1013655012   Other      Talc, Construction stone
# 5            9004655032   Other                          Coal
# 9            9001935742   Other                          Coal
# 17           9001846329   Other            Construction stone
# ...                 ...     ...                           ...
# 47415     Not available  Mining                          Gold
# 47417     Not available  Mining                          Gold
# 47418     Not available  Mining                          Gold
# 47420         600010746   Other                 Oil transport
# 47425    M089700006137L   Other                 Oil transport
#
#       Stock exchange listing or company website  \
# 0                               Not applicable
# 1                               Not applicable
# 5                                           NaN
# 9                                           NaN
# 17                              Not applicable
# ...                                         ...
# 47415                             Not available
# 47417                             Not available
# 47418                             Not available
# 47420                             Not available
# 47425                             Not available
#
#       Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 0                                         Not available
# 1                                         Not available
# 5                                         Not available
# 9                                         Not available
# 17                                        Not available
# ...                                                  ...
# 47415                                      Not available
# 47417                                      Not available
# 47418                                      Not available
# 47420                                      Not available
# 47425                                      Not available
#
#       Payments to Governments Report    Country_x ISO Code_x  ...  \
# 0                             365746  Afghanistan        AFG  ...
# 1                             427491  Afghanistan        AFG  ...
# 5                           10256884  Afghanistan        AFG  ...
# 9                           36244514  Afghanistan        AFG  ...
# 17                            139422  Afghanistan        AFG  ...
# ...                              ...          ...        ...  ...
# 47415                           9833         Chad        TCD  ...
# 47417                           7196         Chad        TCD  ...
# 47418                           6866         Chad        TCD  ...
# 47420                    40463701.62         Chad        TCD  ...
# 47425                        1151588         Chad        TCD  ...
#
#        Revenue value Payment made in-kind (Y/N)  \
# 0             365746                         No
# 1                 18                        NaN
# 5            8953331                        No
# 9           23473826                        No
# 17             89598                         No
# ...              ...                        ...
# 47415           9571                         No
# 47417           7196                         No
# 47418           4167                         No
# 47420    30718669.41                         No
# 47425        1151588                         No
#
#       In-kind volume (if applicable) Unit (if applicable)    Comments  \
# 0                     Not applicable       Not applicable  2018-08-28
# 1                                NaN                  NaN         NaN
# 5                     Not applicable       Not applicable         NaN
# 9                     Not applicable       Not applicable         NaN
# 17                    Not applicable       Not applicable  2018-07-31
# ...                              ...                  ...         ...
# 47415                 Non applicable       Non applicable         NaN
# 47417                 Non applicable       Non applicable         NaN
# 47418                 Non applicable       Non applicable         NaN
# 47420                 Non applicable       Non applicable         NaN
# 47425                 Non applicable       Non applicable         NaN
#
#          Country_y ISO Code_y Year_y Start Date_y  End Date_y
# 0      Afghanistan        AFG   2018   2017-12-21  2018-12-20
# 1      Afghanistan        AFG   2018   2017-12-21  2018-12-20
# 5      Afghanistan        AFG   2018   2017-12-21  2018-12-20
# 9      Afghanistan        AFG   2018   2017-12-21  2018-12-20
# 17     Afghanistan        AFG   2018   2017-12-21  2018-12-20
# ...            ...        ...    ...          ...         ...
# 47415         Chad        TCD   2018   2018-01-01  2018-12-31
# 47417         Chad        TCD   2018   2018-01-01  2018-12-31
# 47418         Chad        TCD   2018   2018-01-01  2018-12-31
# 47420         Chad        TCD   2018   2018-01-01  2018-12-31
# 47425         Chad        TCD   2018   2018-01-01  2018-12-31
#
# [2641 rows x 30 columns]

# %% [markdown]
# #### Part 3 - Reporting government entities' list and Part 5 - Company data

# %%
print("With duplicate rows")

common_columns_3b5 = ["Full name of agency", "Country", "Year"]
common_columns_53b = ["Government entity", "Country", "Year"]

for key, data in compare_tables(df_part_3b, df_part_5, common_columns_3b5, common_columns_53b).items():
    print(key)
    display(data)
# Out:
# With duplicate rows
# in table 1 but not in table 2
#                                    Full name of agency  \
# 4                    Ministry of Industry and Commerce
# 9                    Ministry of Industry and Commerce
# 10                 Direction Générale des Impôts (DGI)
# 14   Direction des Participations et de la Privatis...
# 18                                              Others
# ..                                                 ...
# 542  Autorité de Régulation du Secteur pétrolier Av...
# 543  Société Nationale des Mines et de la Géologie ...
# 544                             Ministère des Finances
# 545                                    Commune de Doba
# 546                                Commune de Koudalwa
#
#                                        Agency type ID number (if applicable)  \
# 4                                Central goverment            Not applicable
# 9                                Central goverment            Not applicable
# 10                               Central goverment             No applicable
# 14                               Central goverment             No applicable
# 18                               Central goverment             No applicable
# ..                                             ...                       ...
# 542                              Central goverment            Non applicable
# 543  State-owned enterprises & public corporations            Non applicable
# 544                              Central goverment            Non applicable
# 545                               Local government            Non applicable
# 546                               Local government            Non applicable
#
#     Total reported        Country ISO Code  Year  Start Date    End Date
# 4              NaN    Afghanistan      AFG  2018  2017-12-21  2018-12-24
# 9              NaN    Afghanistan      AFG  2019  2018-12-21  2019-12-20
# 10    108131178092  Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# 14             NaN  Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# 18             NaN  Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# ..             ...            ...      ...   ...         ...         ...
# 542            NaN           Chad      TCD  2018  2018-01-01  2018-12-31
# 543            NaN           Chad      TCD  2018  2018-01-01  2018-12-31
# 544            NaN           Chad      TCD  2018  2018-01-01  2018-12-31
# 545            NaN           Chad      TCD  2018  2018-01-01  2018-12-31
# 546            NaN           Chad      TCD  2018  2018-01-01  2018-12-31
#
# [167 rows x 9 columns]
# in table 2 but not in table 1
#                                                  Company  \
# 4728                             ENI IVORY COAST LIMITED
# 4729                                           TULLOW CI
# 4746   Société Nationale d'Opérations Petrolière de C...
# 4747   societe ivoiro-suisse abidjanaise de granit (S...
# 4748                                         CADERAC. SA
# ...                                                  ...
# 31069                                         Kiaka Gold
# 31070                                         Kiaka Gold
# 31071                                         Kiaka Gold
# 31074                                         Kiaka Gold
# 31075                                            SOFANEC
#
#                           Government entity               Revenue stream name  \
# 4728    Direction Générale des impôts (DGI)               Bonus de production
# 4729    Direction Générale des impôts (DGI)                Bonus de signature
# 4746    Direction Générale des impôts (DGI)         Contribution des patentes
# 4747    Direction Générale des impôts (DGI)         Contribution des patentes
# 4748    Direction Générale des impôts (DGI)         Contribution des patentes
# ...                                     ...                               ...
# 31069  Direction Générale des Douanes (DGD)                   Pénalités (DGD)
# 31070   Direction Générale des Impôts (DGI)  Taxe sur la Valeur Ajoutée (TVA)
# 31071   Direction Générale des Impôts (DGI)                   Pénalités (DGI)
# 31074           Frais de prestation BUMIGEB       Frais de prestation BUMIGEB
# 31075   Direction Générale des Impôts (DGI)       Droit d'enregistemeent (DE)
#
#       Levied on project (Y/N) Reported by project (Y/N) Project name  \
# 4728                       No                        No          NaN
# 4729                       No                        No          NaN
# 4746                       No                        No          NaN
# 4747                       No                        No          NaN
# 4748                       No                        No          NaN
# ...                       ...                       ...          ...
# 31069                      No                        No          NaN
# 31070                      No                        No          NaN
# 31071                      No                        No          NaN
# 31074                      No                        No          NaN
# 31075                      No                        No          NaN
#
#       Reporting currency Revenue value Payment made in-kind (Y/N)  \
# 4728                 XOF    2454000000                        NaN
# 4729                 XOF     819375000                        NaN
# 4746                 XOF     498167552                        NaN
# 4747                 XOF      16338189                        NaN
# 4748                 XOF       8760605                        NaN
# ...                  ...           ...                        ...
# 31069                XOF        697364                         No
# 31070                XOF          3900                         No
# 31071                XOF          2100                         No
# 31074                XOF      17132152                         No
# 31075                XOF         12000                         No
#
#       In-kind volume (if applicable) Unit (if applicable) Comments  \
# 4728                             NaN                  NaN      NaN
# 4729                             NaN                  NaN      NaN
# 4746                             NaN                  NaN      NaN
# 4747                             NaN                  NaN      NaN
# 4748                             NaN                  NaN      NaN
# ...                              ...                  ...      ...
# 31069                            NaN                  NaN      NaN
# 31070                            NaN                  NaN      NaN
# 31071                            NaN                  NaN      NaN
# 31074                            NaN                  NaN      NaN
# 31075                            NaN                  NaN      NaN
#
#              Country ISO Code  Year  Start Date    End Date
# 4728   Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# 4729   Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# 4746   Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# 4747   Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# 4748   Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# ...              ...      ...   ...         ...         ...
# 31069   Burkina Faso      BFA  2017  2017-01-01  2017-12-31
# 31070   Burkina Faso      BFA  2017  2017-01-01  2017-12-31
# 31071   Burkina Faso      BFA  2017  2017-01-01  2017-12-31
# 31074   Burkina Faso      BFA  2017  2017-01-01  2017-12-31
# 31075   Burkina Faso      BFA  2017  2017-01-01  2017-12-31
#
# [1682 rows x 17 columns]
# in both tables
#                                  Full name of agency        Agency type  \
# 0           Ministry of Finance (Revenue Department)  Central goverment
# 1           Ministry of Finance (Revenue Department)  Central goverment
# 2           Ministry of Finance (Revenue Department)  Central goverment
# 3           Ministry of Finance (Revenue Department)  Central goverment
# 4           Ministry of Finance (Revenue Department)  Central goverment
# ...                                              ...                ...
# 30196  Direction Générale Technique des Mines (DGTM)  Central goverment
# 30197  Direction Générale Technique des Mines (DGTM)  Central goverment
# 30198  Direction Générale Technique des Mines (DGTM)  Central goverment
# 30199  Direction Générale Technique des Mines (DGTM)  Central goverment
# 30200  Direction Générale Technique des Mines (DGTM)  Central goverment
#
#       ID number (if applicable) Total reported      Country ISO Code_x  Year  \
# 0                Not applicable     1441453501  Afghanistan        AFG  2018
# 1                Not applicable     1441453501  Afghanistan        AFG  2018
# 2                Not applicable     1441453501  Afghanistan        AFG  2018
# 3                Not applicable     1441453501  Afghanistan        AFG  2018
# 4                Not applicable     1441453501  Afghanistan        AFG  2018
# ...                         ...            ...          ...        ...   ...
# 30196            Non applicable          96283         Chad        TCD  2018
# 30197            Non applicable          96283         Chad        TCD  2018
# 30198            Non applicable          96283         Chad        TCD  2018
# 30199            Non applicable          96283         Chad        TCD  2018
# 30200            Non applicable          96283         Chad        TCD  2018
#
#       Start Date_x  End Date_x                                      Company  \
# 0       2017-12-21  2018-12-20                        Afghan Gas Enterprise
# 1       2017-12-21  2018-12-20                        Afghan Gas Enterprise
# 2       2017-12-21  2018-12-20                        Afghan Gas Enterprise
# 3       2017-12-21  2018-12-20                        Afghan Gas Enterprise
# 4       2017-12-21  2018-12-20  CNPCI Watan Oil and Gas Afghanistan limited
# ...            ...         ...                                          ...
# 30196   2018-01-01  2018-12-31                                        SOGEM
# 30197   2018-01-01  2018-12-31                            ABOURACHID Mining
# 30198   2018-01-01  2018-12-31                                      MIREDEX
# 30199   2018-01-01  2018-12-31                          Manejem Company Ltd
# 30200   2018-01-01  2018-12-31                                 Société GMIA
#
#        ...    Project name Reporting currency Revenue value  \
# 0      ...             NaN                AFN      24493134
# 1      ...             NaN                AFN      21656316
# 2      ...             NaN                AFN      12325103
# 3      ...             NaN                AFN       1047484
# 4      ...             NaN                AFN        556996
# ...    ...             ...                ...           ...
# 30196  ...  Non applicable                USD         12953
# 30197  ...  Non applicable                USD          9895
# 30198  ...  Non applicable                USD          9571
# 30199  ...  Non applicable                USD          4498
# 30200  ...  Non applicable                USD          2699
#
#       Payment made in-kind (Y/N) In-kind volume (if applicable)  \
# 0                            No                  Not applicable
# 1                            No                  Not applicable
# 2                            No                  Not applicable
# 3                            No                  Not applicable
# 4                            No                  Not applicable
# ...                          ...                            ...
# 30196                         No                 Non applicable
# 30197                         No                 Non applicable
# 30198                         No                 Non applicable
# 30199                         No                 Non applicable
# 30200                         No                 Non applicable
#
#       Unit (if applicable)    Comments ISO Code_y Start Date_y  End Date_y
# 0           Not applicable  2018-12-21        AFG   2017-12-21  2018-12-20
# 1           Not applicable  2018-12-21        AFG   2017-12-21  2018-12-20
# 2           Not applicable  2018-12-21        AFG   2017-12-21  2018-12-20
# 3           Not applicable  2018-12-21        AFG   2017-12-21  2018-12-20
# 4           Not applicable  2018-12-21        AFG   2017-12-21  2018-12-20
# ...                    ...         ...        ...          ...         ...
# 30196       Non applicable         NaN        TCD   2018-01-01  2018-12-31
# 30197       Non applicable         NaN        TCD   2018-01-01  2018-12-31
# 30198       Non applicable         NaN        TCD   2018-01-01  2018-12-31
# 30199       Non applicable         NaN        TCD   2018-01-01  2018-12-31
# 30200       Non applicable         NaN        TCD   2018-01-01  2018-12-31
#
# [30201 rows x 24 columns]

# %%
print("With duplicate rows removed")

for key, data in compare_tables_drop_duplicates(df_part_3b, df_part_5, common_columns_3b5, common_columns_53b).items():
    print(key)
    display(data)
# Out:
# With duplicate rows removed
# in table 1 but not in table 2
#                                    Full name of agency  \
# 4                    Ministry of Industry and Commerce
# 9                    Ministry of Industry and Commerce
# 10                 Direction Générale des Impôts (DGI)
# 14   Direction des Participations et de la Privatis...
# 18                                              Others
# ..                                                 ...
# 542  Autorité de Régulation du Secteur pétrolier Av...
# 543  Société Nationale des Mines et de la Géologie ...
# 544                             Ministère des Finances
# 545                                    Commune de Doba
# 546                                Commune de Koudalwa
#
#                                        Agency type ID number (if applicable)  \
# 4                                Central goverment            Not applicable
# 9                                Central goverment            Not applicable
# 10                               Central goverment             No applicable
# 14                               Central goverment             No applicable
# 18                               Central goverment             No applicable
# ..                                             ...                       ...
# 542                              Central goverment            Non applicable
# 543  State-owned enterprises & public corporations            Non applicable
# 544                              Central goverment            Non applicable
# 545                               Local government            Non applicable
# 546                               Local government            Non applicable
#
#     Total reported        Country ISO Code  Year  Start Date    End Date
# 4              NaN    Afghanistan      AFG  2018  2017-12-21  2018-12-24
# 9              NaN    Afghanistan      AFG  2019  2018-12-21  2019-12-20
# 10    108131178092  Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# 14             NaN  Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# 18             NaN  Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# ..             ...            ...      ...   ...         ...         ...
# 542            NaN           Chad      TCD  2018  2018-01-01  2018-12-31
# 543            NaN           Chad      TCD  2018  2018-01-01  2018-12-31
# 544            NaN           Chad      TCD  2018  2018-01-01  2018-12-31
# 545            NaN           Chad      TCD  2018  2018-01-01  2018-12-31
# 546            NaN           Chad      TCD  2018  2018-01-01  2018-12-31
#
# [164 rows x 9 columns]
# in table 2 but not in table 1
#                                           Company  \
# 4728                      ENI IVORY COAST LIMITED
# 4885              SOCIETE DES MINES D'ITY (S M I)
# 5081                         AMUR MUGOTE & FRERES
# 6015   Barrick Pueblo Viejo Dominican Corporation
# 6109           BEB Erdgas und Erdöl GmbH & Co. KG
# ...                                           ...
# 30531                                    YPF S.A.
# 30537                                    YPF S.A.
# 30928                         IAMGOLD Essakane SA
# 30930                         IAMGOLD Essakane SA
# 30941                         IAMGOLD Essakane SA
#
#                           Government entity  \
# 4728    Direction Générale des impôts (DGI)
# 4885                                 Autres
# 5081    Direction des Recettes Provinciales
# 6015    Ministerio de Energía y Minas (MEM)
# 6109                         Municipalities
# ...                                     ...
# 30531                 Secretaría de Energía
# 30537          Secretaría de Medio Ambiente
# 30928  Direction Générale des Douanes (DGD)
# 30930   Direction Générale des Impôts (DGI)
# 30941           Frais de prestation BUMIGEB
#
#                                      Revenue stream name  \
# 4728                                 Bonus de production
# 4885   Versements au compte de réhabilitation pour l'...
# 5081               Autorisation de transport de minerais
# 6015                                  Tasa por Servicios
# 6109                                           Trade Tax
# ...                                                  ...
# 30531                                           Regalias
# 30537                               Tasa Ambiental Anual
# 30928               Droits de Douane et taxes assimilées
# 30930            Acomptes Provisionnels sur IS (AP - IS)
# 30941                        Frais de prestation BUMIGEB
#
#       Levied on project (Y/N) Reported by project (Y/N)     Project name  \
# 4728                       No                        No              NaN
# 4885                       No                        No              NaN
# 5081                       No                        No              NaN
# 6015                       No                       Yes              NaN
# 6109                       No                        No              NaN
# ...                       ...                       ...              ...
# 30531                     Yes                       Yes  Magallanes AM 6
# 30537                      No                        No              NaN
# 30928                      No                        No              NaN
# 30930                      No                        No              NaN
# 30941                      No                        No              NaN
#
#       Reporting currency Revenue value Payment made in-kind (Y/N)  \
# 4728                 XOF    2454000000                        NaN
# 4885                 XOF      75657609                        NaN
# 5081                 USD         80710                         No
# 6015                 DOP          4000                         No
# 6109                 EUR      19466797                        NaN
# ...                  ...           ...                        ...
# 30531                ARS      37731968                         No
# 30537                ARS         73217                         No
# 30928                XOF   17778937001                         No
# 30930                XOF    5874863793                         No
# 30941                XOF       1235000                         No
#
#       In-kind volume (if applicable) Unit (if applicable) Comments  \
# 4728                             NaN                  NaN      NaN
# 4885                             NaN                  NaN      NaN
# 5081                  Non applicable       Non applicable      NaN
# 6015                             NaN                  NaN        1
# 6109                             NaN                  NaN      NaN
# ...                              ...                  ...      ...
# 30531                            NaN                  NaN      Oil
# 30537                            NaN                  NaN      NaN
# 30928                            NaN                  NaN      NaN
# 30930                            NaN                  NaN      NaN
# 30941                            NaN                  NaN      NaN
#
#                             Country ISO Code  Year  Start Date    End Date
# 4728                  Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# 4885                  Cote d'Ivoire      CIV  2017  2017-01-01  2017-12-31
# 5081   Democratic Republic of Congo      COD  2017  2017-01-01  2017-12-31
# 6015             Dominican Republic      DOM  2018  2018-01-01  2018-12-31
# 6109                        Germany      DEU  2017  2017-01-01  2017-12-31
# ...                             ...      ...   ...         ...         ...
# 30531                     Argentina      ARG  2018  2018-01-01  2018-12-31
# 30537                     Argentina      ARG  2018  2018-01-01  2018-12-31
# 30928                  Burkina Faso      BFA  2017  2017-01-01  2017-12-31
# 30930                  Burkina Faso      BFA  2017  2017-01-01  2017-12-31
# 30941                  Burkina Faso      BFA  2017  2017-01-01  2017-12-31
#
# [147 rows x 17 columns]
# in both tables
#                                      Full name of agency  \
# 0               Ministry of Finance (Revenue Department)
# 181             Ministry of Finance (Customs Department)
# 834    Ministry of Mines and Petroleum (Revenue Depar...
# 1144            National Environmental Protection Agency
# 1153            Ministry of Finance (Revenue Department)
# ...                                                  ...
# 30117      Direction Générale Technique des Mines (DGTM)
# 30121  Direction Générale du Trésor et de la Comptabi...
# 30170           Société des Hydrocarbures du Tchad (SHT)
# 30180     Direction Générale Technique de Pétrole (DGTP)
# 30194      Direction Générale Technique des Mines (DGTM)
#
#                                          Agency type  \
# 0                                  Central goverment
# 181                                Central goverment
# 834                                Central goverment
# 1144                               Central goverment
# 1153                               Central goverment
# ...                                              ...
# 30117                             Central government
# 30121                              Central goverment
# 30170  State-owned enterprises & public corporations
# 30180                              Central goverment
# 30194                              Central goverment
#
#       ID number (if applicable) Total reported      Country ISO Code_x  Year  \
# 0                Not applicable     1441453501  Afghanistan        AFG  2018
# 181              Not applicable     1367722942  Afghanistan        AFG  2018
# 834              Not applicable  1478934310.56  Afghanistan        AFG  2018
# 1144             Not applicable          34000  Afghanistan        AFG  2018
# 1153             Not applicable     1441453501  Afghanistan        AFG  2019
# ...                         ...            ...          ...        ...   ...
# 30117            Non applicable          51575         Chad        TCD  2017
# 30121            Non applicable   316949335.62         Chad        TCD  2018
# 30170            Non applicable   680650556.22         Chad        TCD  2018
# 30180            Non applicable        5440559         Chad        TCD  2018
# 30194            Non applicable          96283         Chad        TCD  2018
#
#       Start Date_x  End Date_x  \
# 0       2017-12-21  2018-12-20
# 181     2017-12-21  2018-12-21
# 834     2017-12-21  2018-12-22
# 1144    2017-12-21  2018-12-23
# 1153    2018-12-21  2019-12-20
# ...            ...         ...
# 30117   2017-01-01  2017-12-31
# 30121   2018-01-01  2018-12-31
# 30170   2018-01-01  2018-12-31
# 30180   2018-01-01  2018-12-31
# 30194   2018-01-01  2018-12-31
#
#                                                  Company  ...    Project name  \
# 0                                  Afghan Gas Enterprise  ...             NaN
# 181                                  Abaan Rayan Limited  ...             NaN
# 834                          North Coal Enterprise (NCE)  ...      EXP 1/2014
# 1144   استخراج 10000مترمکعب ریگ وجغل توسط شرکت ساختما...  ...             NaN
# 1153                               Afghan Gas Enterprise  ...             NaN
# ...                                                  ...  ...             ...
# 30117                                     TEKTON MINERAL  ...  Non applicable
# 30121                                           Petronas  ...  Non applicable
# 30170                         Glencore Energy UK Limited  ...  Non applicable
# 30180                                  Petrochad Mangara  ...  Non applicable
# 30194                                     TEKTON MINERAL  ...  Non applicable
#
#       Reporting currency Revenue value Payment made in-kind (Y/N)  \
# 0                    AFN      24493134                        No
# 181                  AFN       8953331                        No
# 834                  AFN     442801100                         No
# 1144                 AFN          1000                        No
# 1153                 AFN      20000000             Not applicable
# ...                  ...           ...                        ...
# 30117                USD         16332                         No
# 30121                USD     103169362                         No
# 30170                USD  259445592.69                        Yes
# 30180                USD       1772626                         No
# 30194                USD         42275                         No
#
#       In-kind volume (if applicable) Unit (if applicable)  \
# 0                     Not applicable       Not applicable
# 181                   Not applicable       Not applicable
# 834                   Not applicable       Not applicable
# 1144                  Not applicable       Not applicable
# 1153                  Not applicable       Not applicable
# ...                              ...                  ...
# 30117                            NaN                  NaN
# 30121                 Non applicable       Non applicable
# 30170                        3803345              Barrels
# 30180                 Non applicable       Non applicable
# 30194                 Non applicable       Non applicable
#
#                                                 Comments ISO Code_y  \
# 0                                             2018-12-21        AFG
# 181                                                  NaN        AFG
# 834                                           2018-09-22        AFG
# 1144                                          2018-01-11        AFG
# 1153                                                 NaN        AFG
# ...                                                  ...        ...
# 30117                                                NaN        TCD
# 30121                                                NaN        TCD
# 30170  Ventes (export) des quotes-part huile de l'Eta...        TCD
# 30180                                                NaN        TCD
# 30194                                                NaN        TCD
#
#       Start Date_y  End Date_y
# 0       2017-12-21  2018-12-20
# 181     2017-12-21  2018-12-20
# 834     2017-12-21  2018-12-20
# 1144    2017-12-21  2018-12-20
# 1153    2018-12-21  2019-12-20
# ...            ...         ...
# 30117   2017-01-01  2017-12-31
# 30121   2018-01-01  2018-12-31
# 30170   2018-01-01  2018-12-31
# 30180   2018-01-01  2018-12-31
# 30194   2018-01-01  2018-12-31
#
# [379 rows x 24 columns]

# %% [markdown]
# #### Part 3 - Reporting projects' list and Part 5 - Company data

# %%
print("With duplicate rows")

common_columns_3c5 = ["Full project name", "Country", "Year"]
common_columns_53c = ["Project name", "Country", "Year"]

for key, data in compare_tables(df_part_3c, df_part_5, common_columns_3c5, common_columns_53c).items():
    print(key)
    display(data)
# Out:
# With duplicate rows
# in table 1 but not in table 2
#      Full project name  \
# 80           APL-EP-57
# 81           APL-EP-58
# 82           APL-EP-59
# 83           APL-EP-60
# 84           APL-EP-61
# ...                ...
# 4974        Champs Nya
# 4975    Champs Maikeri
# 4976     Champs Timbré
# 4977    Champs MANGARA
# 4978     Champs BADILA
#
#      Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 80                                                  NaN
# 81                                                  NaN
# 82                                                  NaN
# 83                                                  NaN
# 84                                                  NaN
# ...                                                 ...
# 4974  Concession d'exploitation NYA du 20/07/2017 (C...
# 4975  Concession d'exploitation Maikeri du 20/07/201...
# 4976  Concession d'exploitation Timbré du 20/07/2017...
# 4977  Autorisation Exclusive d'Exploitation, MANGARA...
# 4978  Autorisation Exclusive d'Exploitation, BADILA ...
#
#      Affiliated companies, start with Operator  \
# 80                      Jabul Siraj Consortium
# 81                               Core Drillers
# 82                       Amin Karimzai Campany
# 83                         Afghan Talc Limited
# 84                         Nabi Afghan Company
# ...                                        ...
# 4974                        Esso, Petronas,SHT
# 4975                        Esso, Petronas,SHT
# 4976                        Esso, Petronas,SHT
# 4977                          PCM/Glencore/SHT
# 4978                          PCM/Glencore/SHT
#
#      Commodities (one commodity/row)      Status Production (volume)     Unit  \
# 80                               NaN         NaN                 NaN      NaN
# 81                               NaN         NaN                 NaN      NaN
# 82                               NaN         NaN                 NaN      NaN
# 83                               NaN         NaN                 NaN      NaN
# 84                               NaN         NaN                 NaN      NaN
# ...                              ...         ...                 ...      ...
# 4974                Crude oil (2709)  Production              638135  Barrels
# 4975                Crude oil (2709)  Production              550314  Barrels
# 4976                Crude oil (2709)  Production              598515  Barrels
# 4977                Crude oil (2709)  Production             2181729  Barrels
# 4978                Crude oil (2709)  Production             1261093  Barrels
#
#      Production (value) Currency      Country ISO Code  Year  Start Date  \
# 80                  NaN      NaN  Afghanistan      AFG  2019  2018-12-21
# 81                  NaN      NaN  Afghanistan      AFG  2019  2018-12-21
# 82                  NaN      NaN  Afghanistan      AFG  2019  2018-12-21
# 83                  NaN      NaN  Afghanistan      AFG  2019  2018-12-21
# 84                  NaN      NaN  Afghanistan      AFG  2019  2018-12-21
# ...                 ...      ...          ...      ...   ...         ...
# 4974           34993372      USD         Chad      TCD  2017  2017-01-01
# 4975           30177537      USD         Chad      TCD  2017  2017-01-01
# 4976           32820733      USD         Chad      TCD  2017  2017-01-01
# 4977          119639347      USD         Chad      TCD  2017  2017-01-01
# 4978           69154484      USD         Chad      TCD  2017  2017-01-01
#
#         End Date
# 80    2019-12-20
# 81    2019-12-20
# 82    2019-12-20
# 83    2019-12-20
# 84    2019-12-20
# ...          ...
# 4974  2017-12-31
# 4975  2017-12-31
# 4976  2017-12-31
# 4977  2017-12-31
# 4978  2017-12-31
#
# [887 rows x 14 columns]
# in table 2 but not in table 1
#                                                  Company  \
# 4      Habib Shahab Talc and Marble exploitation and ...
# 5                                    Abaan Rayan Limited
# 6                                    Abaan Rayan Limited
# 7                                    Abaan Rayan Limited
# 8                                    Abaan Rayan Limited
# ...                                                  ...
# 31877  China National Petroleum Corporation Internati...
# 31878  China National Petroleum Corporation Internati...
# 31879                                  Petrochad Mangara
# 31880                                  Petrochad Mangara
# 31881                                  Petrochad Mangara
#
#                                        Government entity  \
# 4      Ministry of Mines and Petroleum (Revenue Depar...
# 5               Ministry of Finance (Customs Department)
# 6               Ministry of Finance (Customs Department)
# 7               Ministry of Finance (Customs Department)
# 8               Ministry of Finance (Customs Department)
# ...                                                  ...
# 31877           Société des Hydrocarbures du Tchad (SHT)
# 31878           Société des Hydrocarbures du Tchad (SHT)
# 31879           Société des Hydrocarbures du Tchad (SHT)
# 31880           Société des Hydrocarbures du Tchad (SHT)
# 31881           Société des Hydrocarbures du Tchad (SHT)
#
#                                 Revenue stream name Levied on project (Y/N)  \
# 4                         Penalties of Late Payment                     NaN
# 5                                       Export Duty                      No
# 6                              Fixed Tax on Exports                      No
# 7                              Other Fee on Exports                      No
# 8                                Penalty on Exports                      No
# ...                                             ...                     ...
# 31877  Redevance sur production collecté par la SHT                      No
# 31878                Profit Oil collecté par la SHT                      No
# 31879  Redevance sur production collecté par la SHT                      No
# 31880                   Tax Oil collecté par la SHT                      No
# 31881                Profit Oil collecté par la SHT                      No
#
#       Reported by project (Y/N)    Project name Reporting currency  \
# 4                           NaN             NaN                AFN
# 5                            No             NaN                AFN
# 6                            No             NaN                AFN
# 7                            No             NaN                AFN
# 8                            No             NaN                AFN
# ...                         ...             ...                ...
# 31877                        No  Non applicable                USD
# 31878                        No  Non applicable                USD
# 31879                        No  Non applicable                USD
# 31880                        No  Non applicable                USD
# 31881                        No  Non applicable                USD
#
#       Revenue value Payment made in-kind (Y/N) In-kind volume (if applicable)  \
# 4                18                        NaN                            NaN
# 5           8953331                        No                  Not applicable
# 6           1074419                        No                  Not applicable
# 7            198084                        No                  Not applicable
# 8             31050                        No                  Not applicable
# ...             ...                        ...                            ...
# 31877             -                        Yes                        3543915
# 31878             -                        Yes                        2541955
# 31879             -                        Yes                         545318
# 31880             -                        Yes                         393777
# 31881             -                        Yes                          88711
#
#       Unit (if applicable)                                           Comments  \
# 4                      NaN                                                NaN
# 5           Not applicable                                                NaN
# 6           Not applicable                                                NaN
# 7           Not applicable                                                NaN
# 8           Not applicable                                                NaN
# ...                    ...                                                ...
# 31877              Barrels  Quotes-parts de l'Etat (Redevance sur producti...
# 31878              Barrels  Quotes-parts de l'Etat (Profit Oil SHT- 10%) d...
# 31879              Barrels  Quotes-parts de l'Etat (Redevance sur producti...
# 31880              Barrels  Quotes-parts de l'Etat (Tax Oil SHT) dans le c...
# 31881              Barrels  Quotes-parts de l'Etat (Profit Oil SHT- 15%) d...
#
#            Country ISO Code  Year  Start Date    End Date
# 4      Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 5      Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 6      Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 7      Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 8      Afghanistan      AFG  2018  2017-12-21  2018-12-20
# ...            ...      ...   ...         ...         ...
# 31877         Chad      TCD  2018  2018-01-01  2018-12-31
# 31878         Chad      TCD  2018  2018-01-01  2018-12-31
# 31879         Chad      TCD  2018  2018-01-01  2018-12-31
# 31880         Chad      TCD  2018  2018-01-01  2018-12-31
# 31881         Chad      TCD  2018  2018-01-01  2018-12-31
#
# [22909 rows x 17 columns]
# in both tables
#       Full project name  \
# 0             APL-EP-57
# 1             APL-EP-58
# 2             APL-EP-59
# 3             APL-EP-60
# 4             APL-EP-61
# ...                 ...
# 23963          Yaramoko
# 23964          Yaramoko
# 23965          Yaramoko
# 23966          Yaramoko
# 23967          Yaramoko
#
#       Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 23963                                                NaN
# 23964                                                NaN
# 23965                                                NaN
# 23966                                                NaN
# 23967                                                NaN
#
#       Affiliated companies, start with Operator  \
# 0                        Jabul Siraj Consortium
# 1                                 Core Drillers
# 2                         Amin Karimzai Campany
# 3                           Afghan Talc Limited
# 4                           Nabi Afghan Company
# ...                                         ...
# 23963                           Roxgold Sanu SA
# 23964                           Roxgold Sanu SA
# 23965                           Roxgold Sanu SA
# 23966                           Roxgold Sanu SA
# 23967                           Roxgold Sanu SA
#
#       Commodities (one commodity/row)      Status Production (volume)    Unit  \
# 0                                 NaN         NaN                 NaN     NaN
# 1                                 NaN         NaN                 NaN     NaN
# 2                                 NaN         NaN                 NaN     NaN
# 3                                 NaN         NaN                 NaN     NaN
# 4                                 NaN         NaN                 NaN     NaN
# ...                               ...         ...                 ...     ...
# 23963                     Gold (7108)  Production                4.21  Tonnes
# 23964                   Silver (7106)  Production              446.49      Kg
# 23965                   Silver (7106)  Production              446.49      Kg
# 23966                   Silver (7106)  Production              446.49      Kg
# 23967                   Silver (7106)  Production              446.49      Kg
#
#       Production (value) Currency       Country  ... Project name  \
# 0                    NaN      NaN   Afghanistan  ...    APL-EP-57
# 1                    NaN      NaN   Afghanistan  ...    APL-EP-58
# 2                    NaN      NaN   Afghanistan  ...    APL-EP-59
# 3                    NaN      NaN   Afghanistan  ...    APL-EP-60
# 4                    NaN      NaN   Afghanistan  ...    APL-EP-61
# ...                  ...      ...           ...  ...          ...
# 23963       137920000000      XOF  Burkina Faso  ...     Yaramoko
# 23964         1870000000      XOF  Burkina Faso  ...     Yaramoko
# 23965         1870000000      XOF  Burkina Faso  ...     Yaramoko
# 23966         1870000000      XOF  Burkina Faso  ...     Yaramoko
# 23967         1870000000      XOF  Burkina Faso  ...     Yaramoko
#
#        Reporting currency Revenue value Payment made in-kind (Y/N)  \
# 0                     AFN        378109                         No
# 1                     AFN        367260                         No
# 2                     AFN        365746                         No
# 3                     AFN        366791                         No
# 4                     AFN        365746                         No
# ...                   ...           ...                        ...
# 23963                 XOF       1100000                        NaN
# 23964                 XOF    6964860000                        NaN
# 23965                 XOF    2666660000                        NaN
# 23966                 XOF     224310000                        NaN
# 23967                 XOF       1100000                        NaN
#
#       In-kind volume (if applicable) Unit (if applicable)    Comments  \
# 0                     Not applicable       Not applicable  2018-09-18
# 1                     Not applicable       Not applicable  2018-08-29
# 2                     Not applicable       Not applicable  2018-08-28
# 3                     Not applicable       Not applicable  2018-08-29
# 4                     Not applicable       Not applicable  2018-08-28
# ...                              ...                  ...         ...
# 23963                            NaN                  NaN        TRUE
# 23964                            NaN                  NaN        TRUE
# 23965                            NaN                  NaN        TRUE
# 23966                            NaN                  NaN        TRUE
# 23967                            NaN                  NaN        TRUE
#
#       ISO Code_y Start Date_y  End Date_y
# 0            AFG   2017-12-21  2018-12-20
# 1            AFG   2017-12-21  2018-12-20
# 2            AFG   2017-12-21  2018-12-20
# 3            AFG   2017-12-21  2018-12-20
# 4            AFG   2017-12-21  2018-12-20
# ...          ...          ...         ...
# 23963        BFA   2020-12-01  2020-12-31
# 23964        BFA   2020-12-01  2020-12-31
# 23965        BFA   2020-12-01  2020-12-31
# 23966        BFA   2020-12-01  2020-12-31
# 23967        BFA   2020-12-01  2020-12-31
#
# [23968 rows x 29 columns]

# %%
print("With duplicate rows removed")

# common_columns_3c5 = ["Full project name", "Country", "Year"]
# common_columns_53c = ["Project name", "Country", "Year"]

for key, data in compare_tables_drop_duplicates(df_part_3c, df_part_5, common_columns_3c5, common_columns_53c).items():
    print(key)
    display(data)
# Out:
# With duplicate rows removed
# in table 1 but not in table 2
#      Full project name  \
# 80           APL-EP-57
# 81           APL-EP-58
# 82           APL-EP-59
# 83           APL-EP-60
# 84           APL-EP-61
# ...                ...
# 4974        Champs Nya
# 4975    Champs Maikeri
# 4976     Champs Timbré
# 4977    Champs MANGARA
# 4978     Champs BADILA
#
#      Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 80                                                  NaN
# 81                                                  NaN
# 82                                                  NaN
# 83                                                  NaN
# 84                                                  NaN
# ...                                                 ...
# 4974  Concession d'exploitation NYA du 20/07/2017 (C...
# 4975  Concession d'exploitation Maikeri du 20/07/201...
# 4976  Concession d'exploitation Timbré du 20/07/2017...
# 4977  Autorisation Exclusive d'Exploitation, MANGARA...
# 4978  Autorisation Exclusive d'Exploitation, BADILA ...
#
#      Affiliated companies, start with Operator  \
# 80                      Jabul Siraj Consortium
# 81                               Core Drillers
# 82                       Amin Karimzai Campany
# 83                         Afghan Talc Limited
# 84                         Nabi Afghan Company
# ...                                        ...
# 4974                        Esso, Petronas,SHT
# 4975                        Esso, Petronas,SHT
# 4976                        Esso, Petronas,SHT
# 4977                          PCM/Glencore/SHT
# 4978                          PCM/Glencore/SHT
#
#      Commodities (one commodity/row)      Status Production (volume)     Unit  \
# 80                               NaN         NaN                 NaN      NaN
# 81                               NaN         NaN                 NaN      NaN
# 82                               NaN         NaN                 NaN      NaN
# 83                               NaN         NaN                 NaN      NaN
# 84                               NaN         NaN                 NaN      NaN
# ...                              ...         ...                 ...      ...
# 4974                Crude oil (2709)  Production              638135  Barrels
# 4975                Crude oil (2709)  Production              550314  Barrels
# 4976                Crude oil (2709)  Production              598515  Barrels
# 4977                Crude oil (2709)  Production             2181729  Barrels
# 4978                Crude oil (2709)  Production             1261093  Barrels
#
#      Production (value) Currency      Country ISO Code  Year  Start Date  \
# 80                  NaN      NaN  Afghanistan      AFG  2019  2018-12-21
# 81                  NaN      NaN  Afghanistan      AFG  2019  2018-12-21
# 82                  NaN      NaN  Afghanistan      AFG  2019  2018-12-21
# 83                  NaN      NaN  Afghanistan      AFG  2019  2018-12-21
# 84                  NaN      NaN  Afghanistan      AFG  2019  2018-12-21
# ...                 ...      ...          ...      ...   ...         ...
# 4974           34993372      USD         Chad      TCD  2017  2017-01-01
# 4975           30177537      USD         Chad      TCD  2017  2017-01-01
# 4976           32820733      USD         Chad      TCD  2017  2017-01-01
# 4977          119639347      USD         Chad      TCD  2017  2017-01-01
# 4978           69154484      USD         Chad      TCD  2017  2017-01-01
#
#         End Date
# 80    2019-12-20
# 81    2019-12-20
# 82    2019-12-20
# 83    2019-12-20
# 84    2019-12-20
# ...          ...
# 4974  2017-12-31
# 4975  2017-12-31
# 4976  2017-12-31
# 4977  2017-12-31
# 4978  2017-12-31
#
# [767 rows x 14 columns]
# in table 2 but not in table 1
#                                                  Company  \
# 4      Habib Shahab Talc and Marble exploitation and ...
# 384                                 WESTCO INTERNATIONAL
# 453                                           Hayat Khan
# 1153                     Aazam Khan Wafa Sherzad Limited
# 1175              Abdul Rahman Baba Steel & Iron Company
# ...                                                  ...
# 31495                        NETIANA MINING COMPANY(NMC)
# 31506                 GRYPHON MINERALS BURKINA FASO SARL
# 31577                                                SNH
# 31716                                     TEKTON MINERAL
# 31802                         Glencore Energy UK Limited
#
#                                        Government entity  \
# 4      Ministry of Mines and Petroleum (Revenue Depar...
# 384    Ministry of Mines and Petroleum (Revenue Depar...
# 453    Ministry of Mines and Petroleum (Revenue Depar...
# 1153            Ministry of Finance (Customs Department)
# 1175   Ministry of Mines and Petroleum (Revenue Depar...
# ...                                                  ...
# 31495    Fonds d'Intervention pour l'Environnement (FIE)
# 31506  Direction Générale du Trésor et de la Comptabi...
# 31577          Société Nationale des Hydrocarbures (SNH)
# 31716      Direction Générale Technique des Mines (DGTM)
# 31802           Société des Hydrocarbures du Tchad (SHT)
#
#                                      Revenue stream name  \
# 4                              Penalties of Late Payment
# 384                                            Royalties
# 453                                            Royalties
# 1153                                         Export Duty
# 1175                                        Surface Rent
# ...                                                  ...
# 31495  Versements au Fonds de réhabilitation et de fe...
# 31506                               Taxes superficiaires
# 31577             Parts d'huile de la SNH-Etat (Petrole)
# 31716                               Appui Institutionnel
# 31802                 Vente du pétrole collectés par SHT
#
#       Levied on project (Y/N) Reported by project (Y/N)  \
# 4                         NaN                       NaN
# 384                       Yes                       Yes
# 453                       Yes                       Yes
# 1153                       No                        No
# 1175                      Yes                       Yes
# ...                       ...                       ...
# 31495                     Yes                        No
# 31506                     Yes                       Yes
# 31577                     NaN                       NaN
# 31716                      No                        No
# 31802                      No                        No
#
#                                    Project name Reporting currency  \
# 4                                           NaN                AFN
# 384                                 EXPL 3/2013                AFN
# 453                           SSML-Kabu 48/2014                AFN
# 1153                                        NaN                AFN
# 1175                                EXPL 2/2014                AFN
# ...                                         ...                ...
# 31495                                        Nc                XOF
# 31506  Nogbele Sud Dierisso  Nianka Zeguedougou                XOF
# 31577                                       NaN                XAF
# 31716                            Non applicable                USD
# 31802                            Non applicable                USD
#
#       Revenue value Payment made in-kind (Y/N) In-kind volume (if applicable)  \
# 4                18                        NaN                            NaN
# 384          710962                         No                 Not applicable
# 453          100568                         No                 Not applicable
# 1153         110944             Not applicable                 Not applicable
# 1175        1352198             Not applicable                 Not applicable
# ...             ...                        ...                            ...
# 31495     120000000                        NaN                            NaN
# 31506      24070000                        NaN                            NaN
# 31577           NaN                        Yes                            960
# 31716         16332                         No                            NaN
# 31802  259445592.69                        Yes                        3803345
#
#       Unit (if applicable)                                           Comments  \
# 4                      NaN                                                NaN
# 384         Not applicable                                         2018-04-22
# 453         Not applicable                                         2018-07-23
# 1153        Not applicable                                                NaN
# 1175        Not applicable                                                NaN
# ...                    ...                                                ...
# 31495                  NaN                                               TRUE
# 31506                  NaN                                               TRUE
# 31577              Barrels  The value of this  in-kind payment form part o...
# 31716                  NaN                                                NaN
# 31802              Barrels  Ventes (export) des quotes-part huile de l'Eta...
#
#             Country ISO Code  Year  Start Date    End Date
# 4       Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 384     Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 453     Afghanistan      AFG  2018  2017-12-21  2018-12-20
# 1153    Afghanistan      AFG  2019  2018-12-21  2019-12-20
# 1175    Afghanistan      AFG  2019  2018-12-21  2019-12-20
# ...             ...      ...   ...         ...         ...
# 31495  Burkina Faso      BFA  2020  2020-12-01  2020-12-31
# 31506  Burkina Faso      BFA  2020  2020-12-01  2020-12-31
# 31577      Cameroon      CMR  2017  2017-01-01  2017-12-31
# 31716          Chad      TCD  2017  2017-01-01  2017-12-31
# 31802          Chad      TCD  2018  2018-01-01  2018-12-31
#
# [556 rows x 17 columns]
# in both tables
#          Full project name  \
# 0                APL-EP-57
# 1                APL-EP-58
# 2                APL-EP-59
# 3                APL-EP-60
# 4                APL-EP-61
# ...                    ...
# 23926               SEMAFO
# 23932       SEMAFO Boungou
# 23938              TAPARKO
# 23946  WAHGNION GOLD OP SA
# 23960             Yaramoko
#
#       Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 23926                                                NaN
# 23932                                                NaN
# 23938                                                NaN
# 23946                                                NaN
# 23960                                                NaN
#
#       Affiliated companies, start with Operator  \
# 0                        Jabul Siraj Consortium
# 1                                 Core Drillers
# 2                         Amin Karimzai Campany
# 3                           Afghan Talc Limited
# 4                           Nabi Afghan Company
# ...                                         ...
# 23926                            SEMAFO Burkina
# 23932                            SEMAFO Boungou
# 23938                                    SOMITA
# 23946                       WAHGNION GOLD OP SA
# 23960                           Roxgold Sanu SA
#
#       Commodities (one commodity/row)      Status Production (volume)    Unit  \
# 0                                 NaN         NaN                 NaN     NaN
# 1                                 NaN         NaN                 NaN     NaN
# 2                                 NaN         NaN                 NaN     NaN
# 3                                 NaN         NaN                 NaN     NaN
# 4                                 NaN         NaN                 NaN     NaN
# ...                               ...         ...                 ...     ...
# 23926                   Silver (7106)  Production             1327.56      Kg
# 23932                   Silver (7106)  Production              437.16      Kg
# 23938                     Gold (7108)  Production                2.92  Tonnes
# 23946                     Gold (7108)  Production                5.62  Tonnes
# 23960                     Gold (7108)  Production                4.21  Tonnes
#
#       Production (value) Currency       Country  ...         Project name  \
# 0                    NaN      NaN   Afghanistan  ...            APL-EP-57
# 1                    NaN      NaN   Afghanistan  ...            APL-EP-58
# 2                    NaN      NaN   Afghanistan  ...            APL-EP-59
# 3                    NaN      NaN   Afghanistan  ...            APL-EP-60
# 4                    NaN      NaN   Afghanistan  ...            APL-EP-61
# ...                  ...      ...           ...  ...                  ...
# 23926          520000000      XOF  Burkina Faso  ...               SEMAFO
# 23932          170000000      XOF  Burkina Faso  ...       SEMAFO Boungou
# 23938        94480000000      XOF  Burkina Faso  ...              TAPARKO
# 23946       181820000000      XOF  Burkina Faso  ...  WAHGNION GOLD OP SA
# 23960       137920000000      XOF  Burkina Faso  ...             Yaramoko
#
#        Reporting currency Revenue value Payment made in-kind (Y/N)  \
# 0                     AFN        378109                         No
# 1                     AFN        367260                         No
# 2                     AFN        365746                         No
# 3                     AFN        366791                         No
# 4                     AFN        365746                         No
# ...                   ...           ...                        ...
# 23926                 XOF    9793090000                        NaN
# 23932                 XOF    7119140000                        NaN
# 23938                 XOF    4781340000                        NaN
# 23946                 XOF    8578370000                        NaN
# 23960                 XOF    6964860000                        NaN
#
#       In-kind volume (if applicable) Unit (if applicable)    Comments  \
# 0                     Not applicable       Not applicable  2018-09-18
# 1                     Not applicable       Not applicable  2018-08-29
# 2                     Not applicable       Not applicable  2018-08-28
# 3                     Not applicable       Not applicable  2018-08-29
# 4                     Not applicable       Not applicable  2018-08-28
# ...                              ...                  ...         ...
# 23926                            NaN                  NaN        TRUE
# 23932                            NaN                  NaN        TRUE
# 23938                            NaN                  NaN        TRUE
# 23946                            NaN                  NaN        TRUE
# 23960                            NaN                  NaN        TRUE
#
#       ISO Code_y Start Date_y  End Date_y
# 0            AFG   2017-12-21  2018-12-20
# 1            AFG   2017-12-21  2018-12-20
# 2            AFG   2017-12-21  2018-12-20
# 3            AFG   2017-12-21  2018-12-20
# 4            AFG   2017-12-21  2018-12-20
# ...          ...          ...         ...
# 23926        BFA   2020-12-01  2020-12-31
# 23932        BFA   2020-12-01  2020-12-31
# 23938        BFA   2020-12-01  2020-12-31
# 23946        BFA   2020-12-01  2020-12-31
# 23960        BFA   2020-12-01  2020-12-31
#
# [3146 rows x 29 columns]

# %% [markdown]
# ### TESTS

# %%
# SAMPLE TEST
sample = pd.DataFrame({
    "Full name of agency": ["A", "A", "B", "B", "C", "D", "E"],
    "Agency type": ["pri", "pri", "pri", "soe", "soe", "soe", "soe"],
    "Total reported": [0, 0, 1, 1, 2, 2, 5]
})

columns = ["Full name of agency", "Agency type", "Total reported"]

get_problematic_rows(sample, columns, 2)
# Out:
#   Full name of agency Agency type  Total reported  rowid
# 0                   A         pri               0      0
# 1                   A         pri               0      1
# 2                   B         pri               1      2
# 3                   B         soe               1      3
# 4                   C         soe               2      4
# 5                   D         soe               2      5

# %%
# Sample data for sample_companies_list
sample_companies_list_data = {
    "Full company name": ["A Corp", "B Corp", "C Corp", "D Corp", "E Corp", "B Corp", "F Corp"],
    "Company type": ["Type1", "Type2", "Type3", "Type1", "Type2", "Type2", "Type3"],
    "Company ID number": [101, 102, 103, 104, 105, 102, 106],
    "Country": ["X", "Y", "Z", "X", "Y", "Y", "Z"],
    "Year": [2020, 2021, 2022, 2023, 2020, 2021, 2023]
}

sample_company_list = pd.DataFrame(sample_companies_list_data)

# Sample data for sample_company_data
sample_company_data_data = {
    "Company": ["A Corp", "B Corp", "C Corp", "E Corp", "F Corp", "C Corp", "G Corp"],
    "Project name": ["P1", "P2", "P3", "P4", "P5", "P3", "P6"],
    "Country": ["X", "Y", "Z", "X", "Y", "Z", "X"],
    "Year": [2020, 2021, 2022, 2023, 2022, 2023, 2021]
}

sample_company_data = pd.DataFrame(sample_company_data_data)

display(sample_company_list)
display(sample_company_data)
# Out:
#   Full company name Company type  Company ID number Country  Year
# 0            A Corp        Type1                101       X  2020
# 1            B Corp        Type2                102       Y  2021
# 2            C Corp        Type3                103       Z  2022
# 3            D Corp        Type1                104       X  2023
# 4            E Corp        Type2                105       Y  2020
# 5            B Corp        Type2                102       Y  2021
# 6            F Corp        Type3                106       Z  2023
#   Company Project name Country  Year
# 0  A Corp           P1       X  2020
# 1  B Corp           P2       Y  2021
# 2  C Corp           P3       Z  2022
# 3  E Corp           P4       X  2023
# 4  F Corp           P5       Y  2022
# 5  C Corp           P3       Z  2023
# 6  G Corp           P6       X  2021

# %%
common_columns_df1 = ["Full company name", "Year"]
common_columns_df2 = ["Company", "Year"]

for key, data in compare_tables(sample_company_list, sample_company_data, common_columns_df1, common_columns_df2).items():
    print(key)
    display(data)
# Out:
# in table 1 but not in table 2
#   Full company name Company type  Company ID number Country  Year
# 3            D Corp        Type1                104       X  2023
# 4            E Corp        Type2                105       Y  2020
# 6            F Corp        Type3                106       Z  2023
# in table 2 but not in table 1
#   Company Project name Country  Year
# 3  E Corp           P4       X  2023
# 4  F Corp           P5       Y  2022
# 5  C Corp           P3       Z  2023
# 6  G Corp           P6       X  2021
# in both tables
#   Full company name Company type  Company ID number Country_x  Year Company  \
# 0            A Corp        Type1                101         X  2020  A Corp
# 1            B Corp        Type2                102         Y  2021  B Corp
# 2            C Corp        Type3                103         Z  2022  C Corp
# 3            B Corp        Type2                102         Y  2021  B Corp
#
#   Project name Country_y
# 0           P1         X
# 1           P2         Y
# 2           P3         Z
# 3           P2         Y

# %%
for key, data in compare_tables_drop_duplicates(sample_company_list, sample_company_data, common_columns_df1, common_columns_df2).items():
    print(key)
    display(data)
# Out:
# in table 1 but not in table 2
#   Full company name Company type  Company ID number Country  Year
# 3            D Corp        Type1                104       X  2023
# 4            E Corp        Type2                105       Y  2020
# 6            F Corp        Type3                106       Z  2023
# in table 2 but not in table 1
#   Company Project name Country  Year
# 3  E Corp           P4       X  2023
# 4  F Corp           P5       Y  2022
# 5  C Corp           P3       Z  2023
# 6  G Corp           P6       X  2021
# in both tables
#   Full company name Company type  Company ID number Country_x  Year Company  \
# 0            A Corp        Type1                101         X  2020  A Corp
# 1            B Corp        Type2                102         Y  2021  B Corp
# 2            C Corp        Type3                103         Z  2022  C Corp
#
#   Project name Country_y
# 0           P1         X
# 1           P2         Y
# 2           P3         Z

# %%
rev_part_4 = df_part_4.copy()
rev_part_5 = df_part_5.copy()

rev_part_4["Revenue value"] = rev_part_4["Revenue value"].str.replace(",", "")

rev_part_4["Revenue value"] = pd.to_numeric(rev_part_4["Revenue value"], errors="coerce")
rev_part_5["Revenue value"] = pd.to_numeric(rev_part_5["Revenue value"], errors="coerce")

# rev_part_4

# 100*(rev_part_4["Revenue value"].sum() - rev_part_5["Revenue value"].sum())/rev_part_4["Revenue value"].sum()

rev_part_4_sum = rev_part_4.groupby(["Country"])["Revenue value"].sum()
rev_part_5_sum = rev_part_5.groupby(["Country"])["Revenue value"].sum()

(100*(rev_part_4_sum - rev_part_5_sum)/rev_part_4_sum).sort_values(ascending=False).reset_index().style.format({'Revenue value': '{:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_1cfaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1cfaa_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_1cfaa_level0_col1" class="col_heading level0 col1" >Revenue value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cfaa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1cfaa_row0_col0" class="data row0 col0" >Albania</td>
#       <td id="T_1cfaa_row0_col1" class="data row0 col1" >77.74</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1cfaa_row1_col0" class="data row1 col0" >Nigeria</td>
#       <td id="T_1cfaa_row1_col1" class="data row1 col1" >57.13</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1cfaa_row2_col0" class="data row2 col0" >Argentina</td>
#       <td id="T_1cfaa_row2_col1" class="data row2 col1" >42.85</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1cfaa_row3_col0" class="data row3 col0" >Suriname</td>
#       <td id="T_1cfaa_row3_col1" class="data row3 col1" >37.46</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1cfaa_row4_col0" class="data row4 col0" >Guyana</td>
#       <td id="T_1cfaa_row4_col1" class="data row4 col1" >33.19</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1cfaa_row5_col0" class="data row5 col0" >Liberia</td>
#       <td id="T_1cfaa_row5_col1" class="data row5 col1" >17.03</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1cfaa_row6_col0" class="data row6 col0" >Zambia</td>
#       <td id="T_1cfaa_row6_col1" class="data row6 col1" >15.99</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1cfaa_row7_col0" class="data row7 col0" >Burkina Faso</td>
#       <td id="T_1cfaa_row7_col1" class="data row7 col1" >15.36</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1cfaa_row8_col0" class="data row8 col0" >Mali</td>
#       <td id="T_1cfaa_row8_col1" class="data row8 col1" >12.83</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1cfaa_row9_col0" class="data row9 col0" >Togo</td>
#       <td id="T_1cfaa_row9_col1" class="data row9 col1" >9.38</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1cfaa_row10_col0" class="data row10 col0" >Tanzania</td>
#       <td id="T_1cfaa_row10_col1" class="data row10 col1" >8.84</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1cfaa_row11_col0" class="data row11 col0" >Republic of the Congo</td>
#       <td id="T_1cfaa_row11_col1" class="data row11 col1" >7.38</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1cfaa_row12_col0" class="data row12 col0" >Mongolia</td>
#       <td id="T_1cfaa_row12_col1" class="data row12 col1" >7.25</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1cfaa_row13_col0" class="data row13 col0" >Ethiopia</td>
#       <td id="T_1cfaa_row13_col1" class="data row13 col1" >6.65</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1cfaa_row14_col0" class="data row14 col0" >Iraq</td>
#       <td id="T_1cfaa_row14_col1" class="data row14 col1" >6.24</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1cfaa_row15_col0" class="data row15 col0" >Philippines</td>
#       <td id="T_1cfaa_row15_col1" class="data row15 col1" >6.15</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1cfaa_row16_col0" class="data row16 col0" >Mexico</td>
#       <td id="T_1cfaa_row16_col1" class="data row16 col1" >5.81</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1cfaa_row17_col0" class="data row17 col0" >Madagascar</td>
#       <td id="T_1cfaa_row17_col1" class="data row17 col1" >3.63</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1cfaa_row18_col0" class="data row18 col0" >Myanmar</td>
#       <td id="T_1cfaa_row18_col1" class="data row18 col1" >3.49</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1cfaa_row19_col0" class="data row19 col0" >Ukraine</td>
#       <td id="T_1cfaa_row19_col1" class="data row19 col1" >3.34</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1cfaa_row20_col0" class="data row20 col0" >Ghana</td>
#       <td id="T_1cfaa_row20_col1" class="data row20 col1" >3.33</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1cfaa_row21_col0" class="data row21 col0" >Senegal</td>
#       <td id="T_1cfaa_row21_col1" class="data row21 col1" >2.86</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1cfaa_row22_col0" class="data row22 col0" >United Kingdom</td>
#       <td id="T_1cfaa_row22_col1" class="data row22 col1" >1.52</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1cfaa_row23_col0" class="data row23 col0" >Democratic Republic of Congo</td>
#       <td id="T_1cfaa_row23_col1" class="data row23 col1" >1.03</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_1cfaa_row24_col0" class="data row24 col0" >Cote d'Ivoire</td>
#       <td id="T_1cfaa_row24_col1" class="data row24 col1" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_1cfaa_row25_col0" class="data row25 col0" >Afghanistan</td>
#       <td id="T_1cfaa_row25_col1" class="data row25 col1" >0.49</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_1cfaa_row26_col0" class="data row26 col0" >Armenia</td>
#       <td id="T_1cfaa_row26_col1" class="data row26 col1" >0.49</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_1cfaa_row27_col0" class="data row27 col0" >Dominican Republic</td>
#       <td id="T_1cfaa_row27_col1" class="data row27 col1" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_1cfaa_row28_col0" class="data row28 col0" >Cameroon</td>
#       <td id="T_1cfaa_row28_col1" class="data row28 col1" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_1cfaa_row29_col0" class="data row29 col0" >Mauritania</td>
#       <td id="T_1cfaa_row29_col1" class="data row29 col1" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_1cfaa_row30_col0" class="data row30 col0" >Norway</td>
#       <td id="T_1cfaa_row30_col1" class="data row30 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row31" class="row_heading level0 row31" >31</th>
#       <td id="T_1cfaa_row31_col0" class="data row31 col0" >Trinidad and Tobago</td>
#       <td id="T_1cfaa_row31_col1" class="data row31 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1cfaa_level0_row32" cl

# %%
rev_part_4[rev_part_4["Country"]=="Norway"]["Revenue value"].sum() - rev_part_5[rev_part_5["Country"]=="Norway"]["Revenue value"].sum()
# Out:
# 5550000.0

# %%
err_part_3a = df_part_3a.copy()

err_part_3a["rowid"] = range(len(err_part_3a))

error_rows = err_part_3a[err_part_3a.apply(lambda row: row.astype(str).str.contains('#ERROR!').any(), axis=1)]

display(error_rows)
# Out:
# Empty DataFrame
# Columns: [Full company name, Company type, Company ID number, Sector, Commodities (comma-seperated), Stock exchange listing or company website, Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable), Payments to Governments Report, Country, ISO Code, Year, Start Date, End Date, rowid]
# Index: []
