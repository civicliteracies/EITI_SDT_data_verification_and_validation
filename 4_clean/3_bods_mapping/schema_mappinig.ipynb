# %%
import requests
import pandas as pd

# Loading JSON schema file from Github

def load_json_from_url(url):
    response = requests.get(url)
    return response.json()

# Resolves JSON schema $refs based on definitions

def resolve_ref(ref, definitions):
    ref_path = ref.strip('#/').split('/')
    data = definitions
    for step in ref_path:
        data = data.get(step, {})
    return data

# %%
def extract_schema_data_statement(schema, definitions, path='', required_fields=[]):
    rows = []
    if 'properties' in schema:
        properties = schema['properties']
        for prop_name, prop_details in properties.items():
            full_path = f"{path}.{prop_name}" if path else prop_name
            is_required = prop_name in required_fields
            if '$ref' in prop_details:
                # Resolve the $ref and continue extraction with the resolved schema
                resolved_details = resolve_ref(prop_details['$ref'], definitions)
                rows += extract_schema_data_statement(resolved_details, definitions, full_path, required_fields)
            elif 'properties' in prop_details:
                # Recursively extract nested properties
                rows += extract_schema_data_statement(prop_details, definitions, full_path, required_fields)
            elif 'items' in prop_details and isinstance(prop_details['items'], dict):
                # Handle arrays of items which are objects
                items_details = prop_details['items']
                if '$ref' in items_details:
                    resolved_items = resolve_ref(items_details['$ref'], definitions)
                    rows += extract_schema_data_statement(resolved_items, definitions, f"{full_path}[]", required_fields)
                else:
                    rows += extract_schema_data_statement(items_details, definitions, f"{full_path}[]", required_fields)
            else:
                # Handle simple properties and properties with enum values
                prop_type = prop_details.get('type', 'N/A')
                description = prop_details.get('description', 'No description available')
                enums = prop_details.get('enum', [])
                enum_values = ', '.join(map(str, enums)) if enums else 'N/A'
                rows.append({
                    'Field': full_path,
                    'Type': prop_type,
                    'Description': description,
                    'Required': 'Yes' if is_required else 'No',
                    'Allowed Values': enum_values
                })
    return rows

# %%
# Statement Schema Processing
url = "https://raw.githubusercontent.com/openownership/data-standard/main/schema/statement.json"
json_schema = load_json_from_url(url)
definitions = json_schema.get('$defs', {})
statement_schema = definitions.get('Statement', {})
required_fields = statement_schema.get('required', [])
data = extract_schema_data_statement(statement_schema, definitions, required_fields=required_fields)
df_statement = pd.DataFrame(data)
df_statement
# Out:
#                                  Field    Type  \
# 0                          statementId  string
# 1                        statementDate  string
# 2   publicationDetails.publicationDate  string
# 3       publicationDetails.bodsVersion  string
# 4           publicationDetails.license  string
# 5    publicationDetails.publisher.name  string
# 6     publicationDetails.publisher.url  string
# 7                          declaration  string
# 8                   declarationSubject  string
# 9                             recordId  string
# 10                          recordType  string
# 11                        recordStatus  string
# 12                       recordDetails  object
#
#                                           Description Required  \
# 0   A persistent globally unique identifier for th...      Yes
# 1   The date on which this statement was declared ...      Yes
# 2   The date on which this statement was published...       No
# 3   The version of the Beneficial Ownership Data S...       No
# 4   A link to the license that applies to this Sta...       No
# 5                          The name of the publisher.       No
# 6   The URL where details of the full dataset, or ...       No
# 7   An identifier or reference for a declaration w...       No
# 8   A `recordId` value for the subject of a benefi...      Yes
# 9   A unique identifier for the record (within the...      Yes
# 10  The type of record (within the publisher's sys...      Yes
# 11  The lifecycle status of the record (within the...       No
# 12  The details of the entity, person or relations...      Yes
#
#                   Allowed Values
# 0                            N/A
# 1                            N/A
# 2                            N/A
# 3                            N/A
# 4                            N/A
# 5                            N/A
# 6                            N/A
# 7                            N/A
# 8                            N/A
# 9                            N/A
# 10  entity, person, relationship
# 11          new, updated, closed
# 12                           N/A

# %%
def extract_schema_data_entity(schema, definitions, path='', required_fields=[]):
    rows = []
    if 'properties' in schema:
        properties = schema['properties']
        for prop_name, prop_details in properties.items():
            full_path = f"{path}.{prop_name}" if path else prop_name
            is_required = prop_name in required_fields
            if '$ref' in prop_details:
                # Resolve the $ref and continue extraction with the resolved schema
                resolved_details = resolve_ref(prop_details['$ref'], definitions)
                rows += extract_schema_data_entity(resolved_details, definitions, full_path, required_fields)
            elif 'properties' in prop_details or 'items' in prop_details:
                # Recursively handle nested properties or arrays of items
                rows += extract_schema_data_entity(prop_details, definitions, full_path, required_fields)
            else:
                # Extract basic property information
                prop_type = prop_details.get('type', 'N/A')
                description = prop_details.get('description', 'No description available')
                enums = prop_details.get('enum', [])
                enum_values = ', '.join(map(str, enums)) if enums else 'N/A'
                rows.append({
                    'Field': full_path,
                    'Type': prop_type,
                    'Description': description,
                    'Required': 'Yes' if is_required else 'No',
                    'Allowed Values': enum_values
                })
    return rows

# %%
# Entity schema processing
url = "https://raw.githubusercontent.com/openownership/data-standard/main/schema/entity-record.json"
json_schema = load_json_from_url(url)
definitions = json_schema.get('$defs', {})
required_fields = json_schema.get('required', [])
data = extract_schema_data_entity(json_schema, definitions, required_fields=required_fields)
df_entity = pd.DataFrame(data)
display(df_entity)
# Out:
#                   Field     Type  \
# 0           isComponent  boolean
# 1       entityType.type   string
# 2    entityType.subtype   string
# 3    entityType.details   string
# 4                  name   string
# 5          foundingDate   string
# 6       dissolutionDate   string
# 7                   uri   string
# 8  formedByStatute.name   string
# 9  formedByStatute.date   string
#
#                                          Description Required  \
# 0  Whether this entity is a component in an indir...      Yes
# 1  The general form of the entity, using the enti...       No
# 2  The particular form of the entity, where relev...       No
# 3  This may be used to provide a local name for t...       No
# 4                  The declared name of this entity.       No
# 5  The date on which this entity was founded, cre...       No
# 6  The date on which this entity was dissolved or...       No
# 7  Where a persistent URI (https://en.wikipedia.o...       No
# 8                              The name of the law.        No
# 9  The date on which the law came into force. The...       No
#
#                                       Allowed Values
# 0                                                N/A
# 1  registeredEntity, legalEntity, arrangement, an...
# 2  governmentDepartment, stateAgency, other, trus...
# 3                                                N/A
# 4                                                N/A
# 5                                                N/A
# 6                                                N/A
# 7                                                N/A
# 8                                                N/A
# 9                                                N/A

# %%
def extract_schema_data_relationship(schema, definitions, path='', required_fields=[]):
    rows = []
    if 'properties' in schema:
        properties = schema['properties']
        for prop_name, prop_details in properties.items():
            full_path = f"{path}.{prop_name}" if path else prop_name
            is_required = prop_name in required_fields
            if 'oneOf' in prop_details:
                # Handle oneOf by concatenating all possible types
                type_descriptions = []
                for option in prop_details['oneOf']:
                    if '$ref' in option:
                        ref_info = resolve_ref(option['$ref'], definitions)
                        type_description = f"Ref to {option['$ref']}"
                    elif 'type' in option:
                        type_description = option['type']
                    type_descriptions.append(type_description)
                prop_type = 'oneOf: ' + ', '.join(type_descriptions)
            elif '$ref' in prop_details:
                resolved_details = resolve_ref(prop_details['$ref'], definitions)
                rows += extract_schema_data_relationship(resolved_details, definitions, full_path, required_fields)
                prop_type = f"Ref to {prop_details['$ref']}"
            else:
                prop_type = prop_details.get('type', 'N/A')

            description = prop_details.get('description', 'No description available')
            rows.append({
                'Field': full_path,
                'Type': prop_type,
                'Description': description,
                'Required': 'Yes' if is_required else 'No'
            })

    return rows

# %%
# Relationship schema processing
url = "https://raw.githubusercontent.com/openownership/data-standard/main/schema/relationship-record.json"
json_schema = load_json_from_url(url)
definitions = json_schema.get('$defs', {})
required_fields = json_schema.get('required', [])
data = extract_schema_data_relationship(json_schema, definitions, required_fields=required_fields)
df_relationship = pd.DataFrame(data)
display(df_relationship)
df_relationship.to_csv('test.csv')
# Out:
#               Field                                               Type  \
# 0       isComponent                                            boolean
# 1  componentRecords                                              array
# 2           subject  oneOf: string, Ref to urn:components#/$defs/Un...
# 3   interestedParty  oneOf: string, Ref to urn:components#/$defs/Un...
# 4         interests                                              array
#
#                                          Description Required
# 0  Whether this relationship is a component of a ...      Yes
# 1  The `recordId` values of all component records...       No
# 2  The `recordId` for the subject of the relation...      Yes
# 3  The `recordId` for the interested party in the...      Yes
# 4  A description of the interests held by the int...       No

# %%
def extract_schema_data_components(schema, definitions, path='', required_fields=[]):
    rows = []
    if 'properties' in schema:
        properties = schema['properties']
        for prop_name, prop_details in properties.items():
            full_path = f"{path}.{prop_name}" if path else prop_name
            is_required = prop_name in required_fields
            if '$ref' in prop_details:
                # Resolve the $ref and continue extraction with the resolved schema
                resolved_details = resolve_ref(prop_details['$ref'], definitions)
                rows += extract_schema_data_components(resolved_details, definitions, full_path, required_fields)
            elif 'properties' in prop_details or 'items' in prop_details:
                # Recursively handle nested properties or arrays of items
                rows += extract_schema_data_components(prop_details, definitions, full_path, required_fields)
            else:
                # Extract basic property information
                prop_type = prop_details.get('type', 'N/A')
                description = prop_details.get('description', 'No description available')
                enums = prop_details.get('enum', [])
                enum_values = ', '.join(map(str, enums)) if enums else 'N/A'
                rows.append({
                    'Field': full_path,
                    'Type': prop_type,
                    'Description': description,
                    'Required': 'Yes' if is_required else 'No',
                    'Allowed Values': enum_values
                })
    return rows

# %%
# Components schema processing
url = "https://raw.githubusercontent.com/openownership/data-standard/main/schema/components.json"
json_schema = load_json_from_url(url)
definitions = json_schema.get('$defs', {})
data = []
for component_name, component_schema in definitions.items():
    required_fields = component_schema.get('required', [])
    component_data = extract_schema_data_components(component_schema, definitions, path=component_name, required_fields=required_fields)
    data.extend(component_data)

df_components = pd.DataFrame(data)
display(df_components)
# Out:
#                             Field    Type  \
# 0                    Address.type  string
# 1                 Address.address  string
# 2                Address.postCode  string
# 3                    Country.name  string
# 4                    Country.code  string
# 5               Jurisdiction.name  string
# 6               Jurisdiction.code  string
# 7                   Identifier.id  string
# 8               Identifier.scheme  string
# 9           Identifier.schemeName  string
# 10                 Identifier.uri  string
# 11       UnspecifiedRecord.reason  string
# 12  UnspecifiedRecord.description  string
# 13             Source.description  string
# 14                     Source.url  string
# 15             Source.retrievedAt  string
#
#                                           Description Required  \
# 0   The function of the address, using the address...       No
# 1   The address, with each line or component separ...       No
# 2                   The postal code for this address.       No
# 3                             The name of the country      Yes
# 4   The 2-letter country code (ISO 3166-1) for thi...       No
# 5                        The name of the jurisdiction      Yes
# 6   The 2-letter country code (ISO 3166-1) or the ...       No
# 7   The identifier for a person or entity, as issu...       No
# 8   For entities, a code from org-id.guide (https:...       No
# 9       The name of the identifier-issuing authority.       No
# 10  A canonical URI (https://en.wikipedia.org/wiki...       No
# 11  The reason that a person or entity cannot be s...      Yes
# 12  Additional information about the absence of de...       No
# 13  Additional, free text information about the so...       No
# 14  The external URL from which this information w...       No
# 15  A timestamp indicating when this information w...       No
#
#                                        Allowed Values
# 0   placeOfBirth, residence, registered, service, ...
# 1                                                 N/A
# 2                                                 N/A
# 3                                                 N/A
# 4                                                 N/A
# 5                                                 N/A
# 6                                                 N/A
# 7                                                 N/A
# 8                                                 N/A
# 9                                                 N/A
# 10                                                N/A
# 11  noBeneficialOwners, subjectUnableToConfirmOrId...
# 12                                                N/A
# 13                                                N/A
# 14                                                N/A
# 15                                                N/A

# %%
df_statement['Source'] = 'Statement'
df_entity['Source'] = 'Entity'
df_relationship['Source'] = 'Relationship'
df_components['Source'] = 'Components'

df_final = pd.concat([df_statement, df_entity, df_relationship, df_components], ignore_index=True)

display(df_final)
# Out:
#                                  Field  \
# 0                          statementId
# 1                        statementDate
# 2   publicationDetails.publicationDate
# 3       publicationDetails.bodsVersion
# 4           publicationDetails.license
# 5    publicationDetails.publisher.name
# 6     publicationDetails.publisher.url
# 7                          declaration
# 8                   declarationSubject
# 9                             recordId
# 10                          recordType
# 11                        recordStatus
# 12                       recordDetails
# 13                         isComponent
# 14                     entityType.type
# 15                  entityType.subtype
# 16                  entityType.details
# 17                                name
# 18                        foundingDate
# 19                     dissolutionDate
# 20                                 uri
# 21                formedByStatute.name
# 22                formedByStatute.date
# 23                         isComponent
# 24                    componentRecords
# 25                             subject
# 26                     interestedParty
# 27                           interests
# 28                        Address.type
# 29                     Address.address
# 30                    Address.postCode
# 31                        Country.name
# 32                        Country.code
# 33                   Jurisdiction.name
# 34                   Jurisdiction.code
# 35                       Identifier.id
# 36                   Identifier.scheme
# 37               Identifier.schemeName
# 38                      Identifier.uri
# 39            UnspecifiedRecord.reason
# 40       UnspecifiedRecord.description
# 41                  Source.description
# 42                          Source.url
# 43                  Source.retrievedAt
#
#                                                  Type  \
# 0                                              string
# 1                                              string
# 2                                              string
# 3                                              string
# 4                                              string
# 5                                              string
# 6                                              string
# 7                                              string
# 8                                              string
# 9                                              string
# 10                                             string
# 11                                             string
# 12                                             object
# 13                                            boolean
# 14                                             string
# 15                                             string
# 16                                             string
# 17                                             string
# 18                                             string
# 19                                             string
# 20                                             string
# 21                                             string
# 22                                             string
# 23                                            boolean
# 24                                              array
# 25  oneOf: string, Ref to urn:components#/$defs/Un...
# 26  oneOf: string, Ref to urn:components#/$defs/Un...
# 27                                              array
# 28                                             string
# 29                                             string
# 30                                             string
# 31                                             string
# 32                                             string
# 33                                             string
# 34                                             string
# 35                                             string
# 36                                             string
# 37                                             string
# 38                                             string
# 39                                             string
# 40                                             string
# 41                                             string
# 42                                             string
# 43                                             string
#
#                                           Description Required  \
# 0   A persistent globally unique identifier for th...      Yes
# 1   The date on which this statement was declared ...      Yes
# 2   The date on which this statement was published...       No
# 3   The version of the Beneficial Ownership Data S...       No
# 4   A link to the license that applies to this Sta...       No
# 5                          The name of the publisher.       No
# 6   The URL where details of the full dataset, or ...       No
# 7   An identifier or reference for a declaration w...       No
# 8   A `recordId` value for the subject of a benefi...      Yes
# 9   A unique identifier for the record (within the...      Yes
# 10  The type of record (within the publisher's sys...      Yes
# 11  The lifecycle status of the record (within the...       No
# 12  The details of the entity, person or relations...      Yes
# 13  Whether this entity is a component in an indir...      Yes
# 14  The general form of the entity, using the enti...       No
# 15  The particular form of the entity, where relev...       No
# 16  This may be used to provide a local name for t...       No
# 17                  The declared name of this entity.       No
# 18  The date on which this entity was founded, cre...       No
# 19  The date on which this entity was dissolved or...       No
# 20  Where a persistent URI (https://en.wikipedia.o...       No
# 21                              The name of the law.        No
# 22  The date on which the law came into force. The...       No
# 23  Whether this relationship is a component of a ...      Yes
# 24  The `recordId` values of all component records...       No
# 25  The `recordId` for the subject of the relation...      Yes
# 26  The `recordId` for the interested party in the...      Yes
# 27  A description of the interests held by the int...       No
# 28  The function of the address, using the address...       No
# 29  The address, with each line or component separ...       No
# 30                  The postal code for this address.       No
# 31                            The name of the country      Yes
# 32  The 2-letter country code (ISO 3166-1) for thi...       No
# 33                       The name of the jurisdiction      Yes
# 34  The 2-letter country code (ISO 3166-1) or the ...       No
# 35  The identifier for a person or entity, as issu...       No
# 36  For entities, a code from org-id.guide (https:...       No
# 37      The name of the identifier-issuing authority.       No
# 38  A canonical URI (https://en.wikipedia.org/wiki...       No
# 39  The reason that a person or entity cannot be s...      Yes
# 40  Additional information about the absence of de...       No
# 41  Additional, free text information about the so...       No
# 42  The external URL from which this information w...       No
# 43  A timestamp indicating when this information w...       No
#
#                                        Allowed Values        Source
# 0                                                 N/A     Statement
# 1                                                 N/A     Statement
# 2                                                 N/A     Statement
# 3                                                 N/A     Statement
# 4                                                 N/A     Statement
# 5                                                 N/A     Statement
# 6                                                 N/A     Statement
# 7                                                 N/A     Statement
# 8                                                 N/A     Statement
# 9                                                 N/A     Statement
# 10                       entity, person, relationship     Statement
# 11                               new, updated, closed     Statement
# 12                                                N/A     Statement
# 13                                                N/A        Entity
# 14  registeredEntity, legalEntity, arrangement, an...        Entity
# 15  governmentDepartment, stateAgency, other, trus...        Entity
# 16                                                N/A        Entity
# 17                                                N/A        Entity
# 18                                                N/A        Entity
# 19                                                N/A        Entity
# 20                                                N/A        Entity
# 21                                                N/A        Entity
# 22                                                N/A        Entity
# 23                                                NaN  Relationship
# 24                                                NaN  Relationship
# 25                                                NaN  Relationship
# 26                                                NaN  Relationship
# 27                                                NaN  Relationship
# 28  placeOfBirth, residence, registered, service, ...    Components
# 29                                                N/A    Components
# 30                                                N/A    Components
# 31                                                N/A    Components
# 32                                                N/A    Components
# 33                                                N/A    Components
# 34                                                N/A    Components
# 35                                                N/A    Components
# 36                                                N/A    Components
# 37                                                N/A    Components
# 38                                                N/A    Components
# 39  noBeneficialOwners, subjectUnableToConfirmOrId...    Components
# 40                                                N/A    Components
# 41                                                N/A    Components
# 42                                                N/A    Components
# 43                                                N/A    Components

# %%
df_final.to_csv('mapping.csv',index=False)
