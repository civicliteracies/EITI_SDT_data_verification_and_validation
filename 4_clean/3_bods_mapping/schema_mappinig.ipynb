# %%
import requests
import pandas as pd

# Loading JSON schema file from Github

def load_json_from_url(url):
    response = requests.get(url)
    return response.json()

# Resolves JSON schema $refs based on definitions

def resolve_ref(ref, definitions):
    ref_path = ref.strip('#/').split('/')
    data = definitions
    for step in ref_path:
        data = data.get(step, {})
    return data

# %%
def extract_schema_data_statement(schema, definitions, path='', required_fields=[]):
    rows = []
    if 'properties' in schema:
        properties = schema['properties']
        for prop_name, prop_details in properties.items():
            full_path = f"{path}.{prop_name}" if path else prop_name
            is_required = prop_name in required_fields
            if '$ref' in prop_details:
                resolved_details = resolve_ref(prop_details['$ref'], definitions)
                rows += extract_schema_data_statement(resolved_details, definitions, full_path, required_fields)
            else:
                prop_type = prop_details.get('type', 'N/A')
                description = prop_details.get('description', 'No description available')
                rows.append({
                    'Field': full_path,
                    'Type': prop_type,
                    'Description': description,
                    'Required': 'Yes' if is_required else 'No'
                })
    return rows

# %%
# Statement Schema Processing
url = "https://raw.githubusercontent.com/openownership/data-standard/main/schema/statement.json"
json_schema = load_json_from_url(url)
definitions = json_schema.get('$defs', {})
statement_schema = definitions.get('Statement', {})
required_fields = statement_schema.get('required', [])
data = extract_schema_data_statement(statement_schema, definitions, required_fields=required_fields)
df_statement = pd.DataFrame(data)
display(df_statement)
# Out:
#                 Field    Type  \
# 0         statementId  string
# 1       statementDate  string
# 2         annotations   array
# 3  publicationDetails  object
# 4         declaration  string
# 5  declarationSubject  string
# 6            recordId  string
# 7          recordType  string
# 8        recordStatus  string
# 9       recordDetails  object
#
#                                          Description Required
# 0  A persistent globally unique identifier for th...      Yes
# 1  The date on which this statement was declared ...      Yes
# 2  Annotations about this Statement or parts of t...       No
# 3  Information concerning the publication of this...       No
# 4  An identifier or reference for a declaration w...       No
# 5  A `recordId` value for the subject of a benefi...      Yes
# 6  A unique identifier for the record (within the...      Yes
# 7  The type of record (within the publisher's sys...      Yes
# 8  The lifecycle status of the record (within the...       No
# 9  The details of the entity, person or relations...      Yes

# %%
def extract_schema_data_entity(schema, definitions, path='', required_fields=[]):
    rows = []
    if 'properties' in schema:
        properties = schema['properties']
        for prop_name, prop_details in properties.items():
            full_path = f"{path}.{prop_name}" if path else prop_name
            is_required = prop_name in required_fields
            if '$ref' in prop_details:
                resolved_details = resolve_ref(prop_details['$ref'], definitions)
                rows += extract_schema_data_entity(resolved_details, definitions, full_path, required_fields)
            else:
                prop_type = prop_details.get('type', 'N/A')
                description = prop_details.get('description', 'No description available')
                rows.append({
                    'Field': full_path,
                    'Type': prop_type,
                    'Description': description,
                    'Required': 'Yes' if is_required else 'No'
                })
    return rows

# %%
# Entity schema processing
url = "https://raw.githubusercontent.com/openownership/data-standard/main/schema/entity-record.json"
json_schema = load_json_from_url(url)
definitions = json_schema.get('$defs', {})
required_fields = json_schema.get('required', [])
data = extract_schema_data_entity(json_schema, definitions, required_fields=required_fields)
df_entity = pd.DataFrame(data)
display(df_entity)
# Out:
#              Field     Type  \
# 0      isComponent  boolean
# 1       entityType   object
# 2             name   string
# 3   alternateNames    array
# 4      identifiers    array
# 5     foundingDate   string
# 6  dissolutionDate   string
# 7        addresses    array
# 8              uri   string
# 9  formedByStatute   object
#
#                                          Description Required
# 0  Whether this entity is a component in an indir...      Yes
# 1  The form of the entity described in the Statem...      Yes
# 2                  The declared name of this entity.       No
# 3   An array of other names this entity is known by.       No
# 4  One or more official identifiers for this enti...       No
# 5  The date on which this entity was founded, cre...       No
# 6  The date on which this entity was dissolved or...       No
# 7             One or more addresses for this entity.       No
# 8  Where a persistent URI (https://en.wikipedia.o...       No
# 9  The law which mandated the formation of the en...       No

# %%
def extract_schema_data_relationship(schema, definitions, path='', required_fields=[]):
    rows = []
    if 'properties' in schema:
        properties = schema['properties']
        for prop_name, prop_details in properties.items():
            full_path = f"{path}.{prop_name}" if path else prop_name
            is_required = prop_name in required_fields
            if '$ref' in prop_details:
                resolved_details = resolve_ref(prop_details['$ref'], definitions)
                rows += extract_schema_data_relationship(resolved_details, definitions, full_path, required_fields)
            else:
                prop_type = prop_details.get('type', 'N/A')
                description = prop_details.get('description', 'No description available')
                rows.append({
                    'Field': full_path,
                    'Type': prop_type,
                    'Description': description,
                    'Required': 'Yes' if is_required else 'No'
                })
    return rows

# %%
# Relationship schema processing
url = "https://raw.githubusercontent.com/openownership/data-standard/main/schema/relationship-record.json"
json_schema = load_json_from_url(url)
definitions = json_schema.get('$defs', {})
required_fields = json_schema.get('required', [])
data = extract_schema_data_relationship(json_schema, definitions, required_fields=required_fields)
df_relationship = pd.DataFrame(data)
display(df_relationship)
# Out:
#               Field     Type  \
# 0       isComponent  boolean
# 1  componentRecords    array
# 2           subject      N/A
# 3   interestedParty      N/A
# 4         interests    array
#
#                                          Description Required
# 0  Whether this relationship is a component of a ...      Yes
# 1  The `recordId` values of all component records...       No
# 2  The `recordId` for the subject of the relation...      Yes
# 3  The `recordId` for the interested party in the...      Yes
# 4  A description of the interests held by the int...       No

# %%
def extract_schema_data_components(schema, definitions, path='', required_fields=[]):
    rows = []
    if 'properties' in schema:
        properties = schema['properties']
        for prop_name, prop_details in properties.items():
            full_path = f"{path}.{prop_name}" if path else prop_name
            is_required = prop_name in required_fields
            if '$ref' in prop_details:
                resolved_details = resolve_ref(prop_details['$ref'], definitions)
                rows += extract_schema_data_components(resolved_details, definitions, full_path, required_fields)
            else:
                prop_type = prop_details.get('type', 'N/A')
                description = prop_details.get('description', 'No description available')
                rows.append({
                    'Field': full_path,
                    'Type': prop_type,
                    'Description': description,
                    'Required': 'Yes' if is_required else 'No'
                })
    return rows

# %%
# Components schema processing
url = "https://raw.githubusercontent.com/openownership/data-standard/main/schema/components.json"
json_schema = load_json_from_url(url)
definitions = json_schema.get('$defs', {})
data = []
for component_name, component_schema in definitions.items():
    required_fields = component_schema.get('required', [])
    component_data = extract_schema_data_components(component_schema, definitions, path=component_name, required_fields=required_fields)
    data.extend(component_data)

df_components = pd.DataFrame(data)
display(df_components)
# Out:
#                             Field    Type  \
# 0                    Address.type  string
# 1                 Address.address  string
# 2                Address.postCode  string
# 3                    Country.name  string
# 4                    Country.code  string
# 5               Jurisdiction.name  string
# 6               Jurisdiction.code  string
# 7                   Identifier.id  string
# 8               Identifier.scheme  string
# 9           Identifier.schemeName  string
# 10                 Identifier.uri  string
# 11       UnspecifiedRecord.reason  string
# 12  UnspecifiedRecord.description  string
# 13                    Source.type   array
# 14             Source.description  string
# 15                     Source.url  string
# 16             Source.retrievedAt  string
# 17              Source.assertedBy   array
#
#                                           Description Required
# 0   The function of the address, using the address...       No
# 1   The address, with each line or component separ...       No
# 2                   The postal code for this address.       No
# 3                             The name of the country      Yes
# 4   The 2-letter country code (ISO 3166-1) for thi...       No
# 5                        The name of the jurisdiction      Yes
# 6   The 2-letter country code (ISO 3166-1) or the ...       No
# 7   The identifier for a person or entity, as issu...       No
# 8   For entities, a code from org-id.guide (https:...       No
# 9       The name of the identifier-issuing authority.       No
# 10  A canonical URI (https://en.wikipedia.org/wiki...       No
# 11  The reason that a person or entity cannot be s...      Yes
# 12  Additional information about the absence of de...       No
# 13  The types of the source, using the sourceType ...       No
# 14  Additional, free text information about the so...       No
# 15  The external URL from which this information w...       No
# 16  A timestamp indicating when this information w...       No
# 17  The people or organisations providing the info...       No

# %%
df_statement['Source'] = 'Statement'
df_entity['Source'] = 'Entity'
df_relationship['Source'] = 'Relationship'
df_components['Source'] = 'Components'

df_final = pd.concat([df_statement, df_entity, df_relationship, df_components], ignore_index=True)

display(df_final)
# Out:
#                             Field     Type  \
# 0                     statementId   string
# 1                   statementDate   string
# 2                     annotations    array
# 3              publicationDetails   object
# 4                     declaration   string
# 5              declarationSubject   string
# 6                        recordId   string
# 7                      recordType   string
# 8                    recordStatus   string
# 9                   recordDetails   object
# 10                    isComponent  boolean
# 11                     entityType   object
# 12                           name   string
# 13                 alternateNames    array
# 14                    identifiers    array
# 15                   foundingDate   string
# 16                dissolutionDate   string
# 17                      addresses    array
# 18                            uri   string
# 19                formedByStatute   object
# 20                    isComponent  boolean
# 21               componentRecords    array
# 22                        subject      N/A
# 23                interestedParty      N/A
# 24                      interests    array
# 25                   Address.type   string
# 26                Address.address   string
# 27               Address.postCode   string
# 28                   Country.name   string
# 29                   Country.code   string
# 30              Jurisdiction.name   string
# 31              Jurisdiction.code   string
# 32                  Identifier.id   string
# 33              Identifier.scheme   string
# 34          Identifier.schemeName   string
# 35                 Identifier.uri   string
# 36       UnspecifiedRecord.reason   string
# 37  UnspecifiedRecord.description   string
# 38                    Source.type    array
# 39             Source.description   string
# 40                     Source.url   string
# 41             Source.retrievedAt   string
# 42              Source.assertedBy    array
#
#                                           Description Required        Source
# 0   A persistent globally unique identifier for th...      Yes     Statement
# 1   The date on which this statement was declared ...      Yes     Statement
# 2   Annotations about this Statement or parts of t...       No     Statement
# 3   Information concerning the publication of this...       No     Statement
# 4   An identifier or reference for a declaration w...       No     Statement
# 5   A `recordId` value for the subject of a benefi...      Yes     Statement
# 6   A unique identifier for the record (within the...      Yes     Statement
# 7   The type of record (within the publisher's sys...      Yes     Statement
# 8   The lifecycle status of the record (within the...       No     Statement
# 9   The details of the entity, person or relations...      Yes     Statement
# 10  Whether this entity is a component in an indir...      Yes        Entity
# 11  The form of the entity described in the Statem...      Yes        Entity
# 12                  The declared name of this entity.       No        Entity
# 13   An array of other names this entity is known by.       No        Entity
# 14  One or more official identifiers for this enti...       No        Entity
# 15  The date on which this entity was founded, cre...       No        Entity
# 16  The date on which this entity was dissolved or...       No        Entity
# 17             One or more addresses for this entity.       No        Entity
# 18  Where a persistent URI (https://en.wikipedia.o...       No        Entity
# 19  The law which mandated the formation of the en...       No        Entity
# 20  Whether this relationship is a component of a ...      Yes  Relationship
# 21  The `recordId` values of all component records...       No  Relationship
# 22  The `recordId` for the subject of the relation...      Yes  Relationship
# 23  The `recordId` for the interested party in the...      Yes  Relationship
# 24  A description of the interests held by the int...       No  Relationship
# 25  The function of the address, using the address...       No    Components
# 26  The address, with each line or component separ...       No    Components
# 27                  The postal code for this address.       No    Components
# 28                            The name of the country      Yes    Components
# 29  The 2-letter country code (ISO 3166-1) for thi...       No    Components
# 30                       The name of the jurisdiction      Yes    Components
# 31  The 2-letter country code (ISO 3166-1) or the ...       No    Components
# 32  The identifier for a person or entity, as issu...       No    Components
# 33  For entities, a code from org-id.guide (https:...       No    Components
# 34      The name of the identifier-issuing authority.       No    Components
# 35  A canonical URI (https://en.wikipedia.org/wiki...       No    Components
# 36  The reason that a person or entity cannot be s...      Yes    Components
# 37  Additional information about the absence of de...       No    Components
# 38  The types of the source, using the sourceType ...       No    Components
# 39  Additional, free text information about the so...       No    Components
# 40  The external URL from which this information w...       No    Components
# 41  A timestamp indicating when this information w...       No    Components
# 42  The people or organisations providing the info...       No    Components
