# %%
import requests
import json
import jsonref
import pandas as pd

# %%
# Purpose: Loads JSON data from either a local file path or a remote URL.
# How It Works: This function checks if the provided URL starts with http: or https:, 
# indicating that it's a remote URL. If so, it uses the requests library to fetch the content. 
# If not, it assumes the URL is a local file path and opens the file to load JSON data. 
# It returns the loaded JSON object.

def load_json(source):
    """
    Load JSON data from a given source which can be a URL or a local file path.
    Raises appropriate exceptions for HTTP errors or file reading errors.
    """
    if source.startswith(('http:', 'https:')):
        try:
            response = requests.get(source)
            response.raise_for_status()
            return response.json()
        except requests.RequestException as e:
            raise RuntimeError(f"Failed to fetch data from {source}: {str(e)}")
    else:
        try:
            with open(source, 'r') as file:
                return json.load(file)
        except FileNotFoundError:
            raise FileNotFoundError(f"No file found at {source}")
        except json.JSONDecodeError as e:
            raise json.JSONDecodeError(f"Error decoding JSON from {source}: {str(e)}")


# resolve_fragment
# Purpose: Resolves a JSON Pointer fragment within a JSON document.
# How It Works: Given a document and a fragment (a path like `/properties/name`), 
# it splits the fragment and iteratively accesses nested properties within the JSON document 
# to return the specific part of the document referred to by the fragment.

def resolve_fragment(document, fragment):
    parts = fragment.strip('/').split('/')
    sub_document = document
    for part in parts:
        try:
            sub_document = sub_document[part]
        except KeyError:
            raise KeyError(f"Fragment '{fragment}' not found in the document.")
    return sub_document

# %%
# General JSON reference loader that handles HTTP, HTTPS, or local file URIs.
# Returns the JSON object loaded from the URI.

def custom_loader_general(uri, base_uri=None, **kwargs):
    if uri.startswith(("http://", "https://")):
        return load_json(uri)
    elif uri.startswith("file://"):
        try:
            with open(uri.replace("file://", ""), "r") as file:
                return json.load(file)
        except Exception as e:
            raise ValueError(f"Error reading file at {uri}: {str(e)}")
    else:
        raise ValueError(f"Unhandled URI: {uri}")

# Custom loader for JSON $ref tags that specifically handle component definitions.
# Fetches 'components.json' from a predefined URL and resolves any specific fragments.

def custom_loader_for_components(uri, base_uri=None, **kwargs):
    if uri.startswith("urn:components"):
        components_url = 'https://raw.githubusercontent.com/openownership/data-standard/main/schema/components.json'
        components = load_json(components_url)
        fragment = uri.partition('#')[2] if '#' in uri else ''
        return resolve_fragment(components, fragment) if fragment else components
    else:
        return custom_loader_general(uri, base_uri)

# Custom loader for handling statement-specific URIs and delegating component URIs
# to the custom_loader_for_components. Returns a dictionary representing the reference
# for placeholders or the resolved JSON for component URIs.

def custom_loader_for_components(uri, base_uri=None, **kwargs):
    if uri.startswith("urn:components"):
        components_url = 'https://raw.githubusercontent.com/openownership/data-standard/main/schema/components.json'
        components = load_json(components_url)
        fragment = uri.partition('#')[2] if '#' in uri else ''
        return resolve_fragment(components, fragment) if fragment else components
    else:
        return custom_loader_general(uri, base_uri)

# %%
# process_schema
# Purpose: Loads and processes a JSON schema using a specified loader function 
# to handle `$ref` references.
# How It Works: This function utilizes jsonref.JsonRef.replace_refs() to process 
# the JSON schema, replacing `$ref` references using the provided custom loader.

def process_schema(file_url, loader):
    base_uri = "file://" + file_url if not file_url.startswith(("http:", "https:")) else file_url
    schema = jsonref.JsonRef.replace_refs(load_json(file_url), loader=loader, base_uri=base_uri)
    return schema

# find_and_remove_unused_defs
# Purpose: Cleans the schema by removing unused definitions within the `$defs` section 
# of a JSON schema.
# How It Works: Iterates through definitions in `$defs` and checks if they are referenced 
# anywhere in the schema. If a definition is not referenced, it is removed.

def find_and_remove_unused_defs(schema):
    schema_str = json.dumps(schema, default=str)
    definitions = list(schema.get('$defs', {}).keys())
    for def_key in definitions:
        ref_string = f'"$ref": "#/$defs/{def_key}"'
        if ref_string not in schema_str:
            del schema['$defs'][def_key]
    if not schema['$defs']:
        del schema['$defs']
    return schema

# %%
# flatten_properties
# Purpose: Recursively extracts properties from the JSON schema and flattens them into a list of dictionaries, suitable for conversion into a tabular format.
# How It Works: Handles nested properties and arrays by recursively calling itself, collecting properties' details such as path, title, type, description, and whether they are required.

def flatten_properties(properties, required_fields=None, path='', parent_required=None):
    items = []
    if required_fields is None:
        required_fields = parent_required if parent_required else []

    for key, value in properties.items():
        full_path = f"{path}/{key}" if path else key
        if isinstance(value, dict):
            is_required = 'Yes' if key in required_fields else 'No'
            property_details = {
                'Property Path': full_path,
                'Title': value.get('title', ''),
                'Description': value.get('description', ''),
                'Type': value.get('type', ''),
                'Required': is_required
            }
            if 'properties' in value:
                items.extend(flatten_properties(value['properties'], value.get('required', []), full_path))
            if 'items' in value and isinstance(value['items'], dict):
                items.extend(flatten_properties({'item': value['items']}, [], f"{full_path}/item", value.get('required', [])))
            if 'enum' in value:
                property_details['Enum'] = ', '.join(str(e) for e in value['enum'])
            items.append(property_details)
        elif isinstance(value, list):
            # Handle cases where value is a list of properties
            for item in value:
                if isinstance(item, dict):
                    items.extend(flatten_properties(item, required_fields, full_path, parent_required))
        else:
            print(f"Skipping {key}: expected a dict but got {type(value).__name__}")

    return items

# schema_to_dataframe
# Purpose: Converts the list of dictionaries (flattened schema properties) into a pandas DataFrame.
# How It Works: This function takes the output from flatten_properties and uses it to create a DataFrame. This DataFrame then provides a structured and easy-to-analyze view of the schema properties.

def schema_to_dataframe(schema):
    if 'properties' in schema:
        properties = schema['properties']
        required = schema.get('required', [])
    elif 'items' in schema and isinstance(schema['items'], dict):
        # New handling for schemas where properties are defined under 'items'
        if '$ref' in schema['items']:
            ref_path = schema['items']['$ref'].strip('#/').split('/')
            properties = schema
            for part in ref_path:
                properties = properties.get(part, {})
            properties = properties.get('properties', {})
            required = properties.get('required', [])
        else:
            properties = schema['items'].get('properties', {})
            required = schema['items'].get('required', [])
    else:
        properties = {}
        required = []

    if properties:
        flattened_data = flatten_properties(properties, required)
    else:
        flattened_data = []
        print("No properties to flatten.")
    return pd.DataFrame(flattened_data)

# %%
# Load, process, and display a JSON schema from a specified file URL.
# Takes the file path or URL of the JSON schema and returns a dataframe with the flattened schema

def display_schema_from_url(file_url, loader_function):
    try:
        schema = process_schema(file_url, loader_function)
        df = schema_to_dataframe(schema)
        return df
    except Exception as e:
        print(f"Failed to process schema: {str(e)}")
        return pd.DataFrame()

# %%
# Link to the JSON schema and specify the custom loader for components
schema_url = 'https://raw.githubusercontent.com/openownership/data-standard/main/schema/relationship-record.json'
custom_loader = custom_loader_for_components

# Use the display_schema_from_url function to process and display the schema
df_relationship = display_schema_from_url(schema_url, custom_loader)
df_relationship
# Out:
#                                        Property Path  \
# 0                                        isComponent
# 1                         componentRecords/item/item
# 2                                   componentRecords
# 3                                            subject
# 4                                    interestedParty
# 5                           interests/item/item/type
# 6               interests/item/item/directOrIndirect
# 7   interests/item/item/beneficialOwnershipOrControl
# 8                        interests/item/item/details
# 9                    interests/item/item/share/exact
# 10                 interests/item/item/share/maximum
# 11                 interests/item/item/share/minimum
# 12        interests/item/item/share/exclusiveMinimum
# 13        interests/item/item/share/exclusiveMaximum
# 14                         interests/item/item/share
# 15                     interests/item/item/startDate
# 16                       interests/item/item/endDate
# 17                               interests/item/item
# 18                                         interests
#
#                               Title  \
# 0                      Is component
# 1
# 2              Component Record IDs
# 3                           Subject
# 4                  Interested Party
# 5                  Type of Interest
# 6                Direct or Indirect
# 7   Beneficial Ownership or Control
# 8                           Details
# 9                  Exact percentage
# 10               Maximum Percentage
# 11               Minimum Percentage
# 12     Exclusive Minimum percentage
# 13     Exclusive Maximum Percentage
# 14                 Percentage Share
# 15                       Start Date
# 16                         End Date
# 17                         Interest
# 18                        Interests
#
#                                           Description     Type Required  \
# 0   Whether this relationship is a component of a ...  boolean      Yes
# 1                                                       string       No
# 2   The `recordId` values of all component records...    array       No
# 3   The `recordId` for the subject of the relation...               Yes
# 4   The `recordId` for the interested party in the...               Yes
# 5   The nature of the interest, using the interest...   string       No
# 6   How directly the interest is exercised by the ...   string       No
# 7   Whether this interest (alone or with others) m...  boolean       No
# 8   The local name given to this kind of interest,...   string       No
# 9   The exact share of this interest held (if avai...   number       No
# 10  The inclusive upper bound of the share of this...   number       No
# 11  The inclusive lower bound of the share of this...   number       No
# 12  The exclusive lower bound of the share of this...   number       No
# 13  The exclusive upper bound of the share of this...   number       No
# 14  The proportion of this type of interest held b...   object       No
# 15  The date from which this interest was active. ...   string       No
# 16  The date from which this interest ceased to ex...   string       No
# 17  A description of an interest held by an intere...   object       No
# 18  A description of the interests held by the int...    array       No
#
#                                                  Enum
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   shareholding, votingRights, appointmentOfBoard...
# 6                           direct, indirect, unknown
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN

# %%
# Link to the JSON schema and specify the custom loader for components
schema_url = 'https://raw.githubusercontent.com/openownership/data-standard/main/schema/entity-record.json'
custom_loader = custom_loader_for_components

# Use the display_schema_from_url function to process and display the schema
df_entity = display_schema_from_url(schema_url, custom_loader)
df_entity
# Out:
#                                         Property Path  \
# 0                                         isComponent
# 1                                     entityType/type
# 2                                  entityType/subtype
# 3                                  entityType/details
# 4                                          entityType
# 5                     unspecifiedEntityDetails/reason
# 6                unspecifiedEntityDetails/description
# 7                            unspecifiedEntityDetails
# 8                                                name
# 9                            alternateNames/item/item
# 10                                     alternateNames
# 11                                  jurisdiction/name
# 12                                  jurisdiction/code
# 13                                       jurisdiction
# 14                           identifiers/item/item/id
# 15                       identifiers/item/item/scheme
# 16                   identifiers/item/item/schemeName
# 17                          identifiers/item/item/uri
# 18                              identifiers/item/item
# 19                                        identifiers
# 20                                       foundingDate
# 21                                    dissolutionDate
# 22                           addresses/item/item/type
# 23                        addresses/item/item/address
# 24                       addresses/item/item/postCode
# 25                   addresses/item/item/country/name
# 26                   addresses/item/item/country/code
# 27                        addresses/item/item/country
# 28                                addresses/item/item
# 29                                          addresses
# 30                                                uri
# 31                     publicListing/hasPublicListing
# 32         publicListing/companyFilingsURLs/item/item
# 33                   publicListing/companyFilingsURLs
# 34  publicListing/securitiesListings/item/item/mar...
# 35  publicListing/securitiesListings/item/item/ope...
# 36  publicListing/securitiesListings/item/item/sto...
# 37  publicListing/securitiesListings/item/item/sto...
# 38  publicListing/securitiesListings/item/item/sec...
# 39  publicListing/securitiesListings/item/item/sec...
# 40  publicListing/securitiesListings/item/item/sec...
# 41  publicListing/securitiesListings/item/item/sec...
# 42         publicListing/securitiesListings/item/item
# 43                   publicListing/securitiesListings
# 44                                      publicListing
# 45                               formedByStatute/name
# 46                               formedByStatute/date
# 47                                    formedByStatute
#
#                                                Title  \
# 0                                       Is component
# 1                                               Type
# 2                                            Subtype
# 3                                            Details
# 4                                        Entity Type
# 5                                             Reason
# 6                                        Description
# 7            Unspecified or unknown person or entity
# 8                                        Entity Name
# 9                                               Name
# 10                                 Alternative Names
# 11                                              Name
# 12                       Country or Subdivision Code
# 13                                      Jurisdiction
# 14                                                ID
# 15                                       Scheme Code
# 16                                       Scheme Name
# 17                                               URI
# 18                                        Identifier
# 19                                       Identifiers
# 20                                     Founding Date
# 21                                  Dissolution Date
# 22                                              Type
# 23                                           Address
# 24                                          Postcode
# 25                                              Name
# 26                                      Country Code
# 27                                           Country
# 28                                           Address
# 29                                         Addresses
# 30                                               URI
# 31                                Has Public Listing
# 32
# 33                              Company Filings URLs
# 34                      Market Identifier Code (MIC)
# 35  Operating Market Identifier Code (Operating MIC)
# 36                       Stock Exchange Jurisdiction
# 37                               Stock Exchange Name
# 38                                 Identifier Scheme
# 39                                        Identifier
# 40                                      Stock Ticker
# 41                                          Security
# 42                                Securities Listing
# 43                               Securities Listings
# 44                                    Public Listing
# 45                                      Statute Name
# 46                                              Date
# 47                                 Formed by Statute
#
#                                           Description     Type Required  \
# 0   Whether this entity is a component in an indir...  boolean      Yes
# 1   The general form of the entity, using the enti...   string      Yes
# 2   The particular form of the entity, where relev...   string       No
# 3   This may be used to provide a local name for t...   string       No
# 4   The form of the entity described in the Statem...   object      Yes
# 5   The reason that a person or entity cannot be s...   string      Yes
# 6   Additional information about the absence of de...   string       No
# 7                        A `reason` MUST be supplied.   object       No
# 8                   The declared name of this entity.   string       No
# 9                     A name this entity is known by.   string       No
# 10   An array of other names this entity is known by.    array       No
# 11                       The name of the jurisdiction   string      Yes
# 12  The 2-letter country code (ISO 3166-1) or the ...   string       No
# 13  A Jurisdiction MUST have a name. A jurisdictio...   object       No
# 14  The identifier for a person or entity, as issu...   string       No
# 15  For entities, a code from org-id.guide (https:...   string       No
# 16      The name of the identifier-issuing authority.   string       No
# 17  A canonical URI (https://en.wikipedia.org/wiki...   string       No
# 18  An identifier that has been assigned to a pers...   object       No
# 19  One or more official identifiers for this enti...    array       No
# 20  The date on which this entity was founded, cre...   string       No
# 21  The date on which this entity was dissolved or...   string       No
# 22  The function of the address, using the address...   string       No
# 23  The address, with each line or component separ...   string       No
# 24                  The postal code for this address.   string       No
# 25                            The name of the country   string      Yes
# 26  The 2-letter country code (ISO 3166-1) for thi...   string       No
# 27  A country MUST have a name. A country SHOULD h...   object       No
# 28  Semi-structured address details, suitable for ...   object       No
# 29             One or more addresses for this entity.    array       No
# 30  Where a persistent URI (https://en.wikipedia.o...   string       No
# 31   Whether the entity is a publicly listed company.  boolean      Yes
# 32                                                      string       No
# 33  URL or URLs where regulatory filings related t...    array       No
# 34  The Market Identifier Code (MIC) of the market...   string       No
# 35  The Market Identifier Code (MIC) of the main e...   string       No
# 36  The 2-letter country code (ISO 3166-1) or the ...   string      Yes
# 37  The name of the exchange, market or trading pl...   string      Yes
# 38  The scheme under which the security has been i...   string       No
# 39  The unique identifier of the security as issue...   string       No
# 40  The stock ticker identifying this security on ...   string      Yes
# 41  Identifying information of the stock or other ...   object      Yes
# 42  Details of a security and the market on which ...   object       No
# 43  Details of the entity's securities and the pub...    array       No
# 44  Details of a publicly listed company, its secu...   object       No
# 45                              The name of the law.    string       No
# 46  The date on which the law came into force. The...   string       No
# 47  The law which mandated the formation of the en...   object       No
#
#                                                  Enum
# 0                                                 NaN
# 1   registeredEntity, legalEntity, arrangement, an...
# 2   governmentDepartment, stateAgency, other, trus...
# 3                                                 NaN
# 4                                                 NaN
# 5   noBeneficialOwners, subjectUnableToConfirmOrId...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  placeOfBirth, residence, registered, service, ...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                            isin, figi, cusip, cins
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN

# %%
# Link to the JSON schema and specify the custom loader for components
schema_url = 'https://raw.githubusercontent.com/openownership/data-standard/main/schema/statement.json'
custom_loader = custom_loader_statement

# Use the display_schema_from_url function to process and display the schema
df_statement = display_schema_from_url(schema_url, custom_loader)
df_statement
# Out:
#                                    Property Path                       Title  \
# 0                                    statementId        Statement Identifier
# 1                                  statementDate              Statement Date
# 2   annotations/item/item/statementPointerTarget  Statement Fragment Pointer
# 3             annotations/item/item/creationDate               Creation Date
# 4           annotations/item/item/createdBy/name                        Name
# 5            annotations/item/item/createdBy/uri                         URI
# 6                annotations/item/item/createdBy                  Created By
# 7               annotations/item/item/motivation                  Motivation
# 8              annotations/item/item/description                 Description
# 9       annotations/item/item/transformedContent         Transformed Content
# 10                     annotations/item/item/url                         URL
# 11                         annotations/item/item                  Annotation
# 12                                   annotations                 Annotations
# 13            publicationDetails/publicationDate            Publication date
# 14                publicationDetails/bodsVersion                BODS Version
# 15                    publicationDetails/license                 License URL
# 16             publicationDetails/publisher/name                        Name
# 17              publicationDetails/publisher/url                         URL
# 18                  publicationDetails/publisher                   Publisher
# 19                            publicationDetails         Publication Details
# 20                         source/type/item/item
# 21                                   source/type                 Source Type
# 22                            source/description                 Description
# 23                                    source/url                  Source URL
# 24                            source/retrievedAt                Retrieved At
# 25              source/assertedBy/item/item/name                        Name
# 26               source/assertedBy/item/item/uri                         URI
# 27                   source/assertedBy/item/item
# 28                             source/assertedBy                 Asserted By
# 29                                        source                      Source
# 30                                   declaration       Declaration Reference
# 31                            declarationSubject         Declaration Subject
# 32                                      recordId           Record Identifier
# 33                                    recordType                 Record Type
# 34                                  recordStatus               Record Status
# 35                                 recordDetails              Record Details
#
#                                           Description    Type Required  \
# 0   A persistent globally unique identifier for th...  string      Yes
# 1   The date on which this statement was declared ...  string      Yes
# 2   An RFC6901 JSON Pointer (https://tools.ietf.or...  string       No
# 3   The date on which this Annotation was created,...  string       No
# 4   The name of the person, organisation or agent ...  string       No
# 5   An optional URI to identify the person, organi...  string       No
# 6   The person, organisation or agent that created...  object       No
# 7   The reason for this Annotation, using the anno...  string       No
# 8   A free text description providing extra inform...  string       No
# 9   A representation of the Annotation target afte...  string       No
# 10  A linked resource that annotates, provides con...  string       No
# 11  Additional information about the data containe...  object       No
# 12  Annotations about this Statement or parts of t...   array       No
# 13  The date on which this statement was published...  string      Yes
# 14  The version of the Beneficial Ownership Data S...  string      Yes
# 15  A link to the license that applies to this Sta...  string       No
# 16                         The name of the publisher.  string       No
# 17  The URL where details of the full dataset, or ...  string       No
# 18  Details of the organisation or person publishi...  object      Yes
# 19  Information concerning the publication of this...  object       No
# 20                                                     string       No
# 21  The types of the source, using the sourceType ...   array       No
# 22  Additional, free text information about the so...  string       No
# 23  The external URL from which this information w...  string       No
# 24  A timestamp indicating when this information w...  string       No
# 25         The name of the agent making the assertion  string       No
# 26  An optional URI to identify the agent making t...  string       No
# 27                                                     object       No
# 28  The people or organisations providing the info...   array       No
# 29          Details describing an information source.  object       No
# 30  An identifier or reference for a declaration w...  string       No
# 31  A `recordId` value for the subject of a benefi...  string      Yes
# 32  A unique identifier for the record (within the...  string      Yes
# 33  The type of record (within the publisher's sys...  string      Yes
# 34  The lifecycle status of the record (within the...  string       No
# 35  The details of the entity, person or relations...  object      Yes
#
#                                                  Enum
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   commenting, correcting, identifying, linking, ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  selfDeclaration, officialRegister, thirdParty,...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                       entity, person, relationship
# 34                               new, updated, closed
# 35                                                NaN

# %%
df_statement['Source'] = 'Statement'
df_entity['Source'] = 'Entity'
df_relationship['Source'] = 'Relationship'

df_final = pd.concat([df_statement, df_entity, df_relationship], ignore_index=True)

display(df_final)
# Out:
#                                     Property Path                       Title  \
# 0                                     statementId        Statement Identifier
# 1                                   statementDate              Statement Date
# 2    annotations/item/item/statementPointerTarget  Statement Fragment Pointer
# 3              annotations/item/item/creationDate               Creation Date
# 4            annotations/item/item/createdBy/name                        Name
# ..                                            ...                         ...
# 98                      interests/item/item/share            Percentage Share
# 99                  interests/item/item/startDate                  Start Date
# 100                   interests/item/item/endDate                    End Date
# 101                           interests/item/item                    Interest
# 102                                     interests                   Interests
#
#                                            Description    Type Required Enum  \
# 0    A persistent globally unique identifier for th...  string      Yes  NaN
# 1    The date on which this statement was declared ...  string      Yes  NaN
# 2    An RFC6901 JSON Pointer (https://tools.ietf.or...  string       No  NaN
# 3    The date on which this Annotation was created,...  string       No  NaN
# 4    The name of the person, organisation or agent ...  string       No  NaN
# ..                                                 ...     ...      ...  ...
# 98   The proportion of this type of interest held b...  object       No  NaN
# 99   The date from which this interest was active. ...  string       No  NaN
# 100  The date from which this interest ceased to ex...  string       No  NaN
# 101  A description of an interest held by an intere...  object       No  NaN
# 102  A description of the interests held by the int...   array       No  NaN
#
#            Source
# 0       Statement
# 1       Statement
# 2       Statement
# 3       Statement
# 4       Statement
# ..            ...
# 98   Relationship
# 99   Relationship
# 100  Relationship
# 101  Relationship
# 102  Relationship
#
# [103 rows x 7 columns]

# %%
df_final.to_csv('mapping.csv',index=False)
