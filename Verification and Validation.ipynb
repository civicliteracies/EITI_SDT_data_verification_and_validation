# %% [markdown]
# # EITI consolidated Summary Data files verification and validation
#
# ## Purpose
# The purpose of this notebook is to verify assumptions that should hold true due to the nature of EITI's data and validate the usefulness of the data for different use-cases or business goals.
#
# ## Findings
# 1. There are a number of formatting errors and mistakes in the summary data files, such as:
#     - Spelling mistakes
#     - Using placeholder values
#     - White spaces around the texts
# 2. There is a lot of duplication in the summary data files, such as:
#     - Duplicate listings of companies/agencies in the same year (Part 3 - Reporting companies' list & Part 3 - Reporting government entities list)
#         - possible reason/s:
#            - listing the same company/agency for different commodities
#     - Duplicate project names in the same country and year (Part 3 - Reporting projects list)
#         - possible reason/s:
#             - no project name is given or a placeholder is used
#             - same project names for different commodity values but no commodity value is provided
#     - Duplicate company/agency ids in the same country and year (Part 3 - Reporting companies' list & Part 3 - Reporting government entities list)
#         - possible reason/s:
#             - a majority of the duplication is due to the information not being available or not existing in the dataset (N/A, NC, etc.)
#     - Duplicate company-project and commodity pairs in the same year and country
#         - possible reason/s:
#             - information on commodities are not reported nor available
# 3. There are inconsistencies in the list of projects, companies, and agencies, such as:
#     - There are companies and agencies listed in Part 5 - Company data that are not in Part 3 - Reporting companies' list
#         - possible reasons/s:
#             - mistakes in spelling the name of the same entity
#                 - Royal Dutch Shell PLC VS Royal Dutch Shell plc
#                 - Afghan Shiinink, Mines Extraction and Processing VS Afghan Shinink, Mines Extraction and Processing
#             - companies not being listed in the Reporting companies' list
#     - Company IDs for the same company changes over time
#         - possible reason/s:
#             - typographical errors
#             - reporting change (from Not communicated to Not available, etc.)
#             - actual change in the ID
#     - Not all reported government entities appear in both the Government revenues (Part 4) and the Reporting government entities list
#         - possible reason/s
#             - NaN or NULL values or entity names not being provided correctly
#
# ## Data
# 1. Consolidated summary data files of all countries and years divided into individual sheets (datasets).
#    - [Part 1 - About](data/consolidated/Part%201%20-%20About.csv)
#    - [Part 3 - Reporting companies' list](data/consolidated/Part%203%20-%20Reporting%20companies'%20list.csv)
#    - [Part 3 - Reporting government entities list](data/consolidated/Part%203%20-%20Reporting%20government%20entities%20list.csv)
#    - [Part 3 - Reporting projects' list](data/consolidated/Part%203%20-%20Reporting%20projects'%20list.csv)
#    - [Part 4 - Government revenues](data/consolidated/Part%204%20-%20Government%20revenues.csv)
#    - [Part 5 - Company data](data/consolidated/Part%205%20-%20Company%20data.csv)
#
# ## Methodology
# 1. [Import the libraries](#Import-Libraries)
# 2. [Import/load the data](#Import-the-data)
# 3. Verify the assumptions
# 4. Validate use-cases
# 5. Perform analysis and show simple statistics/visualizations about the data
#
# ## Assumptions to verify
# 1. [**COMPLETENESS AND CORRECTNESS**](#Completeness-and-Correctness)
#     1. [Cell values are complete and/or correct (i.e. no unexpected or incorrect values)](#No-duplicate-company/agency-names-in-the-same-year-and-country)
# 2. [**UNIQUENESS AND NON-DUPLICATION**](#Uniqueness-and-Non-duplication)
#     1. [No duplicate company/agency names in the same year and country](#No-duplicate-company/agency-names-in-the-same-year-and-country)
#     2. [No duplicate project names for the same commodity in the same year and country](#No-duplicate-project-names-for-the-same-commodity-in-the-same-year-and-country)
#     3. [No duplicate company/agency IDs in the same year and country](#No-duplicate-company-ids-in-the-same-year-and-country)
#     4. [No duplicate company-project pair in the same year and country](#No-duplicate-company-project-pair-in-the-same-year-and-country)
# 3. [**CONSISTENCY**](#Consistency)
#     1. [All companies or agencies in company data (Part 5) exist in the Reporting companies' agencies list (Part 3a)](#All-companies-or-agencies-in-company-data-(Part-5)-exist-in-the-Reporting-companies'-agencies-list-(Part-3a))
#     2. [Consistent company name-company ID pair over time](#Consistent-company-name-company-ID-pair-over-time)
#     3. [Government entities that appear in the Government revenues (Part 4) must also appear in the Reporting government entities list (Part 3b)](#Government-entities-that-appear-in-the-Government-revenues-(Part-4)-must-also-appear-in-the-Reporting-government-entities-list-(Part-3b))
#     4. Companies that appear as affiliated companies in Reporting projects list (Part 3c) should also appear in the Company data (Part 5)
#
# ## Use-cases to validate (examples)
# 1. [How has the extractives industry evolved over time in country X? How much is the volume extracted over time? How much revenue is generated?](#How-has-the-extractives-industry-evolved-over-time-in-country-X?-How-much-is-the-volume-extracted-over-time?-How-much-revenue-is-generated?)
# 2. How much taxes are paid by SOEs (SOE = state-owned enterprises company type) for each country? How much is this compared to private companies?
# 3. What percentage of the market share do SOEs take in each country? Based on volume extracted? Based on revenue? Based on taxes paid?
#
# Add more use-cases. A use case should demonstrate if a reuser, coming with a specific question relevant to a real life need, can answer that question in the data.
#
# ## Statistics and graphs
# 1. [How many years of data does each country have?](#How-many-years-of-data-does-each-country-have?)

# %% [markdown]
# ### Import Libraries

# %%
# import libraries

import pandas as pd
from os import path

# %% [markdown]
# ### Import the data

# %%
file_dir = "data/consolidated/"

# load the csvs into data frames
df_part_1 = pd.read_csv(path.join(file_dir, "Part 1 - About.csv"))
df_part_3a = pd.read_csv(path.join(file_dir, "Part 3 - Reporting companies' list.csv"))
df_part_3b = pd.read_csv(path.join(file_dir, "Part 3 - Reporting government entities list.csv"))
df_part_3c = pd.read_csv(path.join(file_dir, "Part 3 - Reporting projects' list.csv"))
df_part_4 = pd.read_csv(path.join(file_dir, "Part 4 - Government revenues.csv"))
# df_part_5 = pd.read_csv(path.join(file_dir, "Part 5 - Company data.csv")) # results in warning about columns having mixed types
df_part_5 = pd.read_csv(path.join(file_dir, "Part 5 - Company data.csv"), low_memory=False)

df_list = [df_part_1, df_part_3a, df_part_3b, df_part_3c, df_part_4, df_part_5]
df_dict = {"Part 1 - About.csv": df_part_1,
           "Part 3 - Reporting companies' list.csv": df_part_3a,
           "Part 3 - Reporting government entities list.csv": df_part_3b,
           "Part 3 - Reporting projects' list.csv": df_part_3c,
           "Part 4 - Government revenues.csv": df_part_4,
           "Part 5 - Company data.csv": df_part_5
          }

# %%
# Checking mixed type columns
mixed_type_columns = df_part_5.map(type).nunique() > 1

# Print or display the columns with mixed types
print("Columns with mixed types:")
print(mixed_type_columns[mixed_type_columns].index.tolist())
# Out:
# Columns with mixed types:
# ['Company', 'Government entity', 'Revenue stream name', 'Levied on project (Y/N)', 'Reported by project (Y/N)', 'Project name', 'Reporting currency', 'Payment made in-kind (Y/N)', 'In-kind volume (if applicable)', 'Unit (if applicable)', 'Comments', 'Country', 'ISO Code', 'Start Date', 'End Date']

# %% [markdown]
# ## Assumptions to verify

# %% [markdown]
# ### Completeness and Correctness
#
# It is assumed that the data received are complete and correct. In this section, we check for any unexpected or unexpected values in the tables such as instances of 'no data', 'NULL', or 'NaN'.

# %% [markdown]
# #### Expectations
# - We expect that the data is complete and correct.
# - There are no 'no data', 'NULL', or 'NaN' values in the dataframes
#
# #### Assumptions
# - The dataset is assumed to have undergone rigorous data validation checks to identify and address any missing or erroneous values.
# - Data entry procedures have been consistently followed, minimizing the likelihood of unexpected or incorrect values.
# - Cell values are expected to fall within valid and meaningful ranges.

# %% [markdown]
# #### Results

# %%
# Functions to find and count NULL and #ERROR! values

def columns_with_null(df):
    return df.columns[df.isnull().any()]

def count_null_per_column(df):
    return df.isnull().sum()    

def columns_with_error(df):
    return df.columns[df.eq('#ERROR!').any()]

def count_error_per_column(df):
    return df.apply(lambda col: (col == '#ERROR!').sum())

def columns_with_empty_strings(df):
    return df.columns[df.eq('').any()]

def count_empty_strings_per_column(df):
    return df.apply(lambda col: (col == '').sum())

def columns_with_only_space(df):
    return df.columns[df.map(lambda cell: isinstance(cell, str) and cell.isspace()).any()]

def count_only_space_per_column(df):
    return df.map(lambda cell: str(cell).isspace()).sum()

# %% [markdown]
# **The results below show that there are columns in the data that has NULL**

# %%
for tab in df_dict:
    print("Columns with NULL values for {}:".format(tab))
    for column in columns_with_null(df_dict[tab]):
        print("- {}".format(column))
        
    print("\nNumber of columns with NULL: {}/{}".format(len(columns_with_null(df_dict[tab])), df_dict[tab].shape[1]))
    print("\nNumber of NULL per column:")
    print(count_null_per_column(df_dict[tab]))
    print("\nTotal number of rows/observations: {}".format(df_dict[tab].shape[0]))
    print("\n------\n")
# Out:
# Columns with NULL values for Part 1 - About.csv:
# - ISO Alpha-3 Code
# - National currency name
# - National currency ISO-4217
# - Start Date
# - End Date
# - Has an EITI Report been prepared by an Independent Administrator?
# - What is the name of the company?
# - Date that the EITI Report was made public
# - URL, EITI Report
# - Does the government systematically disclose EITI data at a single location?
# - Publication date of the EITI data
# - Website link (URL) to EITI data
# - Are there other files of relevance?
# - Date that other file was made public
# - URL
# - Does the government have an open data policy?
# - Open data portal / files
# - Oil
# - Gas
# - Mining (incl. Quarrying)
# - Other, non-upstream sectors
# - If yes, please specify name (insert new rows if multiple)
# - Number of reporting government entities (incl SOEs if recipient)
# - Number of reporting companies (incl SOEs if payer)
# - Reporting currency (ISO-4217 currency codes)
# - Exchange rate used: 1 USD =
# - Exchange rate source (URL,…)
# - … by revenue stream
# - … by government agency
# - … by company
# - … by project
# - Systematically disclosed
# - Through EITI Reporting
# - Not applicable
# - Not available
# - Name
# - Organisation
# - Email address
#
# Number of columns with NULL: 38/39
#
# Number of NULL per column:
# Country or area name                                                            0
# ISO Alpha-3 Code                                                                6
# National currency name                                                          6
# National currency ISO-4217                                                      6
# Start Date                                                                      1
# End Date                                                                        1
# Has an EITI Report been prepared by an Independent Administrator?               6
# What is the name of the company?                                                6
# Date that the EITI Report was made public                                       7
# URL, EITI Report                                                               11
# Does the government systematically disclose EITI data at a single location?     1
# Publication date of the EITI data                                              36
# Website link (URL) to EITI data                                                32
# Are there other files of relevance?                                             2
# Date that other file was made public                                           50
# URL                                                                            42
# Does the government have an open data policy?                                   4
# Open data portal / files                                                       14
# Oil                                                                             3
# Gas                                                                             2
# Mining (incl. Quarrying)                                                        1
# Other, non-upstream sectors                                                     1
# If yes, please specify name (insert new rows if multiple)                      36
# Number of reporting government entities (incl SOEs if recipient)                4
# Number of reporting companies (incl SOEs if payer)                              1
# Reporting currency (ISO-4217 currency codes)                                    1
# Exchange rate used: 1 USD =                                                     1
# Exchange rate source (URL,…)                                                    7
# … by revenue stream                                                             1
# … by government agency                                                          1
# … by company                                                                    1
# … by project                                                                    1
# Systematically disclosed                                                        1
# Through EITI Reporting                                                          1
# Not applicable                                                                  1
# Not available                                                                   1
# Name                                                                            4
# Organisation                                                                    3
# Email address                                                                   3
# dtype: int64
#
# Total number of rows/observations: 75
#
# ------
#
# Columns with NULL values for Part 3 - Reporting companies' list.csv:
# - Company type
# - Company ID number
# - Commodities (comma-seperated)
# - Stock exchange listing or company website
# - Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)
# - Payments to Governments Report
#
# Number of columns with NULL: 6/13
#
# Number of NULL per column:
# Full company name                                                                                      0
# Company type                                                                                         355
# Company ID number                                                                                    187
# Sector                                                                                                 0
# Commodities (comma-seperated)                                                                        461
# Stock exchange listing or company website                                                           2019
# Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)    2196
# Payments to Governments Report                                                                       260
# Country                                                                                                0
# ISO Code                                                                                               0
# Year                                                                                                   0
# Start Date                                                                                             0
# End Date                                                                                               0
# dtype: int64
#
# Total number of rows/observations: 3834
#
# ------
#
# Columns with NULL values for Part 3 - Reporting government entities list.csv:
# - Agency type
# - ID number (if applicable)
# - Total reported
# - Year
#
# Number of columns with NULL: 4/9
#
# Number of NULL per column:
# Full name of agency            0
# Agency type                    1
# ID number (if applicable)    337
# Total reported                73
# Country                        0
# ISO Code                       0
# Year                           9
# Start Date                     0
# End Date                       0
# dtype: int64
#
# Total number of rows/observations: 549
#
# ------
#
# Columns with NULL values for Part 3 - Reporting projects' list.csv:
# - Full project name
# - Legal agreement reference number(s): contract, licence, lease, concession, …
# - Affiliated companies, start with Operator
# - Commodities (one commodity/row)
# - Status
# - Production (volume)
# - Unit
# - Production (value)
# - Currency
# - Country
# - ISO Code
# - Year
# - Start Date
# - End Date
#
# Number of columns with NULL: 14/14
#
# Number of NULL per column:
# Full project name                                                                 23
# Legal agreement reference number(s): contract, licence, lease, concession, …     257
# Affiliated companies, start with Operator                                        169
# Commodities (one commodity/row)                                                  414
# Status                                                                           421
# Production (volume)                                                             1785
# Unit                                                                            3408
# Production (value)                                                              5473
# Currency                                                                        4594
# Country                                                                           21
# ISO Code                                                                          21
# Year                                                                              21
# Start Date                                                                        21
# End Date                                                                          21
# dtype: int64
#
# Total number of rows/observations: 6280
#
# ------
#
# Columns with NULL values for Part 4 - Government revenues.csv:
# - Sector
# - Revenue stream name
# - Government entity
# - Revenue value
# - Currency
#
# Number of columns with NULL: 5/11
#
# Number of NULL per column:
# GFS Classification       0
# Sector                  28
# Revenue stream name      2
# Government entity        2
# Revenue value          324
# Currency                 2
# Country                  0
# ISO Code                 0
# Year                     0
# Start Date               0
# End Date                 0
# dtype: int64
#
# Total number of rows/observations: 2307
#
# ------
#
# Columns with NULL values for Part 5 - Company data.csv:
# - Company
# - Government entity
# - Revenue stream name
# - Levied on project (Y/N)
# - Reported by project (Y/N)
# - Project name
# - Reporting currency
# - Revenue value
# - Payment made in-kind (Y/N)
# - In-kind volume (if applicable)
# - Unit (if applicable)
# - Comments
# - Country
# - ISO Code
# - Year
# - Start Date
# - End Date
#
# Number of columns with NULL: 17/17
#
# Number of NULL per column:
# Company                              28
# Government entity                    34
# Revenue stream name                  35
# Levied on project (Y/N)             203
# Reported by project (Y/N)           185
# Project name                      21034
# Reporting currency                   31
# Revenue value                      6610
# Payment made in-kind (Y/N)         7042
# In-kind volume (if applicable)    19516
# Unit (if applicable)              21680
# Comments                          28780
# Country                              71
# ISO Code                             71
# Year                                100
# Start Date                           71
# End Date                             71
# dtype: int64
#
# Total number of rows/observations: 33044
#
# ------

# %% [markdown]
# **The results below show that there are columns in the data that has '#ERROR!'**

# %%
for tab in df_dict:
    print("Columns with '#ERROR!' values for {}:".format(tab))
    for column in columns_with_error(df_dict[tab]):
        print("- {}".format(column))
        
    print("\nNumber of columns with '#ERROR!': {}/{}".format(len(columns_with_error(df_dict[tab])), df_dict[tab].shape[1]))
    print("\nNumber of '#ERROR!' per column:")
    print(count_error_per_column(df_dict[tab]))
    print("\nTotal number of rows/observations: {}".format(df_dict[tab].shape[0]))
    print("\n------\n")
# Out:
# Columns with '#ERROR!' values for Part 1 - About.csv:
# - ISO Alpha-3 Code
# - National currency name
# - National currency ISO-4217
#
# Number of columns with '#ERROR!': 3/39
#
# Number of '#ERROR!' per column:
# Country or area name                                                            0
# ISO Alpha-3 Code                                                               20
# National currency name                                                         20
# National currency ISO-4217                                                     19
# Start Date                                                                      0
# End Date                                                                        0
# Has an EITI Report been prepared by an Independent Administrator?               0
# What is the name of the company?                                                0
# Date that the EITI Report was made public                                       0
# URL, EITI Report                                                                0
# Does the government systematically disclose EITI data at a single location?     0
# Publication date of the EITI data                                               0
# Website link (URL) to EITI data                                                 0
# Are there other files of relevance?                                             0
# Date that other file was made public                                            0
# URL                                                                             0
# Does the government have an open data policy?                                   0
# Open data portal / files                                                        0
# Oil                                                                             0
# Gas                                                                             0
# Mining (incl. Quarrying)                                                        0
# Other, non-upstream sectors                                                     0
# If yes, please specify name (insert new rows if multiple)                       0
# Number of reporting government entities (incl SOEs if recipient)                0
# Number of reporting companies (incl SOEs if payer)                              0
# Reporting currency (ISO-4217 currency codes)                                    0
# Exchange rate used: 1 USD =                                                     0
# Exchange rate source (URL,…)                                                    0
# … by revenue stream                                                             0
# … by government agency                                                          0
# … by company                                                                    0
# … by project                                                                    0
# Systematically disclosed                                                        0
# Through EITI Reporting                                                          0
# Not applicable                                                                  0
# Not available                                                                   0
# Name                                                                            0
# Organisation                                                                    0
# Email address                                                                   0
# dtype: int64
#
# Total number of rows/observations: 75
#
# ------
#
# Columns with '#ERROR!' values for Part 3 - Reporting companies' list.csv:
# - Payments to Governments Report
#
# Number of columns with '#ERROR!': 1/13
#
# Number of '#ERROR!' per column:
# Full company name                                                                                     0
# Company type                                                                                          0
# Company ID number                                                                                     0
# Sector                                                                                                0
# Commodities (comma-seperated)                                                                         0
# Stock exchange listing or company website                                                             0
# Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)      0
# Payments to Governments Report                                                                      993
# Country                                                                                               0
# ISO Code                                                                                              0
# Year                                                                                                  0
# Start Date                                                                                            0
# End Date                                                                                              0
# dtype: int64
#
# Total number of rows/observations: 3834
#
# ------
#
# Columns with '#ERROR!' values for Part 3 - Reporting government entities list.csv:
# - Total reported
#
# Number of columns with '#ERROR!': 1/9
#
# Number of '#ERROR!' per column:
# Full name of agency            0
# Agency type                    0
# ID number (if applicable)      0
# Total reported               137
# Country                        0
# ISO Code                       0
# Year                           0
# Start Date                     0
# End Date                       0
# dtype: int64
#
# Total number of rows/observations: 549
#
# ------
#
# Columns with '#ERROR!' values for Part 3 - Reporting projects' list.csv:
# - Production (value)
#
# Number of columns with '#ERROR!': 1/14
#
# Number of '#ERROR!' per column:
# Full project name                                                                 0
# Legal agreement reference number(s): contract, licence, lease, concession, …      0
# Affiliated companies, start with Operator                                         0
# Commodities (one commodity/row)                                                   0
# Status                                                                            0
# Production (volume)                                                               0
# Unit                                                                              0
# Production (value)                                                              117
# Currency                                                                          0
# Country                                                                           0
# ISO Code                                                                          0
# Year                                                                              0
# Start Date                                                                        0
# End Date                                                                          0
# dtype: int64
#
# Total number of rows/observations: 6280
#
# ------
#
# Columns with '#ERROR!' values for Part 4 - Government revenues.csv:
#
# Number of columns with '#ERROR!': 0/11
#
# Number of '#ERROR!' per column:
# GFS Classification     0
# Sector                 0
# Revenue stream name    0
# Government entity      0
# Revenue value          0
# Currency               0
# Country                0
# ISO Code               0
# Year                   0
# Start Date             0
# End Date               0
# dtype: int64
#
# Total number of rows/observations: 2307
#
# ------
#
# Columns with '#ERROR!' values for Part 5 - Company data.csv:
# - Comments
#
# Number of columns with '#ERROR!': 1/17
#
# Number of '#ERROR!' per column:
# Company                            0
# Government entity                  0
# Revenue stream name                0
# Levied on project (Y/N)            0
# Reported by project (Y/N)          0
# Project name                       0
# Reporting currency                 0
# Revenue value                      0
# Payment made in-kind (Y/N)         0
# In-kind volume (if applicable)     0
# Unit (if applicable)               0
# Comments                          44
# Country                            0
# ISO Code                           0
# Year                               0
# Start Date                         0
# End Date                           0
# dtype: int64
#
# Total number of rows/observations: 33044
#
# ------

# %% [markdown]
# **The results below show that there are columns in the data that has empty strings ('')**

# %%
for tab in df_dict:
    print("Columns with '' values for {}:".format(tab))
    for column in columns_with_empty_strings(df_dict[tab]):
        print("- {}".format(column))
        
    print("\nNumber of columns with '': {}/{}".format(len(columns_with_empty_strings(df_dict[tab])), df_dict[tab].shape[1]))
    print("\nNumber of '' per column:")
    print(count_empty_strings_per_column(df_dict[tab]))
    print("\nTotal number of rows/observations: {}".format(df_dict[tab].shape[0]))
    print("\n------\n")
# Out:
# Columns with '' values for Part 1 - About.csv:
#
# Number of columns with '': 0/39
#
# Number of '' per column:
# Country or area name                                                           0
# ISO Alpha-3 Code                                                               0
# National currency name                                                         0
# National currency ISO-4217                                                     0
# Start Date                                                                     0
# End Date                                                                       0
# Has an EITI Report been prepared by an Independent Administrator?              0
# What is the name of the company?                                               0
# Date that the EITI Report was made public                                      0
# URL, EITI Report                                                               0
# Does the government systematically disclose EITI data at a single location?    0
# Publication date of the EITI data                                              0
# Website link (URL) to EITI data                                                0
# Are there other files of relevance?                                            0
# Date that other file was made public                                           0
# URL                                                                            0
# Does the government have an open data policy?                                  0
# Open data portal / files                                                       0
# Oil                                                                            0
# Gas                                                                            0
# Mining (incl. Quarrying)                                                       0
# Other, non-upstream sectors                                                    0
# If yes, please specify name (insert new rows if multiple)                      0
# Number of reporting government entities (incl SOEs if recipient)               0
# Number of reporting companies (incl SOEs if payer)                             0
# Reporting currency (ISO-4217 currency codes)                                   0
# Exchange rate used: 1 USD =                                                    0
# Exchange rate source (URL,…)                                                   0
# … by revenue stream                                                            0
# … by government agency                                                         0
# … by company                                                                   0
# … by project                                                                   0
# Systematically disclosed                                                       0
# Through EITI Reporting                                                         0
# Not applicable                                                                 0
# Not available                                                                  0
# Name                                                                           0
# Organisation                                                                   0
# Email address                                                                  0
# dtype: int64
#
# Total number of rows/observations: 75
#
# ------
#
# Columns with '' values for Part 3 - Reporting companies' list.csv:
#
# Number of columns with '': 0/13
#
# Number of '' per column:
# Full company name                                                                                   0
# Company type                                                                                        0
# Company ID number                                                                                   0
# Sector                                                                                              0
# Commodities (comma-seperated)                                                                       0
# Stock exchange listing or company website                                                           0
# Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)    0
# Payments to Governments Report                                                                      0
# Country                                                                                             0
# ISO Code                                                                                            0
# Year                                                                                                0
# Start Date                                                                                          0
# End Date                                                                                            0
# dtype: int64
#
# Total number of rows/observations: 3834
#
# ------
#
# Columns with '' values for Part 3 - Reporting government entities list.csv:
#
# Number of columns with '': 0/9
#
# Number of '' per column:
# Full name of agency          0
# Agency type                  0
# ID number (if applicable)    0
# Total reported               0
# Country                      0
# ISO Code                     0
# Year                         0
# Start Date                   0
# End Date                     0
# dtype: int64
#
# Total number of rows/observations: 549
#
# ------
#
# Columns with '' values for Part 3 - Reporting projects' list.csv:
#
# Number of columns with '': 0/14
#
# Number of '' per column:
# Full project name                                                               0
# Legal agreement reference number(s): contract, licence, lease, concession, …    0
# Affiliated companies, start with Operator                                       0
# Commodities (one commodity/row)                                                 0
# Status                                                                          0
# Production (volume)                                                             0
# Unit                                                                            0
# Production (value)                                                              0
# Currency                                                                        0
# Country                                                                         0
# ISO Code                                                                        0
# Year                                                                            0
# Start Date                                                                      0
# End Date                                                                        0
# dtype: int64
#
# Total number of rows/observations: 6280
#
# ------
#
# Columns with '' values for Part 4 - Government revenues.csv:
#
# Number of columns with '': 0/11
#
# Number of '' per column:
# GFS Classification     0
# Sector                 0
# Revenue stream name    0
# Government entity      0
# Revenue value          0
# Currency               0
# Country                0
# ISO Code               0
# Year                   0
# Start Date             0
# End Date               0
# dtype: int64
#
# Total number of rows/observations: 2307
#
# ------
#
# Columns with '' values for Part 5 - Company data.csv:
#
# Number of columns with '': 0/17
#
# Number of '' per column:
# Company                           0
# Government entity                 0
# Revenue stream name               0
# Levied on project (Y/N)           0
# Reported by project (Y/N)         0
# Project name                      0
# Reporting currency                0
# Revenue value                     0
# Payment made in-kind (Y/N)        0
# In-kind volume (if applicable)    0
# Unit (if applicable)              0
# Comments                          0
# Country                           0
# ISO Code                          0
# Year                              0
# Start Date                        0
# End Date                          0
# dtype: int64
#
# Total number of rows/observations: 33044
#
# ------

# %% [markdown]
# **The results below show that there are columns in the data that are only white spaces**

# %%
for tab in df_dict:
    print("Columns with only white spaces for {}:".format(tab))
    for column in columns_with_only_space(df_dict[tab]):
        print("- {}".format(column))
        
    print("\nNumber of columns with only white spaces: {}/{}".format(len(columns_with_only_space(df_dict[tab])), df_dict[tab].shape[1]))
    print("\nNumber of only white spaces per column:")
    print(count_only_space_per_column(df_dict[tab]))
    print("\nTotal number of rows/observations: {}".format(df_dict[tab].shape[0]))
    print("\n------\n")
# Out:
# Columns with only white spaces for Part 1 - About.csv:
#
# Number of columns with only white spaces: 0/39
#
# Number of only white spaces per column:
# Country or area name                                                           0
# ISO Alpha-3 Code                                                               0
# National currency name                                                         0
# National currency ISO-4217                                                     0
# Start Date                                                                     0
# End Date                                                                       0
# Has an EITI Report been prepared by an Independent Administrator?              0
# What is the name of the company?                                               0
# Date that the EITI Report was made public                                      0
# URL, EITI Report                                                               0
# Does the government systematically disclose EITI data at a single location?    0
# Publication date of the EITI data                                              0
# Website link (URL) to EITI data                                                0
# Are there other files of relevance?                                            0
# Date that other file was made public                                           0
# URL                                                                            0
# Does the government have an open data policy?                                  0
# Open data portal / files                                                       0
# Oil                                                                            0
# Gas                                                                            0
# Mining (incl. Quarrying)                                                       0
# Other, non-upstream sectors                                                    0
# If yes, please specify name (insert new rows if multiple)                      0
# Number of reporting government entities (incl SOEs if recipient)               0
# Number of reporting companies (incl SOEs if payer)                             0
# Reporting currency (ISO-4217 currency codes)                                   0
# Exchange rate used: 1 USD =                                                    0
# Exchange rate source (URL,…)                                                   0
# … by revenue stream                                                            0
# … by government agency                                                         0
# … by company                                                                   0
# … by project                                                                   0
# Systematically disclosed                                                       0
# Through EITI Reporting                                                         0
# Not applicable                                                                 0
# Not available                                                                  0
# Name                                                                           0
# Organisation                                                                   0
# Email address                                                                  0
# dtype: int64
#
# Total number of rows/observations: 75
#
# ------
#
# Columns with only white spaces for Part 3 - Reporting companies' list.csv:
#
# Number of columns with only white spaces: 0/13
#
# Number of only white spaces per column:
# Full company name                                                                                   0
# Company type                                                                                        0
# Company ID number                                                                                   0
# Sector                                                                                              0
# Commodities (comma-seperated)                                                                       0
# Stock exchange listing or company website                                                           0
# Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)    0
# Payments to Governments Report                                                                      0
# Country                                                                                             0
# ISO Code                                                                                            0
# Year                                                                                                0
# Start Date                                                                                          0
# End Date                                                                                            0
# dtype: int64
#
# Total number of rows/observations: 3834
#
# ------
#
# Columns with only white spaces for Part 3 - Reporting government entities list.csv:
#
# Number of columns with only white spaces: 0/9
#
# Number of only white spaces per column:
# Full name of agency          0
# Agency type                  0
# ID number (if applicable)    0
# Total reported               0
# Country                      0
# ISO Code                     0
# Year                         0
# Start Date                   0
# End Date                     0
# dtype: int64
#
# Total number of rows/observations: 549
#
# ------
#
# Columns with only white spaces for Part 3 - Reporting projects' list.csv:
#
# Number of columns with only white spaces: 0/14
#
# Number of only white spaces per column:
# Full project name                                                               0
# Legal agreement reference number(s): contract, licence, lease, concession, …    0
# Affiliated companies, start with Operator                                       0
# Commodities (one commodity/row)                                                 0
# Status                                                                          0
# Production (volume)                                                             0
# Unit                                                                            0
# Production (value)                                                              0
# Currency                                                                        0
# Country                                                                         0
# ISO Code                                                                        0
# Year                                                                            0
# Start Date                                                                      0
# End Date                                                                        0
# dtype: int64
#
# Total number of rows/observations: 6280
#
# ------
#
# Columns with only white spaces for Part 4 - Government revenues.csv:
#
# Number of columns with only white spaces: 0/11
#
# Number of only white spaces per column:
# GFS Classification     0
# Sector                 0
# Revenue stream name    0
# Government entity      0
# Revenue value          0
# Currency               0
# Country                0
# ISO Code               0
# Year                   0
# Start Date             0
# End Date               0
# dtype: int64
#
# Total number of rows/observations: 2307
#
# ------
#
# Columns with only white spaces for Part 5 - Company data.csv:
#
# Number of columns with only white spaces: 0/17
#
# Number of only white spaces per column:
# Company                           0
# Government entity                 0
# Revenue stream name               0
# Levied on project (Y/N)           0
# Reported by project (Y/N)         0
# Project name                      0
# Reporting currency                0
# Revenue value                     0
# Payment made in-kind (Y/N)        0
# In-kind volume (if applicable)    0
# Unit (if applicable)              0
# Comments                          0
# Country                           0
# ISO Code                          0
# Year                              0
# Start Date                        0
# End Date                          0
# dtype: int64
#
# Total number of rows/observations: 33044
#
# ------

# %% [markdown]
# ### Uniqueness and Non-duplication

# %%
def count_duplicates(main_df, duplicate_df, field, name):
    return main_df[duplicate_df].groupby(field).size().reset_index(name=name)

# %% [markdown]
# ### No duplicate company/agency names in the same year and country
#
# #### Expectations
# - A company or agency name will appear only once per year per country.
# - We expect that within the provided dataset, each combination of a company or agency name in a given year and country is unique.
# - This expectation is grounded in the assumption that the dataset is designed to maintain distinct company or agency identities for a given year and country.
#
# #### Assumptions
# - The company or agency is only reported once per year regardless of sector/commodity
# - Company and agency names are assumed to be uniquely associated with specific entities within a given year and country.
# - Any duplicate entries would be considered as potential data entry errors or inconsistencies.
#
# #### Results

# %%
# def get_duplicate_names(df, field):
#     return df[df.duplicated([field, 'Country', 'Year'], keep=False)].sort_values(by=[field])

def get_duplicates(df, field_to_check, *constraint_fields):
    return df[df.duplicated([field_to_check, *constraint_fields], keep=False)].sort_values(by=[field_to_check])

# %%
df_part_3a[df_part_3a.duplicated(subset=['Country', 'Year', 'Full company name'], keep=False)]
# Out:
#                        Full company name Company type Company ID number  \
# 173               شرکت برادران خالد عزیز      Private        1019984010
# 174               شرکت برادران خالد عزیز      Private        1019984010
# 497   Rio Tuba Nickel Mining Corporation      Private   000-142-665-000
# 519   Rio Tuba Nickel Mining Corporation      Private   000-142-665-000
# 1549          Al Waha Petroleum Co. Ltd.      Private               NaN
# 1552                  CNOOC IRAQ LIMITED      Private               NaN
# 1564                   PT PERTAMINA IRAK      Private               NaN
# 1585          Al Waha Petroleum Co. Ltd.      Private               NaN
# 1586                  CNOOC IRAQ LIMITED      Private               NaN
# 1588                   PT PERTAMINA IRAK      Private               NaN
#
#          Sector Commodities (comma-seperated)  \
# 173       Other                          Coal
# 174       Other                          Coal
# 497      Mining                        Nickel
# 519      Mining                     Limestone
# 1549  Oil & Gas         Oil, Gas, Condensates
# 1552  Oil & Gas         Oil, Gas, Condensates
# 1564  Oil & Gas         Oil, Gas, Condensates
# 1585  Oil & Gas         Oil, Gas, Condensates
# 1586  Oil & Gas         Oil, Gas, Condensates
# 1588  Oil & Gas         Oil, Gas, Condensates
#
#               Stock exchange listing or company website  \
# 173                                      Not applicable
# 174                                      Not applicable
# 497   nickelasia.com/subsidiaries/rio-tuba-nickel-mi...
# 519   nickelasia.com/subsidiaries/rio-tuba-nickel-mi...
# 1549                       https://www.petroalwaha.com/
# 1552  https://cnoocinternational.com/operations/midd...
# 1564                                                NaN
# 1585                                                NaN
# 1586                                                NaN
# 1588                                                NaN
#
#      Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 173                                       Not available
# 174                                       Not available
# 497   nickelasia.com/investor-relations/financial-re...
# 519   nickelasia.com/investor-relations/financial-re...
# 1549                                                NaN
# 1552                                                NaN
# 1564                                                NaN
# 1585                                                NaN
# 1586                                                NaN
# 1588                                                NaN
#
#      Payments to Governments Report      Country ISO Code  Year  Start Date  \
# 173                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 174                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 497                  864,690,546.00  Philippines      PHL  2018  2018-01-01
# 519                             NaN  Philippines      PHL  2018  2018-01-01
# 1549                 628,712,909.00         Iraq      IRQ  2018    1/1/2018
# 1552               1,098,601,809.00         Iraq      IRQ  2018    1/1/2018
# 1564                 990,135,616.00         Iraq      IRQ  2018    1/1/2018
# 1585                 628,712,909.00         Iraq      IRQ  2018    1/1/2018
# 1586               1,098,601,809.00         Iraq      IRQ  2018    1/1/2018
# 1588                 990,135,616.00         Iraq      IRQ  2018    1/1/2018
#
#         End Date
# 173   2018-12-20
# 174   2018-12-20
# 497   2018-12-31
# 519   2018-12-31
# 1549  12/31/2018
# 1552  12/31/2018
# 1564  12/31/2018
# 1585  12/31/2018
# 1586  12/31/2018
# 1588  12/31/2018

# %%
get_duplicates(df_part_3a, 'Full company name', *['Country', 'Year'])
# Out:
#                        Full company name Company type Company ID number  \
# 1549          Al Waha Petroleum Co. Ltd.      Private               NaN
# 1585          Al Waha Petroleum Co. Ltd.      Private               NaN
# 1552                  CNOOC IRAQ LIMITED      Private               NaN
# 1586                  CNOOC IRAQ LIMITED      Private               NaN
# 1564                   PT PERTAMINA IRAK      Private               NaN
# 1588                   PT PERTAMINA IRAK      Private               NaN
# 497   Rio Tuba Nickel Mining Corporation      Private   000-142-665-000
# 519   Rio Tuba Nickel Mining Corporation      Private   000-142-665-000
# 173               شرکت برادران خالد عزیز      Private        1019984010
# 174               شرکت برادران خالد عزیز      Private        1019984010
#
#          Sector Commodities (comma-seperated)  \
# 1549  Oil & Gas         Oil, Gas, Condensates
# 1585  Oil & Gas         Oil, Gas, Condensates
# 1552  Oil & Gas         Oil, Gas, Condensates
# 1586  Oil & Gas         Oil, Gas, Condensates
# 1564  Oil & Gas         Oil, Gas, Condensates
# 1588  Oil & Gas         Oil, Gas, Condensates
# 497      Mining                        Nickel
# 519      Mining                     Limestone
# 173       Other                          Coal
# 174       Other                          Coal
#
#               Stock exchange listing or company website  \
# 1549                       https://www.petroalwaha.com/
# 1585                                                NaN
# 1552  https://cnoocinternational.com/operations/midd...
# 1586                                                NaN
# 1564                                                NaN
# 1588                                                NaN
# 497   nickelasia.com/subsidiaries/rio-tuba-nickel-mi...
# 519   nickelasia.com/subsidiaries/rio-tuba-nickel-mi...
# 173                                      Not applicable
# 174                                      Not applicable
#
#      Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 1549                                                NaN
# 1585                                                NaN
# 1552                                                NaN
# 1586                                                NaN
# 1564                                                NaN
# 1588                                                NaN
# 497   nickelasia.com/investor-relations/financial-re...
# 519   nickelasia.com/investor-relations/financial-re...
# 173                                       Not available
# 174                                       Not available
#
#      Payments to Governments Report      Country ISO Code  Year  Start Date  \
# 1549                 628,712,909.00         Iraq      IRQ  2018    1/1/2018
# 1585                 628,712,909.00         Iraq      IRQ  2018    1/1/2018
# 1552               1,098,601,809.00         Iraq      IRQ  2018    1/1/2018
# 1586               1,098,601,809.00         Iraq      IRQ  2018    1/1/2018
# 1564                 990,135,616.00         Iraq      IRQ  2018    1/1/2018
# 1588                 990,135,616.00         Iraq      IRQ  2018    1/1/2018
# 497                  864,690,546.00  Philippines      PHL  2018  2018-01-01
# 519                             NaN  Philippines      PHL  2018  2018-01-01
# 173                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 174                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
#
#         End Date
# 1549  12/31/2018
# 1585  12/31/2018
# 1552  12/31/2018
# 1586  12/31/2018
# 1564  12/31/2018
# 1588  12/31/2018
# 497   2018-12-31
# 519   2018-12-31
# 173   2018-12-20
# 174   2018-12-20

# %% [markdown]
# #### Results
# - There are duplicate listings of companies in the same year in Iraq and Afghanistan
# - The duplicate listing in the Philippines may be attributed to the difference in commodities

# %%
get_duplicates(df_part_3b, 'Full name of agency', *['Country', 'Year'])
# Out:
#            Full name of agency       Agency type ID number (if applicable)  \
# 238          Mpohor Wassa East  Local government                       NaN
# 252          Mpohor Wassa East  Local government                       NaN
# 247  Obuasi Municipal Assembly  Local government                       NaN
# 259  Obuasi Municipal Assembly  Local government                       NaN
#
#     Total reported Country ISO Code    Year  Start Date    End Date
# 238        #ERROR!   Ghana      GHA  2019.0  2019-01-01  2019-12-31
# 252            NaN   Ghana      GHA  2019.0  2019-01-01  2019-12-31
# 247        #ERROR!   Ghana      GHA  2019.0  2019-01-01  2019-12-31
# 259            NaN   Ghana      GHA  2019.0  2019-01-01  2019-12-31

# %% [markdown]
# #### Results
# - There are duplicate listings of agencies for Ghana in 2019

# %% [markdown]
# ### No duplicate project names for the same commodity in the same year and country
#
# #### Expectations
# - A project name will appear only once per year per country per commodity.
# - Each project name within the dataset is unique for a given year, country, and commodity. This anticipation is based on the assumption that project names are assigned in a manner that avoids duplicates for a given year, country, and commodity.
#
# #### Assumptions
# - A project is only reported once per year and country and commodity
# - Project names are assumed to be distinct identifiers for different projects within the same year, country, and commodity.
# - Duplicate project names within the same year, country, and commodity would be treated as anomalies.
#
# #### Results

# %%
duplicate_projects = get_duplicates(df_part_3c, 
                                    'Full project name', 
                                    *['Country', 'Year', 'Commodities (one commodity/row)', 'Affiliated companies, start with Operator'])

duplicate_projects
# Out:
#                         Full project name  \
# 6082                              2025257
# 6081                              2025257
# 5418  ALKANE ENERGY UK LIMITED (03128509)
# 5995  ALKANE ENERGY UK LIMITED (03128509)
# 5965  ALKANE ENERGY UK LIMITED (03128509)
# ...                                   ...
# 1400                                  NaN
# 1402                                  NaN
# 1404                                  NaN
# 1406                                  NaN
# 1525                                  NaN
#
#      Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 6082                                            Licence
# 6081                                            Licence
# 5418                                               AL10
# 5995                                            PEDL279
# 5965                                            PEDL130
# ...                                                 ...
# 1400                                                NaN
# 1402                                                NaN
# 1404                                                NaN
# 1406                                                NaN
# 1525                                                NaN
#
#      Affiliated companies, start with Operator  \
# 6082                         Breedon Group Plc
# 6081                         Breedon Group Plc
# 5418       ALKANE ENERGY UK LIMITED (03128509)
# 5995       ALKANE ENERGY UK LIMITED (03128509)
# 5965       ALKANE ENERGY UK LIMITED (03128509)
# ...                                        ...
# 1400                                       NaN
# 1402                                       NaN
# 1404                                       NaN
# 1406                                       NaN
# 1525                                       NaN
#
#      Commodities (one commodity/row)          Status Production (volume) Unit  \
# 6082                   Not available  Not applicable      Not applicable  NaN
# 6081                   Not available  Not applicable      Not applicable  NaN
# 5418                   Not available  Not applicable      Not applicable  NaN
# 5995                   Not available  Not applicable      Not applicable  NaN
# 5965                   Not available  Not applicable      Not applicable  NaN
# ...                              ...             ...                 ...  ...
# 1400                             NaN             NaN                 NaN  NaN
# 1402                             NaN             NaN                 NaN  NaN
# 1404                             NaN             NaN                 NaN  NaN
# 1406                             NaN             NaN                 NaN  NaN
# 1525                             NaN             NaN                 NaN  NaN
#
#      Production (value) Currency         Country ISO Code   Year  Start Date  \
# 6082                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 6081                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5418                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5995                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5965                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# ...                 ...      ...             ...       ...   ...         ...
# 1400                NaN      NaN             NaN       NaN   NaN         NaN
# 1402                NaN      NaN             NaN       NaN   NaN         NaN
# 1404                NaN      NaN             NaN       NaN   NaN         NaN
# 1406                NaN      NaN             NaN       NaN   NaN         NaN
# 1525                NaN      NaN             NaN       NaN   NaN         NaN
#
#         End Date
# 6082  2021-12-31
# 6081  2021-12-31
# 5418  2021-12-31
# 5995  2021-12-31
# 5965  2021-12-31
# ...          ...
# 1400         NaN
# 1402         NaN
# 1404         NaN
# 1406         NaN
# 1525         NaN
#
# [610 rows x 14 columns]

# %%
duplicate_project_names = duplicate_projects['Full project name'].unique()

print("Number of duplicate project names: {}\n".format(len(duplicate_project_names.tolist())))

duplicate_projects_count = duplicate_projects.groupby('Full project name').size().reset_index(name='number of times duplicated')
duplicate_projects_count
# Out:
# Number of duplicate project names: 159
#                                      Full project name  \
# 0                                              2025257
# 1                  ALKANE ENERGY UK LIMITED (03128509)
# 2    ALKANE ENERGY UK LIMITED (03128509), EGDON RES...
# 3         ALPHA PETROLEUM RESOURCES LIMITED (03949599)
# 4              ANASURIA HIBISCUS UK LIMITED (09696268)
# ..                                                 ...
# 153             THIRD ENERGY UK GAS LIMITED (01421481)
# 154            TOTALENERGIES E&P UK LIMITED (00811900)
# 155                                             VICTOR
# 156               WINTERSHALL NOORDZEE B.V. (FC027567)
# 157                   Wharf, Rvr Usk nr Caldicot Level
#
#      number of times duplicated
# 0                             2
# 1                             3
# 2                             2
# 3                             2
# 4                             2
# ..                          ...
# 153                           5
# 154                          17
# 155                           2
# 156                           2
# 157                           2
#
# [158 rows x 2 columns]

# %%
duplicate_project_check = duplicate_projects[duplicate_projects['Full project name'] == 'TOTALENERGIES E&P UK LIMITED (00811900)']
duplicate_project_check
# Out:
#                             Full project name  \
# 5925  TOTALENERGIES E&P UK LIMITED (00811900)
# 5876  TOTALENERGIES E&P UK LIMITED (00811900)
# 5914  TOTALENERGIES E&P UK LIMITED (00811900)
# 5842  TOTALENERGIES E&P UK LIMITED (00811900)
# 5839  TOTALENERGIES E&P UK LIMITED (00811900)
# 5843  TOTALENERGIES E&P UK LIMITED (00811900)
# 5477  TOTALENERGIES E&P UK LIMITED (00811900)
# 5485  TOTALENERGIES E&P UK LIMITED (00811900)
# 5947  TOTALENERGIES E&P UK LIMITED (00811900)
# 5528  TOTALENERGIES E&P UK LIMITED (00811900)
# 5511  TOTALENERGIES E&P UK LIMITED (00811900)
# 5556  TOTALENERGIES E&P UK LIMITED (00811900)
# 5881  TOTALENERGIES E&P UK LIMITED (00811900)
# 5891  TOTALENERGIES E&P UK LIMITED (00811900)
# 5571  TOTALENERGIES E&P UK LIMITED (00811900)
# 5910  TOTALENERGIES E&P UK LIMITED (00811900)
# 5657  TOTALENERGIES E&P UK LIMITED (00811900)
#
#      Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 5925                                               P724
# 5876                                               P362
# 5914                                               P666
# 5842                                               P281
# 5839                                               P268
# 5843                                               P284
# 5477                                              P1159
# 5485                                              P1195
# 5947                                               P911
# 5528                                              P1678
# 5511                                              P1453
# 5556                                              P1970
# 5881                                               P416
# 5891                                               P491
# 5571                                               P208
# 5910                                               P622
# 5657                                               P239
#
#               Affiliated companies, start with Operator  \
# 5925            TOTALENERGIES E&P UK LIMITED (00811900)
# 5876  E. F. OIL AND GAS LIMITED (03430228), ENI ELGI...
# 5914  E. F. OIL AND GAS LIMITED (03430228), ENI ELGI...
# 5842            TOTALENERGIES E&P UK LIMITED (00811900)
# 5839            TOTALENERGIES E&P UK LIMITED (00811900)
# 5843            TOTALENERGIES E&P UK LIMITED (00811900)
# 5477  INEOS E&P (UK) LIMITED (04376184), KISTOS ENER...
# 5485  INEOS E&P (UK) LIMITED (04376184), KISTOS ENER...
# 5947  INEOS E&P (UK) LIMITED (04376184), KISTOS ENER...
# 5528  INEOS E&P (UK) LIMITED (04376184), KISTOS ENER...
# 5511  INEOS E&P (UK) LIMITED (04376184), KISTOS ENER...
# 5556            TOTALENERGIES E&P UK LIMITED (00811900)
# 5881            TOTALENERGIES E&P UK LIMITED (00811900)
# 5891            TOTALENERGIES E&P UK LIMITED (00811900)
# 5571            TOTALENERGIES E&P UK LIMITED (00811900)
# 5910            TOTALENERGIES E&P UK LIMITED (00811900)
# 5657            TOTALENERGIES E&P UK LIMITED (00811900)
#
#      Commodities (one commodity/row)          Status Production (volume) Unit  \
# 5925                   Not available  Not applicable      Not applicable  NaN
# 5876                   Not available  Not applicable      Not applicable  NaN
# 5914                   Not available  Not applicable      Not applicable  NaN
# 5842                   Not available  Not applicable      Not applicable  NaN
# 5839                   Not available  Not applicable      Not applicable  NaN
# 5843                   Not available  Not applicable      Not applicable  NaN
# 5477                   Not available  Not applicable      Not applicable  NaN
# 5485                   Not available  Not applicable      Not applicable  NaN
# 5947                   Not available  Not applicable      Not applicable  NaN
# 5528                   Not available  Not applicable      Not applicable  NaN
# 5511                   Not available  Not applicable      Not applicable  NaN
# 5556                   Not available  Not applicable      Not applicable  NaN
# 5881                   Not available  Not applicable      Not applicable  NaN
# 5891                   Not available  Not applicable      Not applicable  NaN
# 5571                   Not available  Not applicable      Not applicable  NaN
# 5910                   Not available  Not applicable      Not applicable  NaN
# 5657                   Not available  Not applicable      Not applicable  NaN
#
#      Production (value) Currency         Country ISO Code   Year  Start Date  \
# 5925                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5876                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5914                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5842                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5839                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5843                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5477                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5485                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5947                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5528                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5511                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5556                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5881                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5891                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5571                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5910                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 5657                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
#
#         End Date
# 5925  2021-12-31
# 5876  2021-12-31
# 5914  2021-12-31
# 5842  2021-12-31
# 5839  2021-12-31
# 5843  2021-12-31
# 5477  2021-12-31
# 5485  2021-12-31
# 5947  2021-12-31
# 5528  2021-12-31
# 5511  2021-12-31
# 5556  2021-12-31
# 5881  2021-12-31
# 5891  2021-12-31
# 5571  2021-12-31
# 5910  2021-12-31
# 5657  2021-12-31

# %%
duplicate_project_check = duplicate_projects[duplicate_projects['Country'] == 'Afghanistan']
duplicate_project_check
# Out:
#      Full project name  \
# 21         EXPL 3/2012
# 22         EXPL 3/2012
# 101        EXPL 3/2012
# 102        EXPL 3/2012
# 37   SSML-Kabu 10/2016
# 118  SSML-Kabu 10/2016
# 117  SSML-Kabu 10/2016
# 38   SSML-Kabu 10/2016
# 121  SSML-Kabu 13/2012
# 42   SSML-Kabu 13/2012
# 43   SSML-Kabu 13/2012
# 41   SSML-Kabu 13/2012
# 123  SSML-Kabu 13/2012
# 122  SSML-Kabu 13/2012
# 54   SSML-Kabu 19/2016
# 133  SSML-Kabu 19/2016
# 134  SSML-Kabu 19/2016
# 53   SSML-Kabu 19/2016
# 136   SSML-Kabu 2/2008
# 135   SSML-Kabu 2/2008
# 56    SSML-Kabu 2/2008
# 55    SSML-Kabu 2/2008
# 69   SSML-Kabu 42/2014
# 149  SSML-Kabu 42/2014
# 150  SSML-Kabu 42/2014
# 70   SSML-Kabu 42/2014
#
#     Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 21                          Mining Exploration License
# 22                          Mining Exploration License
# 101                         Mining Exploration License
# 102                         Mining Exploration License
# 37                          Small-scale mining license
# 118                         Small-scale mining license
# 117                         Small-scale mining license
# 38                          Small-scale mining license
# 121                         Small-scale mining license
# 42                          Small-scale mining license
# 43                          Small-scale mining license
# 41                          Small-scale mining license
# 123                         Small-scale mining license
# 122                         Small-scale mining license
# 54                          Small-scale mining license
# 133                         Small-scale mining license
# 134                         Small-scale mining license
# 53                          Small-scale mining license
# 136                         Small-scale mining license
# 135                         Small-scale mining license
# 56                          Small-scale mining license
# 55                          Small-scale mining license
# 69                          Small-scale mining license
# 149                         Small-scale mining license
# 150                         Small-scale mining license
# 70                          Small-scale mining license
#
#              Affiliated companies, start with Operator  \
# 21                              شرکت برادران خالد عزیز
# 22                              شرکت برادران خالد عزیز
# 101                             شرکت برادران خالد عزیز
# 102                             شرکت برادران خالد عزیز
# 37                                           Hakim Jan
# 118                                          Hakim Jan
# 117                                          Hakim Jan
# 38                                           Hakim Jan
# 121                       شرکت ساختمانی فاروق استانکزی
# 42                        شرکت ساختمانی فاروق استانکزی
# 43                        شرکت ساختمانی فاروق استانکزی
# 41                        شرکت ساختمانی فاروق استانکزی
# 123                       شرکت ساختمانی فاروق استانکزی
# 122                       شرکت ساختمانی فاروق استانکزی
# 54   نقیب الله فرزند محمد نبی, نقیب الله فرزند محمد...
# 133  نقیب الله فرزند محمد نبی, نقیب الله فرزند محمد...
# 134  نقیب الله فرزند محمد نبی, نقیب الله فرزند محمد...
# 53   نقیب الله فرزند محمد نبی, نقیب الله فرزند محمد...
# 136                                     شرکت تکنالوجست
# 135                                     شرکت تکنالوجست
# 56                                      شرکت تکنالوجست
# 55                                      شرکت تکنالوجست
# 69                   شرکت ساختمانی غلام حضرت ارغندیوال
# 149                  شرکت ساختمانی غلام حضرت ارغندیوال
# 150                  شرکت ساختمانی غلام حضرت ارغندیوال
# 70                   شرکت ساختمانی غلام حضرت ارغندیوال
#
#     Commodities (one commodity/row) Status Production (volume)  \
# 21                              NaN    NaN      Not applicable
# 22                              NaN    NaN      Not applicable
# 101                             NaN    NaN      Not applicable
# 102                             NaN    NaN      Not applicable
# 37                              NaN    NaN                 NaN
# 118                             NaN    NaN                 NaN
# 117                             NaN    NaN                 NaN
# 38                              NaN    NaN                 NaN
# 121                             NaN    NaN                 NaN
# 42                              NaN    NaN                 NaN
# 43                              NaN    NaN                 NaN
# 41                              NaN    NaN                 NaN
# 123                             NaN    NaN                 NaN
# 122                             NaN    NaN                 NaN
# 54                              NaN    NaN                 NaN
# 133                             NaN    NaN                 NaN
# 134                             NaN    NaN                 NaN
# 53                              NaN    NaN                 NaN
# 136                             NaN    NaN                 NaN
# 135                             NaN    NaN                 NaN
# 56                              NaN    NaN                 NaN
# 55                              NaN    NaN                 NaN
# 69                              NaN    NaN                 NaN
# 149                             NaN    NaN                 NaN
# 150                             NaN    NaN                 NaN
# 70                              NaN    NaN                 NaN
#
#                Unit Production (value)        Currency      Country ISO Code   \
# 21   Not applicable     Not applicable  Not applicable  Afghanistan       AFG
# 22   Not applicable     Not applicable  Not applicable  Afghanistan       AFG
# 101  Not applicable     Not applicable  Not applicable  Afghanistan       AFG
# 102  Not applicable     Not applicable  Not applicable  Afghanistan       AFG
# 37              NaN                NaN             NaN  Afghanistan       AFG
# 118             NaN                NaN             NaN  Afghanistan       AFG
# 117             NaN                NaN             NaN  Afghanistan       AFG
# 38              NaN                NaN             NaN  Afghanistan       AFG
# 121             NaN                NaN             NaN  Afghanistan       AFG
# 42              NaN                NaN             NaN  Afghanistan       AFG
# 43              NaN                NaN             NaN  Afghanistan       AFG
# 41              NaN                NaN             NaN  Afghanistan       AFG
# 123             NaN                NaN             NaN  Afghanistan       AFG
# 122             NaN                NaN             NaN  Afghanistan       AFG
# 54              NaN                NaN             NaN  Afghanistan       AFG
# 133             NaN                NaN             NaN  Afghanistan       AFG
# 134             NaN                NaN             NaN  Afghanistan       AFG
# 53              NaN                NaN             NaN  Afghanistan       AFG
# 136             NaN                NaN             NaN  Afghanistan       AFG
# 135             NaN                NaN             NaN  Afghanistan       AFG
# 56              NaN                NaN             NaN  Afghanistan       AFG
# 55              NaN                NaN             NaN  Afghanistan       AFG
# 69              NaN                NaN             NaN  Afghanistan       AFG
# 149             NaN                NaN             NaN  Afghanistan       AFG
# 150             NaN                NaN             NaN  Afghanistan       AFG
# 70              NaN                NaN             NaN  Afghanistan       AFG
#
#      Year  Start Date    End Date
# 21   2018  2017-12-21  2018-12-20
# 22   2018  2017-12-21  2018-12-20
# 101  2019  2018-12-21  2019-12-20
# 102  2019  2018-12-21  2019-12-20
# 37   2018  2017-12-21  2018-12-20
# 118  2019  2018-12-21  2019-12-20
# 117  2019  2018-12-21  2019-12-20
# 38   2018  2017-12-21  2018-12-20
# 121  2019  2018-12-21  2019-12-20
# 42   2018  2017-12-21  2018-12-20
# 43   2018  2017-12-21  2018-12-20
# 41   2018  2017-12-21  2018-12-20
# 123  2019  2018-12-21  2019-12-20
# 122  2019  2018-12-21  2019-12-20
# 54   2018  2017-12-21  2018-12-20
# 133  2019  2018-12-21  2019-12-20
# 134  2019  2018-12-21  2019-12-20
# 53   2018  2017-12-21  2018-12-20
# 136  2019  2018-12-21  2019-12-20
# 135  2019  2018-12-21  2019-12-20
# 56   2018  2017-12-21  2018-12-20
# 55   2018  2017-12-21  2018-12-20
# 69   2018  2017-12-21  2018-12-20
# 149  2019  2018-12-21  2019-12-20
# 150  2019  2018-12-21  2019-12-20
# 70   2018  2017-12-21  2018-12-20

# %%
duplicate_project_names
# Out:
# array(['2025257', 'ALKANE ENERGY UK LIMITED (03128509)',
#        'ALKANE ENERGY UK LIMITED (03128509), EGDON RESOURCES U.K. LIMITED (03424561)',
#        'ALPHA PETROLEUM RESOURCES LIMITED (03949599)',
#        'ANASURIA HIBISCUS UK LIMITED (09696268)',
#        'ANGUS ENERGY WEALD BASIN NO.3 LIMITED (SC055329)',
#        'APACHE BERYL I LIMITED (FC005975)',
#        'AURORA ENERGY RESOURCES LIMITED (SC335749)', 'Altan tsagaan ovoo',
#        'Ambatovy - AMBATOVY MINERALS S.A',
#        'Ambatovy - AMBATOVY MINERALS S.A.',
#        'Area 106/400, 1,500,000 tpa, North Dowsing',
#        'Area 127, 200,000 tpa, SW Needles',
#        'Area 137, 1,000,000 tpa, Area A',
#        'Area 197, 300,000 tpa, Protector Overfalls',
#        'Area 228, 1,500,000 tpa (mix), Off Great Yarmouth',
#        'Area 240, 1,500,000 tpa, Cross Sands',
#        'Area 242/361, 325,000 tpa, Lowestoft',
#        'Area 254, 500,000 tpa, Off Great Yarmouth',
#        'Area 340, 500,000 tpa, Nab',
#        'Area 351, 500,000 tpa, SE Isle of Wight',
#        'Area 351, 750,000 tpa (mix), SE Isle of Wight',
#        'Area 395/1-2, 500,000 tpa, Off Selsey Bill',
#        'Area 395/1-2, 750,000 tpa (Off Selsey Bill)',
#        'Area 396/488, 500,000 tpa, Inner Owers',
#        'Area 401/2, 900,000 tpa, Yarmouth',
#        "Area 407, 1,000,000 tpa, St Catherine's",
#        'Area 430, 300,000 tpa, Southwold East',
#        'Area 435, 900,000 tpa (mix), Inner Owers',
#        "Area 451, 1,250,000 tpa (mix), St Catherine's",
#        'Area 457, 1,200,000 tpa (mix), Liverpool Bay',
#        'Area 458/464, 1,000,000 tpa, West Bassurelle',
#        'Area 458/464, 2,000,000 tpa, West Bassurelle',
#        'Area 460, 1,000,000 tpa, South Hastings',
#        'Area 460, 500,000 tpa, South Hastings',
#        'Area 461, 1,000,000 tpa, Median Deep',
#        'Area 470/1-2, 125,000 tpa, N. Bristol Deep',
#        'Area 473, 1,000,000 tpa, Greenwich Light East',
#        'Area 473, 666,667 tpa, Greenwich Light East',
#        'Area 476, 500,000 tpa (mix) (Nobel Banks)',
#        'Area 478, 1,000,000 tpa, Area 1 South',
#        'Area 481, 250,000 tpa (mix), Inner Dowsing',
#        'Area 481, 375,000 tpa, Inner Dowsing',
#        'Area 483, 600,000 tpa, Humber 5',
#        'Area 484, 600,000 tpa, Humber 3',
#        'Area 493, 300,000 tpa, Humber Overfalls',
#        'Area 494, 500,000 tpa, North Cross Sands',
#        'Area 498, 175,000 tpa, North Inner Gabbard',
#        'Area 500/1-4, 850,000 tpa, South Wight',
#        'Area 501, 3,000,000 tpa (mix), North Falls East',
#        'Area 506, 800,000 tpa, Humber 4 & 7',
#        'Area 508, 750,000 tpa (mix), Longsand',
#        'Area 509/1-3, 750,000 tpa, Longsand',
#        'Area 511, 650,000 tpa, Lowestoft',
#        'Area 512, 650,000 tpa, ex 251/454',
#        'Area 513, 650,000 tpa, Lowestoft',
#        'Area 514/1-4, 1,500,000 tpa, Humber',
#        'Area 515, 2,250,000 tpa (mix), Outer Dowsing',
#        'Area 526, 666,666 tpa, Culver Extension',
#        'BP EXPLORATION OPERATING COMPANY LIMITED (00305943)',
#        'Baruun noyon uul', 'Bloc Ta29', 'Boulby Offshore Mine',
#        'CHRYSAOR NORTH SEA LIMITED (00958880)',
#        'CHRYSAOR PETROLEUM COMPANY U.K. LIMITED (00792712)',
#        'CHRYSAOR PRODUCTION (U.K.) LIMITED (00524868)',
#        'CHRYSAOR RESOURCES (IRISH SEA) LIMITED (03440053)', 'CI-526',
#        'CIRQUE ENERGY (UK) LIMITED (03080778)', 'CNH-M5- MIQUETLA/2018',
#        'CNH-R02-L02- A10.CS/2017', 'CNH-R02-L02- A4.BG/2017',
#        'CNH-R02-L02- A5.BG/2017', 'CNH-R02-L03-CS01/2017',
#        'CNH-R02-L03-VC02/2017', 'CNH-R02-L04-APCS-G02/2018',
#        'CNHA3.CÁRDENASMORA/2018', 'CNHA4.OGARRIO/2018',
#        'CNR INTERNATIONAL (U.K.) LIMITED (00813187)', 'Claymore',
#        'Crown Farm & Delamere Quarries',
#        'DANA PETROLEUM (E&P) LIMITED (02294746)',
#        'EGDON RESOURCES U.K. LIMITED (03424561)',
#        'EGDON RESOURCES U.K. LIMITED (03424561), REGENT PARK ENERGY LIMITED (04557422)',
#        'ENI UK LIMITED (00862823)', 'ENQUEST HEATHER LIMITED (02748866)',
#        'EQUINOR UK LIMITED (01285743)', 'EXPL 3/2012',
#        'Falconbridge Dominicana, S.A.',
#        'Feasibility study for open pit mining and heap leaching of oxidized gold and silver deposits',
#        'Full project name', 'Fulmar',
#        'HORSE HILL DEVELOPMENTS LTD (08808553)',
#        'IGAS ENERGY DEVELOPMENT LIMITED (07240286)',
#        'IGAS ENERGY ENTERPRISE LIMITED (05457589)',
#        'IGAS ENERGY PRODUCTION LIMITED (SC298739)',
#        'INEOS UK SNS LIMITED (01021338)',
#        'IOG NORTH SEA LIMITED (07632999)',
#        'ISLAND GAS LIMITED (04962079)',
#        'ITHACA OIL AND GAS LIMITED (01546623)',
#        'ITHACA SP E&P LIMITED (01504603)',
#        'Island Quarry and Aggregates Corporation', 'Jubilee Fields',
#        'KOLE', 'LOKELE', 'MPSA No. 111-98-VII\r\n(Amended I)',
#        'MV-000296', 'Miller',
#        'NEO ENERGY PRODUCTION UK LIMITED (12086835)',
#        'NEPTUNE E&P UK LIMITED (01483021)', 'NO OPERATOR',
#        "Nalaikh mine's eastern wing, usage of mud mining",
#        'Non applicable', 'Non précisé', 'Not applicable',
#        'ONE-DYAS UK LIMITED (03531783)',
#        'PARKMEAD (E&P) LIMITED (SC397002)',
#        'PERENCO GAS (UK) LIMITED (00715529)',
#        'PERENCO UK LIMITED (04653066)',
#        'PETROGAS NORTH SEA LIMITED (05470844)', 'PL-5/126 (Ntronang 1)',
#        'PL-5/126 (Ntronang 2)', 'PREMIER OIL E&P UK LIMITED (02761032)',
#        'PREMIER OIL UK LIMITED (SC048705)', 'Pant y Pwll Dwr Quarry',
#        'Piper', 'REPSOL SINOPEC RESOURCES UK LIMITED (00825828)',
#        'Rio Tinto - QIT MADAGASCAR MINERALS S.A.',
#        'Rio Tinto- QIT MADAGASCAR MINERALS S.A',
#        'SERICA ENERGY (UK) LIMITED (04073712)', 'SGN Fields',
#        'SHELL U.K. LIMITED (00140141)',
#        'SOUTH WESTERN ENERGY LIMITED (08019159)',
#        'SPIRIT ENERGY NORTH SEA LIMITED (04594558)',
#        'SPIRIT ENERGY PRODUCTION UK LIMITED (03115179)',
#        'SPIRIT ENERGY RESOURCES LIMITED (02855151)', 'SSML-Kabu 10/2016',
#        'SSML-Kabu 13/2012', 'SSML-Kabu 19/2016', 'SSML-Kabu 2/2008',
#        'SSML-Kabu 42/2014',
#        'Southgobi province gurvantes soum, Zangat soum, stone coal mine',
#        'Stainton Quarry', 'Stowe Hill Cert/Surf Rnt & Roy',
#        'Subsoil use special permit No. 3685, dated 12.09.2005',
#        'Subsoil use special permit No. 3686, dated 12.09.2005',
#        'Subsoil use special permit No. 3687, dated 12.09.2005',
#        'Subsoil use special permit No. 4062, dated 21.10.2011',
#        'Subsoil use special permit No. 4063, dated 31.10.2011',
#        'Subsoil use special permit No. 4294, dated 29.12.2012',
#        'Subsoil use special permit No. 5395, dated 14.10.2011',
#        'TAQA BRATANI LIMITED (05975475)', 'TEN Fields',
#        'THIRD ENERGY UK GAS LIMITED (01421481)',
#        'TOTALENERGIES E&P UK LIMITED (00811900)', 'VICTOR',
#        'WINTERSHALL NOORDZEE B.V. (FC027567)',
#        'Wharf, Rvr Usk nr Caldicot Level', nan], dtype=object)

# %% [markdown]
# #### Implications
# - There is a significant number of duplicate project names across many of the countries.
# - This can be caused by not having information in the commodities field
# - There is a need to check/count the number of duplicates per country to see if this should be expected

# %%
# pd.set_option('display.max_rows', None)

project_counts_per_country = duplicate_projects.groupby('Country')['Full project name'].value_counts()

duplicates_per_country = project_counts_per_country[project_counts_per_country > 1]

print("Number of duplicate project names per country:")
print(duplicates_per_country)

# pd.reset_option('display.max_rows')
# Out:
# Number of duplicate project names per country:
# Country         Full project name
# Afghanistan     SSML-Kabu 13/2012                                 6
#                 EXPL 3/2012                                       4
#                 SSML-Kabu 10/2016                                 4
#                 SSML-Kabu 19/2016                                 4
#                 SSML-Kabu 2/2008                                  4
#                                                                  ..
# United Kingdom  SPIRIT ENERGY PRODUCTION UK LIMITED (03115179)    2
#                 Stowe Hill Cert/Surf Rnt & Roy                    2
#                 VICTOR                                            2
#                 WINTERSHALL NOORDZEE B.V. (FC027567)              2
#                 Wharf, Rvr Usk nr Caldicot Level                  2
# Name: count, Length: 158, dtype: int64

# %%
duplicate_projects.groupby('Country').size().reset_index(name='duplicates per country')
# Out:
#                Country  duplicates per country
# 0          Afghanistan                      26
# 1             Cameroon                       4
# 2        Cote d'Ivoire                       2
# 3              Country                       7
# 4             Country                        9
# 5   Dominican Republic                       2
# 6                Ghana                      14
# 7              Liberia                      17
# 8           Madagascar                       9
# 9           Mauritania                       2
# 10              Mexico                      19
# 11            Mongolia                      12
# 12         Philippines                       4
# 13             Senegal                       2
# 14             Ukraine                      14
# 15      United Kingdom                     449

# %%
df_part_3c[df_part_3c['Full project name'] == 'CIRQUE ENERGY (UK) LIMITED (03080778)']
# Out:
#                           Full project name  \
# 6001  CIRQUE ENERGY (UK) LIMITED (03080778)
# 6008  CIRQUE ENERGY (UK) LIMITED (03080778)
#
#      Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 6001                                            PEDL324
# 6008                                            PEDL348
#
#               Affiliated companies, start with Operator  \
# 6001  CIRQUE ENERGY (UK) LIMITED (03080778), STELINM...
# 6008  CIRQUE ENERGY (UK) LIMITED (03080778), STELINM...
#
#      Commodities (one commodity/row)          Status Production (volume) Unit  \
# 6001                   Not available  Not applicable      Not applicable  NaN
# 6008                   Not available  Not applicable      Not applicable  NaN
#
#      Production (value) Currency         Country ISO Code   Year  Start Date  \
# 6001                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
# 6008                NaN      GBP  United Kingdom       GBR  2021  2021-01-01
#
#         End Date
# 6001  2021-12-31
# 6008  2021-12-31

# %%
duplicate_projects[duplicate_projects['Country']=='Afghanistan']
# Out:
#      Full project name  \
# 21         EXPL 3/2012
# 22         EXPL 3/2012
# 101        EXPL 3/2012
# 102        EXPL 3/2012
# 37   SSML-Kabu 10/2016
# 118  SSML-Kabu 10/2016
# 117  SSML-Kabu 10/2016
# 38   SSML-Kabu 10/2016
# 121  SSML-Kabu 13/2012
# 42   SSML-Kabu 13/2012
# 43   SSML-Kabu 13/2012
# 41   SSML-Kabu 13/2012
# 123  SSML-Kabu 13/2012
# 122  SSML-Kabu 13/2012
# 54   SSML-Kabu 19/2016
# 133  SSML-Kabu 19/2016
# 134  SSML-Kabu 19/2016
# 53   SSML-Kabu 19/2016
# 136   SSML-Kabu 2/2008
# 135   SSML-Kabu 2/2008
# 56    SSML-Kabu 2/2008
# 55    SSML-Kabu 2/2008
# 69   SSML-Kabu 42/2014
# 149  SSML-Kabu 42/2014
# 150  SSML-Kabu 42/2014
# 70   SSML-Kabu 42/2014
#
#     Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 21                          Mining Exploration License
# 22                          Mining Exploration License
# 101                         Mining Exploration License
# 102                         Mining Exploration License
# 37                          Small-scale mining license
# 118                         Small-scale mining license
# 117                         Small-scale mining license
# 38                          Small-scale mining license
# 121                         Small-scale mining license
# 42                          Small-scale mining license
# 43                          Small-scale mining license
# 41                          Small-scale mining license
# 123                         Small-scale mining license
# 122                         Small-scale mining license
# 54                          Small-scale mining license
# 133                         Small-scale mining license
# 134                         Small-scale mining license
# 53                          Small-scale mining license
# 136                         Small-scale mining license
# 135                         Small-scale mining license
# 56                          Small-scale mining license
# 55                          Small-scale mining license
# 69                          Small-scale mining license
# 149                         Small-scale mining license
# 150                         Small-scale mining license
# 70                          Small-scale mining license
#
#              Affiliated companies, start with Operator  \
# 21                              شرکت برادران خالد عزیز
# 22                              شرکت برادران خالد عزیز
# 101                             شرکت برادران خالد عزیز
# 102                             شرکت برادران خالد عزیز
# 37                                           Hakim Jan
# 118                                          Hakim Jan
# 117                                          Hakim Jan
# 38                                           Hakim Jan
# 121                       شرکت ساختمانی فاروق استانکزی
# 42                        شرکت ساختمانی فاروق استانکزی
# 43                        شرکت ساختمانی فاروق استانکزی
# 41                        شرکت ساختمانی فاروق استانکزی
# 123                       شرکت ساختمانی فاروق استانکزی
# 122                       شرکت ساختمانی فاروق استانکزی
# 54   نقیب الله فرزند محمد نبی, نقیب الله فرزند محمد...
# 133  نقیب الله فرزند محمد نبی, نقیب الله فرزند محمد...
# 134  نقیب الله فرزند محمد نبی, نقیب الله فرزند محمد...
# 53   نقیب الله فرزند محمد نبی, نقیب الله فرزند محمد...
# 136                                     شرکت تکنالوجست
# 135                                     شرکت تکنالوجست
# 56                                      شرکت تکنالوجست
# 55                                      شرکت تکنالوجست
# 69                   شرکت ساختمانی غلام حضرت ارغندیوال
# 149                  شرکت ساختمانی غلام حضرت ارغندیوال
# 150                  شرکت ساختمانی غلام حضرت ارغندیوال
# 70                   شرکت ساختمانی غلام حضرت ارغندیوال
#
#     Commodities (one commodity/row) Status Production (volume)  \
# 21                              NaN    NaN      Not applicable
# 22                              NaN    NaN      Not applicable
# 101                             NaN    NaN      Not applicable
# 102                             NaN    NaN      Not applicable
# 37                              NaN    NaN                 NaN
# 118                             NaN    NaN                 NaN
# 117                             NaN    NaN                 NaN
# 38                              NaN    NaN                 NaN
# 121                             NaN    NaN                 NaN
# 42                              NaN    NaN                 NaN
# 43                              NaN    NaN                 NaN
# 41                              NaN    NaN                 NaN
# 123                             NaN    NaN                 NaN
# 122                             NaN    NaN                 NaN
# 54                              NaN    NaN                 NaN
# 133                             NaN    NaN                 NaN
# 134                             NaN    NaN                 NaN
# 53                              NaN    NaN                 NaN
# 136                             NaN    NaN                 NaN
# 135                             NaN    NaN                 NaN
# 56                              NaN    NaN                 NaN
# 55                              NaN    NaN                 NaN
# 69                              NaN    NaN                 NaN
# 149                             NaN    NaN                 NaN
# 150                             NaN    NaN                 NaN
# 70                              NaN    NaN                 NaN
#
#                Unit Production (value)        Currency      Country ISO Code   \
# 21   Not applicable     Not applicable  Not applicable  Afghanistan       AFG
# 22   Not applicable     Not applicable  Not applicable  Afghanistan       AFG
# 101  Not applicable     Not applicable  Not applicable  Afghanistan       AFG
# 102  Not applicable     Not applicable  Not applicable  Afghanistan       AFG
# 37              NaN                NaN             NaN  Afghanistan       AFG
# 118             NaN                NaN             NaN  Afghanistan       AFG
# 117             NaN                NaN             NaN  Afghanistan       AFG
# 38              NaN                NaN             NaN  Afghanistan       AFG
# 121             NaN                NaN             NaN  Afghanistan       AFG
# 42              NaN                NaN             NaN  Afghanistan       AFG
# 43              NaN                NaN             NaN  Afghanistan       AFG
# 41              NaN                NaN             NaN  Afghanistan       AFG
# 123             NaN                NaN             NaN  Afghanistan       AFG
# 122             NaN                NaN             NaN  Afghanistan       AFG
# 54              NaN                NaN             NaN  Afghanistan       AFG
# 133             NaN                NaN             NaN  Afghanistan       AFG
# 134             NaN                NaN             NaN  Afghanistan       AFG
# 53              NaN                NaN             NaN  Afghanistan       AFG
# 136             NaN                NaN             NaN  Afghanistan       AFG
# 135             NaN                NaN             NaN  Afghanistan       AFG
# 56              NaN                NaN             NaN  Afghanistan       AFG
# 55              NaN                NaN             NaN  Afghanistan       AFG
# 69              NaN                NaN             NaN  Afghanistan       AFG
# 149             NaN                NaN             NaN  Afghanistan       AFG
# 150             NaN                NaN             NaN  Afghanistan       AFG
# 70              NaN                NaN             NaN  Afghanistan       AFG
#
#      Year  Start Date    End Date
# 21   2018  2017-12-21  2018-12-20
# 22   2018  2017-12-21  2018-12-20
# 101  2019  2018-12-21  2019-12-20
# 102  2019  2018-12-21  2019-12-20
# 37   2018  2017-12-21  2018-12-20
# 118  2019  2018-12-21  2019-12-20
# 117  2019  2018-12-21  2019-12-20
# 38   2018  2017-12-21  2018-12-20
# 121  2019  2018-12-21  2019-12-20
# 42   2018  2017-12-21  2018-12-20
# 43   2018  2017-12-21  2018-12-20
# 41   2018  2017-12-21  2018-12-20
# 123  2019  2018-12-21  2019-12-20
# 122  2019  2018-12-21  2019-12-20
# 54   2018  2017-12-21  2018-12-20
# 133  2019  2018-12-21  2019-12-20
# 134  2019  2018-12-21  2019-12-20
# 53   2018  2017-12-21  2018-12-20
# 136  2019  2018-12-21  2019-12-20
# 135  2019  2018-12-21  2019-12-20
# 56   2018  2017-12-21  2018-12-20
# 55   2018  2017-12-21  2018-12-20
# 69   2018  2017-12-21  2018-12-20
# 149  2019  2018-12-21  2019-12-20
# 150  2019  2018-12-21  2019-12-20
# 70   2018  2017-12-21  2018-12-20

# %%
duplicate_projects.groupby('Full project name').size().reset_index(name='duplicates per project name')
# Out:
#                                      Full project name  \
# 0                                              2025257
# 1                  ALKANE ENERGY UK LIMITED (03128509)
# 2    ALKANE ENERGY UK LIMITED (03128509), EGDON RES...
# 3         ALPHA PETROLEUM RESOURCES LIMITED (03949599)
# 4              ANASURIA HIBISCUS UK LIMITED (09696268)
# ..                                                 ...
# 153             THIRD ENERGY UK GAS LIMITED (01421481)
# 154            TOTALENERGIES E&P UK LIMITED (00811900)
# 155                                             VICTOR
# 156               WINTERSHALL NOORDZEE B.V. (FC027567)
# 157                   Wharf, Rvr Usk nr Caldicot Level
#
#      duplicates per project name
# 0                              2
# 1                              3
# 2                              2
# 3                              2
# 4                              2
# ..                           ...
# 153                            5
# 154                           17
# 155                            2
# 156                            2
# 157                            2
#
# [158 rows x 2 columns]

# %%
duplicate_projects2 = get_duplicates(df_part_3c, 
                                    'Full project name', 
                                    *['Country', 'Year', 'Commodities (one commodity/row)', 'Affiliated companies, start with Operator', 
                                      'Legal agreement reference number(s): contract, licence, lease, concession, …',
                                     'Production (volume)', 'Status', 'Unit', 'Production (value)'])

duplicate_projects2
# Out:
#                                       Full project name  \
# 6048                                            2025257
# 6047                                            2025257
# 6117         Area 106/400, 1,500,000 tpa, North Dowsing
# 6130         Area 106/400, 1,500,000 tpa, North Dowsing
# 6129         Area 106/400, 1,500,000 tpa, North Dowsing
# ...                                                 ...
# 2022  Subsoil use special permit No. 4294, dated 29....
# 4800                                             VICTOR
# 4801                                             VICTOR
# 6116                   Wharf, Rvr Usk nr Caldicot Level
# 6115                   Wharf, Rvr Usk nr Caldicot Level
#
#      Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 6048                                            Licence
# 6047                                            Licence
# 6117                                            Licence
# 6130                                            Licence
# 6129                                            Licence
# ...                                                 ...
# 2022                                               4294
# 4800                                      Not available
# 4801                                      Not available
# 6116                                            Licence
# 6115                                            Licence
#
#      Affiliated companies, start with Operator  \
# 6048                         Breedon Group Plc
# 6047                         Breedon Group Plc
# 6117                            Hanson Limited
# 6130                            Hanson Limited
# 6129                            Hanson Limited
# ...                                        ...
# 2022                  Naftogaz of Ukraine NJSC
# 4800                             Not available
# 4801                             Not available
# 6116                            Hanson Limited
# 6115                            Hanson Limited
#
#      Commodities (one commodity/row)          Status Production (volume) Unit  \
# 6048                   Not available  Not applicable      Not applicable  NaN
# 6047                   Not available  Not applicable      Not applicable  NaN
# 6117                   Not available  Not applicable      Not applicable  NaN
# 6130                   Not available  Not applicable      Not applicable  NaN
# 6129                   Not available  Not applicable      Not applicable  NaN
# ...                              ...             ...                 ...  ...
# 2022                             NaN      Production                 NaN  NaN
# 4800                   Not available   Not available       Not available  NaN
# 4801                   Not available   Not available       Not available  NaN
# 6116                   Not available  Not applicable      Not applicable  NaN
# 6115                   Not available  Not applicable      Not applicable  NaN
#
#      Production (value) Currency         Country ISO Code     Year  \
# 6048                NaN      GBP  United Kingdom       GBR  2021.0
# 6047                NaN      GBP  United Kingdom       GBR  2021.0
# 6117                NaN      GBP  United Kingdom       GBR  2021.0
# 6130                NaN      GBP  United Kingdom       GBR  2021.0
# 6129                NaN      GBP  United Kingdom       GBR  2021.0
# ...                 ...      ...             ...       ...     ...
# 2022                NaN      NaN         Ukraine       UKR  2018.0
# 4800                NaN      NaN  United Kingdom       GBR  2019.0
# 4801                NaN      NaN  United Kingdom       GBR  2019.0
# 6116                NaN      GBP  United Kingdom       GBR  2021.0
# 6115                NaN      GBP  United Kingdom       GBR  2021.0
#
#       Start Date    End Date
# 6048  2021-01-01  2021-12-31
# 6047  2021-01-01  2021-12-31
# 6117  2021-01-01  2021-12-31
# 6130  2021-01-01  2021-12-31
# 6129  2021-01-01  2021-12-31
# ...          ...         ...
# 2022  2018-01-01  2018-12-31
# 4800  2019-01-01  2019-12-31
# 4801  2019-01-01  2019-12-31
# 6116  2021-01-01  2021-12-31
# 6115  2021-01-01  2021-12-31
#
# [271 rows x 14 columns]

# %%
duplicate_projects2.groupby('Country').size().reset_index(name='duplicates per country')
# Out:
#           Country  duplicates per country
# 0     Afghanistan                      26
# 1   Cote d'Ivoire                       2
# 2           Ghana                       8
# 3         Liberia                      17
# 4      Mauritania                       2
# 5          Mexico                      19
# 6         Ukraine                       6
# 7  United Kingdom                     189

# %%
duplicate_projects2['Full project name'].nunique()
# Out:
# 84

# %% [markdown]
# ### No duplicate company ids in the same year and country
#
# #### Expectations
# - A company ID will appear only once per year per country
# - The company or agency identification numbers (IDs) within the dataset are unique for a given year and country.
# - The dataset has been structured to ensure a one-to-one mapping between company or agency IDs.
#
# #### Assumptions
# - 1 company ID = 1 company in a country
# - Each company or agency ID is assumed to uniquely represent a specific entity for the year and country.
# - Duplicate company or agency IDs within the same year and country are considered deviations from the expected dataset structure.
#
# #### Results

# %%
duplicate_ids = get_duplicates(df_part_3a, 
                                    'Company ID number', 
                                    *['Country', 'Year'])

duplicate_ids
# Out:
#                                     Full company name  \
# 519                Rio Tuba Nickel Mining Corporation
# 497                Rio Tuba Nickel Mining Corporation
# 878                          HOUNDE GOLD OPERATION SA
# 877                        HOUNDE EXPLORATION BF SARL
# 872                        HOUNDE EXPLORATION BF SARL
# ...                                               ...
# 3216                                    GX Technology
# 3217                                           JOGMEX
# 3242                                    GRAYSON BANDA
# 3256  TANZANIA PORTLAND CEMENT PUBLIC LIMITED COMPANY
# 3258               State Mining Corporation (STAMICO)
#
#                                        Company type Company ID number  \
# 519                                         Private   000-142-665-000
# 497                                         Private   000-142-665-000
# 878                                         Private         00064526S
# 877                                         Private         00064526S
# 872                                         Private         00064526S
# ...                                             ...               ...
# 3216                                            NaN               NaN
# 3217                                            NaN               NaN
# 3242                                        Private               NaN
# 3256                                        Private               NaN
# 3258  State-owned enterprises & public corporations               NaN
#
#          Sector Commodities (comma-seperated)  \
# 519      Mining                     Limestone
# 497      Mining                        Nickel
# 878      Mining                            Or
# 877      Mining                            Or
# 872      Mining                          Gold
# ...         ...                           ...
# 3216  Oil & Gas                           NaN
# 3217  Oil & Gas                           NaN
# 3242     Mining                          Gold
# 3256     Mining           Limeston, Sandstone
# 3258     Mining                          Gold
#
#               Stock exchange listing or company website  \
# 519   nickelasia.com/subsidiaries/rio-tuba-nickel-mi...
# 497   nickelasia.com/subsidiaries/rio-tuba-nickel-mi...
# 878                                        Indisponible
# 877   https://www.endeavourmining.com/our-portfolio/...
# 872   https://www.endeavourmining.com/our-portfolio/...
# ...                                                 ...
# 3216                                                NaN
# 3217                                                NaN
# 3242                                      Not available
# 3256                                      Not available
# 3258                          http://www.stamico.co.tz/
#
#      Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 519   nickelasia.com/investor-relations/financial-re...
# 497   nickelasia.com/investor-relations/financial-re...
# 878                                                 NaN
# 877                                                 NaN
# 872                                                 NaN
# ...                                                 ...
# 3216                                                NaN
# 3217                                                NaN
# 3242                                      Not available
# 3256                                      Not available
# 3258                                      Not available
#
#      Payments to Governments Report       Country ISO Code  Year  Start Date  \
# 519                             NaN   Philippines      PHL  2018  2018-01-01
# 497                  864,690,546.00   Philippines      PHL  2018  2018-01-01
# 878               39,636,048,842.00  Burkina Faso      BFA  2019    1/1/2019
# 877                    7,879,789.00  Burkina Faso      BFA  2019    1/1/2019
# 872                   13,130,988.00  Burkina Faso      BFA  2018    1/1/2018
# ...                             ...           ...      ...   ...         ...
# 3216                            NaN    Seychelles      SYC  2018  2018-01-01
# 3217                            NaN    Seychelles      SYC  2018  2018-01-01
# 3242               3,126,118,498.00      Tanzania      TZA  2018  2017-07-01
# 3256              24,750,760,174.02      Tanzania      TZA  2018  2017-07-01
# 3258                   1,357,092.00      Tanzania      TZA  2018  2017-07-01
#
#         End Date
# 519   2018-12-31
# 497   2018-12-31
# 878   12/31/2019
# 877   12/31/2019
# 872   12/31/2018
# ...          ...
# 3216  2018-12-31
# 3217  2018-12-31
# 3242  2018-06-30
# 3256  2018-06-30
# 3258  2018-06-30
#
# [450 rows x 13 columns]

# %%
# duplicate_company_ids_1 = df_part_3a[df_part_3a.duplicated(['Country', 'Year', 'Company ID number'], keep=False)]

# %%
duplicate_ids = get_duplicates(df_part_3a, 
                                    'Company ID number', 
                                    *['Country', 'Year', 'Full company name', 
                                      'Sector', 'Company type','Stock exchange listing or company website'])

duplicate_ids
# Out:
#                        Full company name Company type Company ID number  \
# 497   Rio Tuba Nickel Mining Corporation      Private   000-142-665-000
# 519   Rio Tuba Nickel Mining Corporation      Private   000-142-665-000
# 173               شرکت برادران خالد عزیز      Private        1019984010
# 174               شرکت برادران خالد عزیز      Private        1019984010
# 1564                   PT PERTAMINA IRAK      Private               NaN
# 1588                   PT PERTAMINA IRAK      Private               NaN
#
#          Sector Commodities (comma-seperated)  \
# 497      Mining                        Nickel
# 519      Mining                     Limestone
# 173       Other                          Coal
# 174       Other                          Coal
# 1564  Oil & Gas         Oil, Gas, Condensates
# 1588  Oil & Gas         Oil, Gas, Condensates
#
#               Stock exchange listing or company website  \
# 497   nickelasia.com/subsidiaries/rio-tuba-nickel-mi...
# 519   nickelasia.com/subsidiaries/rio-tuba-nickel-mi...
# 173                                      Not applicable
# 174                                      Not applicable
# 1564                                                NaN
# 1588                                                NaN
#
#      Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 497   nickelasia.com/investor-relations/financial-re...
# 519   nickelasia.com/investor-relations/financial-re...
# 173                                       Not available
# 174                                       Not available
# 1564                                                NaN
# 1588                                                NaN
#
#      Payments to Governments Report      Country ISO Code  Year  Start Date  \
# 497                  864,690,546.00  Philippines      PHL  2018  2018-01-01
# 519                             NaN  Philippines      PHL  2018  2018-01-01
# 173                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 174                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 1564                 990,135,616.00         Iraq      IRQ  2018    1/1/2018
# 1588                 990,135,616.00         Iraq      IRQ  2018    1/1/2018
#
#         End Date
# 497   2018-12-31
# 519   2018-12-31
# 173   2018-12-20
# 174   2018-12-20
# 1564  12/31/2018
# 1588  12/31/2018

# %%
duplicate_ids2 = get_duplicates(df_part_3a, 
                                    'Company ID number', 
                                    *['Full company name', 'Company type', 'Sector', 
                                      'Commodities (comma-seperated)', 'Stock exchange listing or company website', 
                                      'Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)',
                                      'Payments to Governments Report', 'Country', 'Year'])

duplicate_ids2
# Out:
#            Full company name Company type Company ID number     Sector  \
# 173   شرکت برادران خالد عزیز      Private        1019984010      Other
# 174   شرکت برادران خالد عزیز      Private        1019984010      Other
# 1564       PT PERTAMINA IRAK      Private               NaN  Oil & Gas
# 1588       PT PERTAMINA IRAK      Private               NaN  Oil & Gas
#
#      Commodities (comma-seperated) Stock exchange listing or company website  \
# 173                           Coal                            Not applicable
# 174                           Coal                            Not applicable
# 1564         Oil, Gas, Condensates                                       NaN
# 1588         Oil, Gas, Condensates                                       NaN
#
#      Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 173                                       Not available
# 174                                       Not available
# 1564                                                NaN
# 1588                                                NaN
#
#      Payments to Governments Report      Country ISO Code  Year  Start Date  \
# 173                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 174                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 1564                 990,135,616.00         Iraq      IRQ  2018    1/1/2018
# 1588                 990,135,616.00         Iraq      IRQ  2018    1/1/2018
#
#         End Date
# 173   2018-12-20
# 174   2018-12-20
# 1564  12/31/2018
# 1588  12/31/2018

# %%
duplicate_ids2 = get_duplicates(df_part_3a, 
                                    'Company ID number', 
                                    *['Full company name', 'Company type', 'Sector', 
                                      'Commodities (comma-seperated)', 'Stock exchange listing or company website', 
                                      'Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)',
                                      'Payments to Governments Report', 'Country', 'Year'])

duplicate_ids2
# Out:
#            Full company name Company type Company ID number     Sector  \
# 173   شرکت برادران خالد عزیز      Private        1019984010      Other
# 174   شرکت برادران خالد عزیز      Private        1019984010      Other
# 1564       PT PERTAMINA IRAK      Private               NaN  Oil & Gas
# 1588       PT PERTAMINA IRAK      Private               NaN  Oil & Gas
#
#      Commodities (comma-seperated) Stock exchange listing or company website  \
# 173                           Coal                            Not applicable
# 174                           Coal                            Not applicable
# 1564         Oil, Gas, Condensates                                       NaN
# 1588         Oil, Gas, Condensates                                       NaN
#
#      Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 173                                       Not available
# 174                                       Not available
# 1564                                                NaN
# 1588                                                NaN
#
#      Payments to Governments Report      Country ISO Code  Year  Start Date  \
# 173                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 174                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 1564                 990,135,616.00         Iraq      IRQ  2018    1/1/2018
# 1588                 990,135,616.00         Iraq      IRQ  2018    1/1/2018
#
#         End Date
# 173   2018-12-20
# 174   2018-12-20
# 1564  12/31/2018
# 1588  12/31/2018

# %%
duplicate_ids.groupby('Company ID number').size().reset_index(name='duplicates')
# Out:
#    Company ID number  duplicates
# 0    000-142-665-000           2
# 1          00064526S           4
# 2         1007815085           4
# 3         1008627083           3
# 4         1009592088           4
# 5         1010360087           4
# 6         1013655012           5
# 7         1016525014           4
# 8         1019984010           2
# 9          103947189           2
# 10        1044142014           2
# 11         108744308           2
# 12    1384,1998-1999           2
# 13           2700773           4
# 14     761,1998-1999           2
# 15        9000036856           2
# 16        9000197187           4
# 17        9000647140           2
# 18        9001044669           4
# 19        9001204305           4
# 20        9001353375           2
# 21        9001505461           2
# 22        9002301225           2
# 23        9003329902           2
# 24         919160675           2
# 25         931713671           2
# 26         983426417           5
# 27                NC          37
# 28                Nc           2
# 29     Not Available           8
# 30    Not applicable          81
# 31     Not available          40
# 32  Not communicated          19
# 33          RC321517           2
# 34          RC322270           2

# %%
# duplicate_id_names = duplicate_ids['Company ID number'].unique()

# print("Number of duplicate IDs: {}\n".format(len(duplicate_id_names.tolist())))

# duplicate_id_counts = duplicate_ids['Company ID number'].value_counts()
# # print(duplicate_project_counts)

# print("Number of duplicate IDS")
# for id, count in duplicate_id_counts.items():
#     if count > 1:
#         duplicates = duplicate_ids[duplicate_ids['Company ID number'] == id]
#         print(f"Name: {id}, Count: {count}")

# %%
duplicate_ids.groupby('Country').size().reset_index(name='duplicates')
# Out:
#                          Country  duplicates
# 0                    Afghanistan          55
# 1                        Armenia           4
# 2                   Burkina Faso           4
# 3                           Chad          48
# 4                  Cote d'Ivoire           6
# 5   Democratic Republic of Congo           4
# 6                      Guatemala          11
# 7                           Iraq         141
# 8                     Mauritania           5
# 9                         Mexico          10
# 10                       Myanmar          57
# 11                       Nigeria          44
# 12                        Norway          11
# 13                   Philippines           2
# 14         Republic of the Congo          35
# 15                    Seychelles          10
# 16                      Tanzania           3

# %% [markdown]
# **Let's check the data for Afghanistan**

# %%
duplicate_ids[duplicate_ids['Country'] == 'Afghanistan'].sort_values(by=['Company ID number'])
# Out:
#                                      Full company name  \
# 356  د امین کریمزی د شوکانو او مرمرو داستخراج اوپرو...
# 234  Ameen Karimzai Talc and Marble Extraction and ...
# 116  د امین کریمزی د شوکانو او مرمرو داستخراج اوپرو...
# 0                                Amin Karimzai Campany
# 272                                  Mati Sami Limited
# 230          Ahmad Shah Talc Extraction and Processing
# 229                           Ahmad shah Maidanwall Co
# 107  بلال موسی زی دمعدنی ډبرو استخراج او پروسس شرکت...
# 18                       Bilal Musazai Company Limited
# 347  بلال موسی زی دمعدنی ډبرو استخراج او پروسس شرکت...
# 244  Bilal Musazai Mineral Processing Industrial Co...
# 216  نبی افغان دمعدن استخراج او پروسس شر کت Nabi Af...
# 284  Nabi Afghan Mines Extraction and Processing Co...
# 58                                 Nabi Afghan Company
# 460  نبی افغان دمعدن استخراج او پروسس شر کت Nabi Af...
# 1    Habib Shahab Talc and Marble exploitation and ...
# 353  حبیب شهاب تا لک اومر مرواستخراج او پروسس شر کت...
# 254  Habib Shahab Talc and Marble Extraction and Pr...
# 30   Habib Shahab Talc and Marble Extraction and Pr...
# 115  حبیب شهاب تا لک اومر مرواستخراج او پروسس شر کت...
# 82     Standard Talc Extraction and Processing Company
# 311    Standard Talc Processing and Extraction Company
# 358  ستندر شو کا ڼی دپرو سس او استخراج شر کت Standa...
# 119  ستندر شو کا ڼی دپرو سس او استخراج شر کت Standa...
# 174                             شرکت برادران خالد عزیز
# 173                             شرکت برادران خالد عزیز
# 446  شرکت معدن کاران برادران دره صوف Darai Soof Bro...
# 271                                        Madan Karan
# 326                         استخراج معادن هیواد برادرز
# 393  شرکت استخراج معادن هیواد برادرز Hewad Brothers...
# 424                شرکت امانیه مایننگ Amania Mining Co
# 14                               Amania Mining Company
# 233                              Amania Mining Company
# 171                شرکت امانیه مایننگ Amanya Mining Co
# 327            استخراج معادن یاسمین Yasameen Mining Co
# 330              استخراج معدن امتیاز Emtiyaz Mining Co
# 125                                   شرکت استانه بابا
# 380  شرکت استخراج معادن ستانه بابا Stana Baba Minin...
# 140  شرکت استخراج معادن ستانه بابا Stana Baba minin...
# 364                                   شرکت استانه بابا
# 120                 سلک رود مایننگ Silk road Mining Co
# 359                    سلک رود مایننگ Silk Road Mining
# 109  پروژه اکتشاف مس شیدای هرات Herat Shaida Copper...
# 309                                   Silk Road Mining
# 370  شرکت استخراج معادن افغان اکتیف لمیتد Afghan Ac...
# 369                     شرکت استخراج معادن افغان اکتیف
# 94                                             Zar Jan
# 138  شرکت استخراج معادن ذغال سنک افراسیاب Afrasyab ...
# 419           شرکت استخراج وپروسس سنگ بری زرافشان سفید
# 343  استخراج و پروسس سنگ زرافشان سفید Zarafshan-e-S...
# 43                            Javed Liaqat Ali Limited
# 105  اغا احمدی منرالز استخراج اوپروسس Agha Ahmadi M...
# 456                 محمد یاور ولد عبدالکریم, محمد یاور
# 225                              Afghan Gas Enterprise
# 346                              افغان گولد اند منرالز
#
#                                       Company type Company ID number  \
# 356                                        Private        1007815085
# 234                                        Private        1007815085
# 116                                        Private        1007815085
# 0                                          Private        1007815085
# 272                                        Private        1008627083
# 230                                        Private        1008627083
# 229                                        Private        1008627083
# 107                                        Private        1009592088
# 18                                         Private        1009592088
# 347                                        Private        1009592088
# 244                                        Private        1009592088
# 216                                        Private        1010360087
# 284                                        Private        1010360087
# 58                                         Private        1010360087
# 460                                        Private        1010360087
# 1                                          Private        1013655012
# 353                                        Private        1013655012
# 254                                        Private        1013655012
# 30                                         Private        1013655012
# 115                                        Private        1013655012
# 82                                         Private        1016525014
# 311                                        Private        1016525014
# 358                                        Private        1016525014
# 119                                        Private        1016525014
# 174                                        Private        1019984010
# 173                                        Private        1019984010
# 446                                        Private        1044142014
# 271                                        Private        1044142014
# 326                                        Private        9000036856
# 393                                        Private        9000036856
# 424                                        Private        9000197187
# 14                                         Private        9000197187
# 233                                        Private        9000197187
# 171                                        Private        9000197187
# 327                                        Private        9000647140
# 330                                        Private        9000647140
# 125                                        Private        9001044669
# 380                                        Private        9001044669
# 140                                        Private        9001044669
# 364                                        Private        9001044669
# 120                                        Private        9001204305
# 359                                        Private        9001204305
# 109                                        Private        9001204305
# 309                                        Private        9001204305
# 370                                        Private        9001353375
# 369                                        Private        9001353375
# 94                                         Private        9001505461
# 138                                        Private        9001505461
# 419                                        Private        9002301225
# 343                                        Private        9002301225
# 43                                         Private        9003329902
# 105                                        Private        9003329902
# 456                                        Private     Not available
# 225  State-owned enterprises & public corporations     Not available
# 346                                        Private     Not available
#
#         Sector Commodities (comma-seperated)  \
# 356      Other                          Talc
# 234      Other                          Talc
# 116      Other                          Talc
# 0        Other                          Talc
# 272      Other                          Talc
# 230      Other                          Talc
# 229      Other                          Talc
# 107      Other                          Talc
# 18       Other                          Talc
# 347      Other                           NaN
# 244      Other                          Talc
# 216      Other                          Talc
# 284      Other                          Talc
# 58       Other                          Talc
# 460     Mining                           NaN
# 1        Other      Talc, Construction stone
# 353      Other                          Talc
# 254      Other                          Talc
# 30       Other                          Talc
# 115      Other                          Talc
# 82       Other                          Talc
# 311      Other                          Talc
# 358     Mining                           NaN
# 119      Other                          Talc
# 174      Other                          Coal
# 173      Other                          Coal
# 446      Other                          coal
# 271      Other                          Coal
# 326      Other                      coromait
# 393      Other                      Chromite
# 424      Other                      Fluoride
# 14       Other                      Fluoride
# 233      Other                      Fluoride
# 171      Other                           NaN
# 327      Other                        quartz
# 330      Other                           NaN
# 125      Other                      Chromite
# 380      Other                      Chromite
# 140      Other                      Chromite
# 364      Other                      Chromite
# 120      Other                        Copper
# 359      Other                        Copper
# 109     Mining                        Copper
# 309      Other                        Copper
# 370      Other                      Chromite
# 369      Other                      Chromite
# 94      Mining                Coal, Chromite
# 138      Other                          Coal
# 419      Other            Construction Stone
# 343      Other            Construction stone
# 43       Other                          Coal
# 105     Mining                           NaN
# 456      Other            Construction Stone
# 225  Oil & Gas         Oil, Gas, Condensates
# 346      Other                          coal
#
#     Stock exchange listing or company website  \
# 356                            Not applicable
# 234                            Not applicable
# 116                            Not applicable
# 0                              Not applicable
# 272                            Not applicable
# 230                            Not applicable
# 229                            Not applicable
# 107                            Not applicable
# 18                             Not applicable
# 347                            Not applicable
# 244                            Not applicable
# 216                            Not applicable
# 284                            Not applicable
# 58                             Not applicable
# 460                                       NaN
# 1                              Not applicable
# 353                                       NaN
# 254                            Not applicable
# 30                             Not applicable
# 115                            Not applicable
# 82                             Not applicable
# 311                            Not applicable
# 358                                       NaN
# 119                            Not applicable
# 174                            Not applicable
# 173                            Not applicable
# 446                            Not applicable
# 271                            Not applicable
# 326                            Not applicable
# 393                                       NaN
# 424                            Not applicable
# 14                             Not applicable
# 233                            Not applicable
# 171                            Not applicable
# 327                            Not applicable
# 330                                       NaN
# 125                            Not applicable
# 380                            Not applicable
# 140                            Not applicable
# 364                            Not applicable
# 120                            Not applicable
# 359                            Not applicable
# 109                            Not applicable
# 309                            Not applicable
# 370                                       NaN
# 369                            Not applicable
# 94                             Not applicable
# 138                            Not applicable
# 419                            Not applicable
# 343                            Not applicable
# 43                             Not applicable
# 105                            Not applicable
# 456                            Not applicable
# 225                            Not applicable
# 346                            Not applicable
#
#     Audited financial statement (or balance sheet, cash flows, profit/loss statement if unavailable)  \
# 356                                      Not available
# 234                                      Not available
# 116                                      Not available
# 0                                        Not available
# 272                                      Not available
# 230                                      Not available
# 229                                      Not available
# 107                                      Not available
# 18                                       Not available
# 347                                      Not available
# 244                                      Not available
# 216                                      Not available
# 284                                      Not available
# 58                                       Not available
# 460                                                NaN
# 1                                        Not available
# 353                                                NaN
# 254                                      Not available
# 30                                       Not available
# 115                                      Not available
# 82                                       Not available
# 311                                      Not available
# 358                                                NaN
# 119                                      Not available
# 174                                      Not available
# 173                                      Not available
# 446                                      Not available
# 271                                      Not available
# 326                                      Not available
# 393                                                NaN
# 424                                      Not available
# 14                                       Not available
# 233                                      Not available
# 171                                      Not available
# 327                                      Not available
# 330                                                NaN
# 125                                      Not available
# 380                                      Not available
# 140                                      Not available
# 364                                      Not available
# 120                                      Not available
# 359                                      Not available
# 109                                      Not available
# 309                                      Not available
# 370                                                NaN
# 369                                      Not available
# 94                                       Not available
# 138                                      Not available
# 419                                      Not available
# 343                                      Not available
# 43                                       Not available
# 105                                      Not available
# 456                                      Not available
# 225                           https://momp.gov.af/soes
# 346                                      Not available
#
#     Payments to Governments Report      Country ISO Code  Year  Start Date  \
# 356                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 234                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 116                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 0                          #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 272                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 230                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 229                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 107                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 18                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 347                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 244                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 216                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 284                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 58                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 460                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 1                          #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 353                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 254                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 30                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 115                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 82                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 311                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 358                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 119                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 174                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 173                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 446                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 271                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 326                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 393                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 424                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 14                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 233                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 171                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 327                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 330                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 125                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 380                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 140                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 364                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 120                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 359                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 109                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 309                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 370                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 369                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 94                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 138                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 419                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 343                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 43                         #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 105                        #ERROR!  Afghanistan      AFG  2018  2017-12-21
# 456                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 225                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
# 346                        #ERROR!  Afghanistan      AFG  2019  2018-12-21
#
#        End Date
# 356  2019-12-20
# 234  2019-12-20
# 116  2018-12-20
# 0    2018-12-20
# 272  2019-12-20
# 230  2019-12-20
# 229  2019-12-20
# 107  2018-12-20
# 18   2018-12-20
# 347  2019-12-20
# 244  2019-12-20
# 216  2018-12-20
# 284  2019-12-20
# 58   2018-12-20
# 460  2019-12-20
# 1    2018-12-20
# 353  2019-12-20
# 254  2019-12-20
# 30   2018-12-20
# 115  2018-12-20
# 82   2018-12-20
# 311  2019-12-20
# 358  2019-12-20
# 119  2018-12-20
# 174  2018-12-20
# 173  2018-12-20
# 446  2019-12-20
# 271  2019-12-20
# 326  2019-12-20
# 393  2019-12-20
# 424  2019-12-20
# 14   2018-12-20
# 233  2019-12-20
# 171  2018-12-20
# 327  2019-12-20
# 330  2019-12-20
# 125  2018-12-20
# 380  2019-12-20
# 140  2018-12-20
# 364  2019-12-20
# 120  2018-12-20
# 359  2019-12-20
# 109  2018-12-20
# 309  2019-12-20
# 370  2019-12-20
# 369  2019-12-20
# 94   2018-12-20
# 138  2018-12-20
# 419  2019-12-20
# 343  2019-12-20
# 43   2018-12-20
# 105  2018-12-20
# 456  2019-12-20
# 225  2019-12-20
# 346  2019-12-20

# %% [markdown]
# ##### Now let's look at government entities

# %%
duplicate_ids_agency = get_duplicates(df_part_3b, 
                                    'ID number (if applicable)', 
                                    *['Country', 'Year'])

duplicate_ids_agency
# Out:
#                                    Full name of agency         Agency type  \
# 424                             Norwegian Central Bank   Central goverment
# 425                                             Petoro   Central goverment
# 265  Superintendencia de Administración Tributaria ...  Central government
# 266                                    Municipalidades    Local government
# 262                Ministerio de Energia y Minas (MEM)  Central government
# ..                                                 ...                 ...
# 544         Ministry of Mines and Minerals Development   Central goverment
# 545                      Environmental Protection Fund               Other
# 546                                  Ministry of Lands   Central goverment
# 547                                                IDC               Other
# 548                                                MoF   Central goverment
#
#                       ID number (if applicable)     Total reported    Country  \
# 424                                   937884117                  -     Norway
# 425                                   937884117  96,478,000,000.00     Norway
# 265  <Use Legal Entity Identifier if available>     149,007,097.60  Guatemala
# 266  <Use Legal Entity Identifier if available>      63,301,988.42  Guatemala
# 262  <Use Legal Entity Identifier if available>     228,058,363.73  Guatemala
# ..                                          ...                ...        ...
# 544                                         NaN      48,229,839.93     Zambia
# 545                                         NaN      23,330,601.78     Zambia
# 546                                         NaN       1,756,688.47     Zambia
# 547                                         NaN      69,205,641.67     Zambia
# 548                                         NaN      23,178,861.72     Zambia
#
#     ISO Code    Year  Start Date    End Date
# 424      NOR  2019.0    1/1/2019  12/31/2019
# 425      NOR  2019.0    1/1/2019  12/31/2019
# 265      GTM  2017.0  2017-01-01  2017-12-01
# 266      GTM  2017.0  2017-01-01  2017-12-01
# 262      GTM  2017.0  2017-01-01  2017-12-01
# ..       ...     ...         ...         ...
# 544      ZMB  2018.0  2018-01-01  2018-12-31
# 545      ZMB  2018.0  2018-01-01  2018-12-31
# 546      ZMB  2018.0  2018-01-01  2018-12-31
# 547      ZMB  2018.0  2018-01-01  2018-12-31
# 548      ZMB  2018.0  2018-01-01  2018-12-31
#
# [469 rows x 9 columns]

# %%
duplicate_ids_agency.groupby('Country').size().reset_index(name='duplicates')
# Out:
#                          Country  duplicates
# 0                    Afghanistan          10
# 1                        Albania          22
# 2                      Argentina           4
# 3                        Armenia           6
# 4                   Burkina Faso          36
# 5                       Cameroon           8
# 6                           Chad          21
# 7                  Cote d'Ivoire          18
# 8   Democratic Republic of Congo          10
# 9                       Ethiopia           3
# 10                       Germany          16
# 11                         Ghana          80
# 12                     Guatemala           5
# 13                          Iraq          17
# 14                       Liberia          10
# 15                    Madagascar          24
# 16                          Mali          14
# 17                    Mauritania           6
# 18                        Mexico           3
# 19                      Mongolia          23
# 20                    Mozambique           4
# 21                       Myanmar          10
# 22                       Nigeria          18
# 23                        Norway           2
# 24         Republic of the Congo           9
# 25                       Senegal          20
# 26                    Seychelles           6
# 27                      Tanzania          15
# 28                          Togo          18
# 29           Trinidad and Tobago           6
# 30                United Kingdom          12
# 31                        Zambia          13

# %%
duplicate_ids_agency.groupby('ID number (if applicable)').size().reset_index(name='duplicates')
# Out:
#                     ID number (if applicable)  duplicates
# 0                                   937884117           2
# 1  <Use Legal Entity Identifier if available>           5
# 2                                      Mining           3
# 3                               No applicable           7
# 4                              Non applicable          45
# 5                              Not applicable          59
# 6                               Not available           9
# 7                                   Oil & Gas           6

# %%
duplicate_ids_agency[duplicate_ids_agency['Country'] == 'Afghanistan'].sort_values(by=['ID number (if applicable)'])
# Out:
#                                  Full name of agency        Agency type  \
# 0           Ministry of Finance (Revenue Department)  Central goverment
# 9                  Ministry of Industry and Commerce  Central goverment
# 8           National Environmental Protection Agency  Central goverment
# 7  Ministry of Mines and Petroleum (Revenue Depar...  Central goverment
# 6           Ministry of Finance (Customs Department)  Central goverment
# 5           Ministry of Finance (Revenue Department)  Central goverment
# 4                  Ministry of Industry and Commerce  Central goverment
# 3           National Environmental Protection Agency  Central goverment
# 2  Ministry of Mines and Petroleum (Revenue Depar...  Central goverment
# 1           Ministry of Finance (Customs Department)  Central goverment
#
#   ID number (if applicable) Total reported      Country ISO Code    Year  \
# 0            Not applicable        #ERROR!  Afghanistan      AFG  2018.0
# 9            Not applicable        #ERROR!  Afghanistan      AFG  2019.0
# 8            Not applicable        #ERROR!  Afghanistan      AFG  2019.0
# 7            Not applicable        #ERROR!  Afghanistan      AFG  2019.0
# 6            Not applicable        #ERROR!  Afghanistan      AFG  2019.0
# 5            Not applicable        #ERROR!  Afghanistan      AFG  2019.0
# 4            Not applicable        #ERROR!  Afghanistan      AFG  2018.0
# 3            Not applicable        #ERROR!  Afghanistan      AFG  2018.0
# 2            Not applicable        #ERROR!  Afghanistan      AFG  2018.0
# 1            Not applicable        #ERROR!  Afghanistan      AFG  2018.0
#
#    Start Date    End Date
# 0  2017-12-21  2018-12-20
# 9  2018-12-21  2019-12-20
# 8  2018-12-21  2019-12-20
# 7  2018-12-21  2019-12-20
# 6  2018-12-21  2019-12-20
# 5  2018-12-21  2019-12-20
# 4  2017-12-21  2018-12-24
# 3  2017-12-21  2018-12-23
# 2  2017-12-21  2018-12-22
# 1  2017-12-21  2018-12-21

# %% [markdown]
# #### Implications
# - There is a significant number of duplicate company ID values
# - Most are due to the information not being available or not existing in the dataset
# - Several others are due the same ids appearing multiple times with different names in the name field

# %% [markdown]
# ### No duplicate company-project-commodity combination in the same year and country
#
# #### Expectations
# - We anticipate that within the provided dataset, each combination of a company and project in a given year and country should be unique.
# - This expectation is grounded in the assumption that projects are distinctly identified by the combination of the involved company, the project name, and the associated year and country.
#
# #### Assumptions
# - Projects are uniquely identified by the combination of the company, project name, year, and country.
# - The dataset has been curated to prevent duplicate entries for the same project within the same year and country.
#
# #### Results

# %%
company_project_duplicates = df_part_3c.duplicated(subset=['Affiliated companies, start with Operator', 'Full project name', 'Year', 'Country'], keep=False)

duplicate_rows = df_part_3c[company_project_duplicates]
duplicate_rows
# Out:
#                          Full project name  \
# 21                             EXPL 3/2012
# 22                             EXPL 3/2012
# 37                       SSML-Kabu 10/2016
# 38                       SSML-Kabu 10/2016
# 41                       SSML-Kabu 13/2012
# ...                                    ...
# 6254  Area 461, 1,000,000 tpa, Median Deep
# 6255                        Kansanshi Mine
# 6256                        Kansanshi Mine
# 6268                        Kansanshi Mine
# 6269                        Kansanshi Mine
#
#      Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 21                           Mining Exploration License
# 22                           Mining Exploration License
# 37                           Small-scale mining license
# 38                           Small-scale mining license
# 41                           Small-scale mining license
# ...                                                 ...
# 6254                                            Licence
# 6255                                        7057 HQ LML
# 6256                                       17019-HQ-LEL
# 6268                                        7057 HQ LML
# 6269                                       17019-HQ-LEL
#
#      Affiliated companies, start with Operator  \
# 21                      شرکت برادران خالد عزیز
# 22                      شرکت برادران خالد عزیز
# 37                                   Hakim Jan
# 38                                   Hakim Jan
# 41                شرکت ساختمانی فاروق استانکزی
# ...                                        ...
# 6254                       Volker Dredging Ltd
# 6255                      Kansanshi Mining Plc
# 6256                      Kansanshi Mining Plc
# 6268                      KANSANSHI MINING PLC
# 6269                      KANSANSHI MINING PLC
#
#      Commodities (one commodity/row)          Status Production (volume)  \
# 21                               NaN             NaN      Not applicable
# 22                               NaN             NaN      Not applicable
# 37                               NaN             NaN                 NaN
# 38                               NaN             NaN                 NaN
# 41                               NaN             NaN                 NaN
# ...                              ...             ...                 ...
# 6254                   Not available  Not applicable      Not applicable
# 6255                   Copper (2603)      Production             250,860
# 6256                     Gold (7108)      Production               4.565
# 6268                   Copper (2603)      Production          251,517.19
# 6269                     Gold (7108)      Production                 3.9
#
#                 Unit Production (value)        Currency         Country  \
# 21    Not applicable     Not applicable  Not applicable     Afghanistan
# 22    Not applicable     Not applicable  Not applicable     Afghanistan
# 37               NaN                NaN             NaN     Afghanistan
# 38               NaN                NaN             NaN     Afghanistan
# 41               NaN                NaN             NaN     Afghanistan
# ...              ...                ...             ...             ...
# 6254             NaN                NaN             GBP  United Kingdom
# 6255          Tonnes           1,547.48             USD          Zambia
# 6256          Tonnes             183.31             USD          Zambia
# 6268          Tonnes   1,640,609,303.36             USD          Zambia
# 6269          Tonnes     140,315,848.29             USD          Zambia
#
#      ISO Code   Year  Start Date    End Date
# 21         AFG  2018  2017-12-21  2018-12-20
# 22         AFG  2018  2017-12-21  2018-12-20
# 37         AFG  2018  2017-12-21  2018-12-20
# 38         AFG  2018  2017-12-21  2018-12-20
# 41         AFG  2018  2017-12-21  2018-12-20
# ...        ...   ...         ...         ...
# 6254       GBR  2021  2021-01-01  2021-12-31
# 6255       ZMB  2017  2017-01-01  2017-12-31
# 6256       ZMB  2017  2017-01-01  2017-12-31
# 6268       ZMB  2018  2018-01-01  2018-12-31
# 6269       ZMB  2018  2018-01-01  2018-12-31
#
# [2416 rows x 14 columns]

# %%
print("Duplicates per country:")
dup_country = count_duplicates(df_part_3c, company_project_duplicates, 'Country', 'duplicates_per_country')
dup_country
# Out:
# Duplicates per country:
#                 Country  duplicates_per_country
# 0           Afghanistan                      26
# 1               Albania                      16
# 2             Argentina                      15
# 3               Armenia                       9
# 4          Burkina Faso                      30
# 5              Cameroon                       4
# 6         Cote d'Ivoire                      10
# 7               Country                       7
# 8              Country                        9
# 9    Dominican Republic                      29
# 10                Ghana                      26
# 11            Guatemala                       3
# 12              Liberia                      17
# 13           Madagascar                      13
# 14           Mauritania                       2
# 15               Mexico                      19
# 16             Mongolia                      12
# 17           Mozambique                       2
# 18              Myanmar                       2
# 19          Philippines                      32
# 20              Senegal                      36
# 21  Trinidad and Tobago                      36
# 22              Ukraine                    1590
# 23       United Kingdom                     449
# 24               Zambia                       4

# %%
print("Duplicates per year:")
dup_year = count_duplicates(df_part_3c, company_project_duplicates, 'Year', 'duplicates_per_year')
dup_year
# Out:
# Duplicates per year:
#    Year  duplicates_per_year
# 0  2017                   41
# 1  2018                  651
# 2  2019                  526
# 3  2020                  725
# 4  2021                  439
# 5  Year                   16

# %% [markdown]
# In the next part, let's look at duplicates with the same project name, affiliated companies, country, year, and commodity

# %%
company_project_comm_duplicates = df_part_3c.duplicated(subset=['Affiliated companies, start with Operator', 'Full project name', 'Year', 'Country', 'Commodities (one commodity/row)'], keep=False)

duplicate_rows_2 = df_part_3c[company_project_comm_duplicates]
duplicate_rows_2
# Out:
#                             Full project name  \
# 21                                EXPL 3/2012
# 22                                EXPL 3/2012
# 37                          SSML-Kabu 10/2016
# 38                          SSML-Kabu 10/2016
# 41                          SSML-Kabu 13/2012
# ...                                       ...
# 6250               Area 340, 500,000 tpa, Nab
# 6251  Area 351, 500,000 tpa, SE Isle of Wight
# 6252  Area 351, 500,000 tpa, SE Isle of Wight
# 6253     Area 461, 1,000,000 tpa, Median Deep
# 6254     Area 461, 1,000,000 tpa, Median Deep
#
#      Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 21                           Mining Exploration License
# 22                           Mining Exploration License
# 37                           Small-scale mining license
# 38                           Small-scale mining license
# 41                           Small-scale mining license
# ...                                                 ...
# 6250                                            Licence
# 6251                                            Licence
# 6252                                            Licence
# 6253                                            Licence
# 6254                                            Licence
#
#      Affiliated companies, start with Operator  \
# 21                      شرکت برادران خالد عزیز
# 22                      شرکت برادران خالد عزیز
# 37                                   Hakim Jan
# 38                                   Hakim Jan
# 41                شرکت ساختمانی فاروق استانکزی
# ...                                        ...
# 6250                       Volker Dredging Ltd
# 6251                       Volker Dredging Ltd
# 6252                       Volker Dredging Ltd
# 6253                       Volker Dredging Ltd
# 6254                       Volker Dredging Ltd
#
#      Commodities (one commodity/row)          Status Production (volume)  \
# 21                               NaN             NaN      Not applicable
# 22                               NaN             NaN      Not applicable
# 37                               NaN             NaN                 NaN
# 38                               NaN             NaN                 NaN
# 41                               NaN             NaN                 NaN
# ...                              ...             ...                 ...
# 6250                   Not available  Not applicable      Not applicable
# 6251                   Not available  Not applicable      Not applicable
# 6252                   Not available  Not applicable      Not applicable
# 6253                   Not available  Not applicable      Not applicable
# 6254                   Not available  Not applicable      Not applicable
#
#                 Unit Production (value)        Currency         Country  \
# 21    Not applicable     Not applicable  Not applicable     Afghanistan
# 22    Not applicable     Not applicable  Not applicable     Afghanistan
# 37               NaN                NaN             NaN     Afghanistan
# 38               NaN                NaN             NaN     Afghanistan
# 41               NaN                NaN             NaN     Afghanistan
# ...              ...                ...             ...             ...
# 6250             NaN                NaN             GBP  United Kingdom
# 6251             NaN                NaN             GBP  United Kingdom
# 6252             NaN                NaN             GBP  United Kingdom
# 6253             NaN                NaN             GBP  United Kingdom
# 6254             NaN                NaN             GBP  United Kingdom
#
#      ISO Code   Year  Start Date    End Date
# 21         AFG  2018  2017-12-21  2018-12-20
# 22         AFG  2018  2017-12-21  2018-12-20
# 37         AFG  2018  2017-12-21  2018-12-20
# 38         AFG  2018  2017-12-21  2018-12-20
# 41         AFG  2018  2017-12-21  2018-12-20
# ...        ...   ...         ...         ...
# 6250       GBR  2021  2021-01-01  2021-12-31
# 6251       GBR  2021  2021-01-01  2021-12-31
# 6252       GBR  2021  2021-01-01  2021-12-31
# 6253       GBR  2021  2021-01-01  2021-12-31
# 6254       GBR  2021  2021-01-01  2021-12-31
#
# [610 rows x 14 columns]

# %%
print("Duplicates per country with the same project name, affiliated companies, year, and commodity:")
dup_country_aff = count_duplicates(df_part_3c, company_project_comm_duplicates, 'Country', 'duplicates_per_country')
dup_country_aff
# Out:
# Duplicates per country with the same project name, affiliated companies, year, and commodity:
#                Country  duplicates_per_country
# 0          Afghanistan                      26
# 1             Cameroon                       4
# 2        Cote d'Ivoire                       2
# 3              Country                       7
# 4             Country                        9
# 5   Dominican Republic                       2
# 6                Ghana                      14
# 7              Liberia                      17
# 8           Madagascar                       9
# 9           Mauritania                       2
# 10              Mexico                      19
# 11            Mongolia                      12
# 12         Philippines                       4
# 13             Senegal                       2
# 14             Ukraine                      14
# 15      United Kingdom                     449

# %%
duplicate_rows_2[duplicate_rows_2['Country'] == 'Mexico'].sort_values(by=['Full project name'])
# Out:
#               Full project name  \
# 1069      CNH-M5- MIQUETLA/2018
# 1059      CNH-M5- MIQUETLA/2018
# 1057   CNH-R02-L02- A10.CS/2017
# 1066   CNH-R02-L02- A10.CS/2017
# 1055    CNH-R02-L02- A4.BG/2017
# 1064    CNH-R02-L02- A4.BG/2017
# 1056    CNH-R02-L02- A5.BG/2017
# 1065    CNH-R02-L02- A5.BG/2017
# 1053      CNH-R02-L03-CS01/2017
# 1061      CNH-R02-L03-CS01/2017
# 1063      CNH-R02-L03-VC02/2017
# 1054      CNH-R02-L03-VC02/2017
# 1077  CNH-R02-L04-APCS-G02/2018
# 1078  CNH-R02-L04-APCS-G02/2018
# 1060    CNHA3.CÁRDENASMORA/2018
# 1070    CNHA3.CÁRDENASMORA/2018
# 1058         CNHA4.OGARRIO/2018
# 1068         CNHA4.OGARRIO/2018
# 1071         CNHA4.OGARRIO/2018
#
#      Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 1069                              CNH-M5- MIQUETLA/2018
# 1059                              CNH-M5- MIQUETLA/2018
# 1057                           CNH-R02-L02- A10.CS/2017
# 1066                           CNH-R02-L02- A10.CS/2017
# 1055                            CNH-R02-L02- A4.BG/2017
# 1064                            CNH-R02-L02- A4.BG/2017
# 1056                            CNH-R02-L02- A5.BG/2017
# 1065                            CNH-R02-L02- A5.BG/2017
# 1053                              CNH-R02-L03-CS01/2017
# 1061                              CNH-R02-L03-CS01/2017
# 1063                              CNH-R02-L03-VC02/2017
# 1054                              CNH-R02-L03-VC02/2017
# 1077                          CNH-R02-L04-APCS-G02/2018
# 1078                          CNH-R02-L04-APCS-G02/2018
# 1060                            CNHA3.CÁRDENASMORA/2018
# 1070                            CNHA3.CÁRDENASMORA/2018
# 1058                                 CNHA4.OGARRIO/2018
# 1068                                 CNHA4.OGARRIO/2018
# 1071                                 CNHA4.OGARRIO/2018
#
#              Affiliated companies, start with Operator  \
# 1069                    Pemex Exploración y Producción
# 1059                    Pemex Exploración y Producción
# 1057                                           Pantera
# 1066                                           Pantera
# 1055                                           Pantera
# 1064                                           Pantera
# 1056                                           Pantera
# 1065                                           Pantera
# 1053  Jaguar Exploración Y Producción De Hidrocarburos
# 1061  Jaguar Exploración Y Producción De Hidrocarburos
# 1063  Jaguar Exploración Y Producción De Hidrocarburos
# 1054  Jaguar Exploración Y Producción De Hidrocarburos
# 1077                                             Shell
# 1078                                             Shell
# 1060                    Pemex Exploración y Producción
# 1070                    Pemex Exploración y Producción
# 1058                            Wintershall DEA Mexico
# 1068                            Wintershall DEA Mexico
# 1071                            Wintershall DEA Mexico
#
#      Commodities (one commodity/row)      Status Production (volume) Unit  \
# 1069                Crude oil (2709)  Production       Not available  NaN
# 1059                Crude oil (2709)  Production       Not available  NaN
# 1057                Crude oil (2709)  Production       Not available  NaN
# 1066                Crude oil (2709)  Production       Not available  NaN
# 1055                Crude oil (2709)  Production       Not available  NaN
# 1064                Crude oil (2709)  Production       Not available  NaN
# 1056                Crude oil (2709)  Production       Not available  NaN
# 1065                Crude oil (2709)  Production       Not available  NaN
# 1053                Crude oil (2709)  Production       Not available  NaN
# 1061                Crude oil (2709)  Production       Not available  NaN
# 1063                Crude oil (2709)  Production       Not available  NaN
# 1054                Crude oil (2709)  Production       Not available  NaN
# 1077                Crude oil (2709)  Production       Not available  NaN
# 1078                Crude oil (2709)  Production       Not available  NaN
# 1060                Crude oil (2709)  Production       Not available  NaN
# 1070                Crude oil (2709)  Production       Not available  NaN
# 1058                Crude oil (2709)  Production       Not available  NaN
# 1068                Crude oil (2709)  Production       Not available  NaN
# 1071                Crude oil (2709)  Production       Not available  NaN
#
#      Production (value) Currency Country ISO Code   Year Start Date  \
# 1069                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1059                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1057                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1066                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1055                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1064                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1056                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1065                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1053                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1061                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1063                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1054                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1077                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1078                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1060                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1070                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1058                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1068                NaN      NaN  Mexico       MEX  2018   1/1/2018
# 1071                NaN      NaN  Mexico       MEX  2018   1/1/2018
#
#         End Date
# 1069  12/31/2018
# 1059  12/31/2018
# 1057  12/31/2018
# 1066  12/31/2018
# 1055  12/31/2018
# 1064  12/31/2018
# 1056  12/31/2018
# 1065  12/31/2018
# 1053  12/31/2018
# 1061  12/31/2018
# 1063  12/31/2018
# 1054  12/31/2018
# 1077  12/31/2018
# 1078  12/31/2018
# 1060  12/31/2018
# 1070  12/31/2018
# 1058  12/31/2018
# 1068  12/31/2018
# 1071  12/31/2018

# %%
print("Duplicates per year with the same project name, affiliated companies, country, and commodity::")
dup_year_aff = count_duplicates(df_part_3c, company_project_comm_duplicates, 'Year', 'duplicates_per_year')
dup_year_aff
# Out:
# Duplicates per year with the same project name, affiliated companies, country, and commodity::
#    Year  duplicates_per_year
# 0  2017                   10
# 1  2018                   82
# 2  2019                   27
# 3  2020                   18
# 4  2021                  439
# 5  Year                   16

# %%
duplicate_rows_2[duplicate_rows_2['Year'] == '2020'].sort_values(by=['Full project name'])
# Out:
#                                       Full project name  \
# 1187                                 Altan tsagaan ovoo
# 1186                                 Altan tsagaan ovoo
# 1213                                   Baruun noyon uul
# 1214                                   Baruun noyon uul
# 1103  Feasibility study for open pit mining and heap...
# 1104  Feasibility study for open pit mining and heap...
# 1217                                          MV-000296
# 1218                                          MV-000296
# 1209   Nalaikh mine's eastern wing, usage of mud mining
# 1210   Nalaikh mine's eastern wing, usage of mud mining
# 1140  Southgobi province gurvantes soum, Zangat soum...
# 1141  Southgobi province gurvantes soum, Zangat soum...
# 2910  Subsoil use special permit No. 3685, dated 12....
# 2911  Subsoil use special permit No. 3685, dated 12....
# 2912  Subsoil use special permit No. 3686, dated 12....
# 2913  Subsoil use special permit No. 3686, dated 12....
# 2906  Subsoil use special permit No. 3687, dated 12....
# 2907  Subsoil use special permit No. 3687, dated 12....
#
#      Legal agreement reference number(s): contract, licence, lease, concession, …  \
# 1187                                         T/19-11-11
# 1186                                         T/19-11-11
# 1213                                         Т/19-08-02
# 1214                                         Т/20-12-08
# 1103                                         Т/18-12-15
# 1104                                         Т/18-12-15
# 1217                                           ХХ-11-12
# 1218                                           ХХ-07-11
# 1209                                            Д/03-06
# 1210                                         Т/18-12-01
# 1140                                              9-Feb
# 1141                                         Т/17-11-07
# 2910                                               3685
# 2911                                               3685
# 2912                                               3686
# 2913                                               3686
# 2906                                               3687
# 2907                                               3687
#
#      Affiliated companies, start with Operator  \
# 1187                               Steppe Gold
# 1186                               Steppe Gold
# 1213                           Tsagaan uvuljuu
# 1214                           Tsagaan uvuljuu
# 1103                   Bayan airag exploration
# 1104                   Bayan airag exploration
# 1217                          Tsarig Skhonkhor
# 1218                          Tsarig Skhonkhor
# 1209                                  Khualyan
# 1210                                  Khualyan
# 1140                             Javkhlant ord
# 1141                             Javkhlant ord
# 2910                           Lvivvuhillia SE
# 2911                           Lvivvuhillia SE
# 2912                           Lvivvuhillia SE
# 2913                           Lvivvuhillia SE
# 2906                           Lvivvuhillia SE
# 2907                           Lvivvuhillia SE
#
#      Commodities (one commodity/row)          Status Production (volume)  \
# 1187                  Not applicable      Production              426.44
# 1186                  Not applicable      Production              987.02
# 1213                  Not applicable  Not applicable                 NaN
# 1214                  Not applicable      Production          160,627.00
# 1103                  Not applicable      Production            3,147.00
# 1104                  Not applicable      Production            1,233.00
# 1217                  Not applicable      Production                1.05
# 1218                  Not applicable      Production                 9.1
# 1209                  Not applicable  Not applicable                 NaN
# 1210                  Not applicable      Production          661,863.00
# 1140                  Not applicable      Production           14,300.00
# 1141                  Not applicable  Not applicable                 NaN
# 2910           Coal, Technical water      Production          267,000.00
# 2911           Coal, Technical water      Production          110,900.00
# 2912           Coal, Technical water      Production          141,000.00
# 2913           Coal, Technical water      Production           89,000.00
# 2906           Coal, Technical water      Production          184,000.00
# 2907           Coal, Technical water      Production          100,700.00
#
#                 Unit Production (value)        Currency   Country ISO Code   \
# 1187             NaN     Not applicable  Not applicable  Mongolia       MNG
# 1186             NaN     Not applicable  Not applicable  Mongolia       MNG
# 1213  Not applicable     Not applicable  Not applicable  Mongolia       MNG
# 1214             NaN     Not applicable  Not applicable  Mongolia       MNG
# 1103              Kg     Not applicable  Not applicable  Mongolia       MNG
# 1104              Kg     Not applicable  Not applicable  Mongolia       MNG
# 1217             NaN     Not applicable  Not applicable  Mongolia       MNG
# 1218             NaN     Not applicable  Not applicable  Mongolia       MNG
# 1209  Not applicable     Not applicable  Not applicable  Mongolia       MNG
# 1210             NaN     Not applicable  Not applicable  Mongolia       MNG
# 1140             NaN     Not applicable  Not applicable  Mongolia       MNG
# 1141  Not applicable     Not applicable  Not applicable  Mongolia       MNG
# 2910          Tonnes                NaN             NaN   Ukraine       UKR
# 2911             Sm3                NaN             NaN   Ukraine       UKR
# 2912          Tonnes                NaN             NaN   Ukraine       UKR
# 2913             Sm3                NaN             NaN   Ukraine       UKR
# 2906          Tonnes                NaN             NaN   Ukraine       UKR
# 2907             Sm3                NaN             NaN   Ukraine       UKR
#
#       Year  Start Date    End Date
# 1187  2020    1/1/2020  12/31/2020
# 1186  2020    1/1/2020  12/31/2020
# 1213  2020    1/1/2020  12/31/2020
# 1214  2020    1/1/2020  12/31/2020
# 1103  2020    1/1/2020  12/31/2020
# 1104  2020    1/1/2020  12/31/2020
# 1217  2020    1/1/2020  12/31/2020
# 1218  2020    1/1/2020  12/31/2020
# 1209  2020    1/1/2020  12/31/2020
# 1210  2020    1/1/2020  12/31/2020
# 1140  2020    1/1/2020  12/31/2020
# 1141  2020    1/1/2020  12/31/2020
# 2910  2020  2020-01-01  2020-12-31
# 2911  2020  2020-01-01  2020-12-31
# 2912  2020  2020-01-01  2020-12-31
# 2913  2020  2020-01-01  2020-12-31
# 2906  2020  2020-01-01  2020-12-31
# 2907  2020  2020-01-01  2020-12-31

# %%
print("Duplicates per commodity:")
dup_comm_aff = count_duplicates(df_part_3c, company_project_comm_duplicates, 'Commodities (one commodity/row)', 'duplicates_per_commodity')
dup_comm_aff
# Out:
# Duplicates per commodity:
#     Commodities (one commodity/row)  duplicates_per_commodity
# 0             Coal, Technical water                         6
# 1   Commodities (one commodity/row)                        16
# 2                        Condensate                         2
# 3                  Crude oil (2709)                        23
# 4                       Gold (7108)                         4
# 5                  Limestone (2521)                         4
# 6                Natural gas (2711)                         4
# 7                     Nickel (2604)                         2
# 8                    Non applicable                         2
# 9                    Not applicable                        29
# 10                    Not available                       441
# 11                     Not reported                         8
# 12                     Other (2617)                        11

# %% [markdown]
# #### Implications
# - there are a significant number of duplicates that have the same Full project name and Affiliated companies in the data (2416)
# - even when accounting for the commodity being reported in the project, there are still a significant number of dupliates (610) that have the same Full project name, Affiliated companies, and commodities being reported
# - most of these duplicates may be attributed to commodities not being part of the information provided (464/610)

# %% [markdown]
# ### Consistency

# %% [markdown]
# ### All companies or agencies in company data (Part 5) exist in the Reporting companies' agencies list (Part 3a)
# #### Expectations
# - We expect that every company or agency mentioned in the company dataset should have a corresponding entry in either the reporting companies dataset or the reporting government entities dataset.
# - This is based on the assumption that the company data are associated with existing companies and/or government entities and any discrepancies could indicate data inconsistencies or missing information.
#
# #### Assumptions
# - The company and agency datasets are comprehensive and contain information about all relevant companies and government entities.
# - The naming conventions for companies and agencies in the company report match those in the company and government entities tab/dataset.
# - Each entry in the company report corresponds to a valid and existing company or agency.
#
# #### Results

# %%
def count_missing(main_df, missing_df, field, name):
    return main_df[missing_df].groupby(field).size().reset_index(name=name)

# %%
all_companies = df_part_5['Company'].isin(df_part_3a['Full company name'])
all_companies_reverse = df_part_3a['Full company name'].isin(df_part_5['Company'])
all_agencies = df_part_5['Company'].isin(df_part_3b['Full name of agency'])
all_agencies_reverse = df_part_3b['Full name of agency'].isin(df_part_5['Company'])
all_names = (
    df_part_5['Company'].isin(df_part_3a['Full company name']) | 
    df_part_5['Company'].isin(df_part_3b['Full name of agency'])
)

# %%
# Check if all companies in the Company data is in the Reporting companies list
print(f'All company names in the Company data are present in the Reporting companies list: {all_companies.all()}')
print(f'All company names in the Reporting companies list are present in the Company data: {all_companies_reverse.all()}')
# Out:
# All company names in the Company data are present in the Reporting companies list: False
# All company names in the Reporting companies list are present in the Company data: False

# %%
# Get list of companies in Company data that is not in the Reporting companies list
missing_companies = df_part_5[~all_companies].reset_index(drop=True)
missing_companies
# Out:
#                                                Company  \
# 0                           Abid Hassan Zadran Limited
# 1                           Abid Hassan Zadran Limited
# 2                           Abid Hassan Zadran Limited
# 3                           Abid Hassan Zadran Limited
# 4     Afghan Shiinink, Mines Extraction and Processing
# ...                                                ...
# 1910                             Royal Dutch Shell plc
# 1911                             Royal Dutch Shell plc
# 1912                             Royal Dutch Shell plc
# 1913                             Royal Dutch Shell plc
# 1914                             Royal Dutch Shell plc
#
#                              Government entity  \
# 0     Ministry of Finance (Customs Department)
# 1     Ministry of Finance (Customs Department)
# 2     Ministry of Finance (Customs Department)
# 3     Ministry of Finance (Customs Department)
# 4     Ministry of Finance (Customs Department)
# ...                                        ...
# 1910                 Oil & Gas Authority (OGA)
# 1911                 Oil & Gas Authority (OGA)
# 1912                 Oil & Gas Authority (OGA)
# 1913                 Oil & Gas Authority (OGA)
# 1914                 Oil & Gas Authority (OGA)
#
#                  Revenue stream name Levied on project (Y/N)  \
# 0                        Export Duty                      No
# 1               Fixed Tax on Exports                      No
# 2               Other Fee on Exports                      No
# 3                 Penalty on Exports                      No
# 4                        Export Duty                      No
# ...                              ...                     ...
# 1910  Oil & Gas Authority (OGA) Levy                     Yes
# 1911  Oil & Gas Authority (OGA) Levy                     Yes
# 1912  Oil & Gas Authority (OGA) Levy                     Yes
# 1913  Oil & Gas Authority (OGA) Levy                     Yes
# 1914  Oil & Gas Authority (OGA) Levy                     Yes
#
#      Reported by project (Y/N) Project name Reporting currency  Revenue value  \
# 0                           No          NaN                AFN      1192667.0
# 1                           No          NaN                AFN       143121.0
# 2                           No          NaN                AFN        25954.0
# 3                           No          NaN                AFN         6350.0
# 4                           No          NaN                AFN        35222.0
# ...                        ...          ...                ...            ...
# 1910                       Yes          P84                GBP        99220.0
# 1911                       Yes          P88                GBP        99220.0
# 1912                       Yes         P886                GBP        99220.0
# 1913                       Yes          P96                GBP        99220.0
# 1914                       Yes          P98                GBP        11768.0
#
#      Payment made in-kind (Y/N) In-kind volume (if applicable)  \
# 0                            No                 Not applicable
# 1                            No                 Not applicable
# 2                            No                 Not applicable
# 3                            No                 Not applicable
# 4                            No                 Not applicable
# ...                         ...                            ...
# 1910             Not applicable                 Not applicable
# 1911             Not applicable                 Not applicable
# 1912             Not applicable                 Not applicable
# 1913             Not applicable                 Not applicable
# 1914             Not applicable                 Not applicable
#
#      Unit (if applicable) Comments         Country ISO Code    Year  \
# 0          Not applicable      NaN     Afghanistan      AFG  2018.0
# 1          Not applicable      NaN     Afghanistan      AFG  2018.0
# 2          Not applicable      NaN     Afghanistan      AFG  2018.0
# 3          Not applicable      NaN     Afghanistan      AFG  2018.0
# 4          Not applicable      NaN     Afghanistan      AFG  2018.0
# ...                   ...      ...             ...      ...     ...
# 1910       Not applicable      NaN  United Kingdom      GBR  2021.0
# 1911       Not applicable      NaN  United Kingdom      GBR  2021.0
# 1912       Not applicable      NaN  United Kingdom      GBR  2021.0
# 1913       Not applicable      NaN  United Kingdom      GBR  2021.0
# 1914       Not applicable      NaN  United Kingdom      GBR  2021.0
#
#       Start Date    End Date
# 0     2017-12-21  2018-12-20
# 1     2017-12-21  2018-12-20
# 2     2017-12-21  2018-12-20
# 3     2017-12-21  2018-12-20
# 4     2017-12-21  2018-12-20
# ...          ...         ...
# 1910  2021-01-01  2021-12-31
# 1911  2021-01-01  2021-12-31
# 1912  2021-01-01  2021-12-31
# 1913  2021-01-01  2021-12-31
# 1914  2021-01-01  2021-12-31
#
# [1915 rows x 17 columns]

# %%
# Get list of companies in Company data that is not in the Reporting companies list
missing_companies_reverse = df_part_3b[~all_companies_reverse].reset_index(drop=True)
missing_companies_reverse
# Out:
# /tmp/ipykernel_261395/2733678155.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   missing_companies_reverse = df_part_3b[~all_companies_reverse].reset_index(drop=True)
#                                   Full name of agency  \
# 0   Ministry of Mines and Petroleum (Revenue Depar...
# 1                   Ministry of Industry and Commerce
# 2   Société Nationale d’Investissement du Cameroun...
# 3          Direction Générale des Hydrocarbures (DGH)
# 4                               Localité de Bondoukou
# 5                    Ghana National Petroleum Company
# 6                                               Other
# 7                   Internal Revenue Department (IRD)
# 8                         Department of Trading (DoT)
# 9   Direction Générale des Douanes et des Droits I...
# 10                                 Other Govt. Agency
#
#                                       Agency type ID number (if applicable)  \
# 0                               Central goverment            Not applicable
# 1                               Central goverment            Not applicable
# 2   State-owned enterprises & public corporations                       NaN
# 3                               Central goverment            Non applicable
# 4                                Local government            Non applicable
# 5                               Central goverment                       NaN
# 6                                           Other                       NaN
# 7                               Central goverment            Not applicable
# 8                               Central goverment            Not applicable
# 9                              Central government                       NaN
# 10                                          Other                       NaN
#
#         Total reported                Country ISO Code    Year  Start Date  \
# 0              #ERROR!            Afghanistan      AFG  2019.0  2018-12-21
# 1              #ERROR!            Afghanistan      AFG  2019.0  2018-12-21
# 2       539,200,395.00               Cameroon      CMR  2017.0    1/1/2017
# 3     2,674,420,060.00          Cote d'Ivoire      CIV  2018.0  2018-01-01
# 4        19,449,399.00          Cote d'Ivoire      CIV  2018.0  2018-01-01
# 5              #ERROR!                  Ghana      GHA  2017.0  2017-01-01
# 6    51,191,621,914.04               Mongolia      MNG  2019.0    1/1/2019
# 7   353,671,807,113.44                Myanmar      MMR  2018.0    4/1/2017
# 8     4,559,476,231.00                Myanmar      MMR  2018.0    4/1/2017
# 9        Voir partie 4  Republic of the Congo      COG  2017.0  2017-01-01
# 10                 NaN               Tanzania      TZA  2018.0  2017-07-01
#
#       End Date
# 0   2019-12-20
# 1   2019-12-20
# 2   12/31/2017
# 3   2018-12-31
# 4   2018-12-31
# 5   2017-12-31
# 6   12/31/2019
# 7    3/31/2018
# 8    3/31/2018
# 9   2017-12-31
# 10  2018-06-30

# %%
# Count number of instances the missing companies appear in the Company data per year
missing_companies_count_pt = missing_companies.pivot_table(index=['Company', 'Country'], columns='Year', values='ISO Code', aggfunc='count', fill_value=0).reset_index()
missing_companies_count_pt
# Out:
# Year                                            Company      Country  2017.0  \
# 0                            Abid Hassan Zadran Limited  Afghanistan       0
# 1     Add new rows as necessary, right click the row...    Argentina       0
# 2      Afghan Shiinink, Mines Extraction and Processing  Afghanistan       0
# 3       Afghan Shinink, Mines Extraction and Processing  Afghanistan       0
# 4                     Afghan Talc Limited Joint Venture  Afghanistan       0
# ..                                                  ...          ...     ...
# 81                      محمد عیسی ولد آغا گل, محمد عیسی  Afghanistan       0
# 82                   محمد یونس ولد محمد عیسی, محمد یونس  Afghanistan       0
# 83    نصب ومنتاژیک دستگاه ریگریشن محمد سمیع Mohammad...  Afghanistan       0
# 84                              واثق ولد ملنگ خان, واثق  Afghanistan       0
# 85    پروژه انتقال پایپ لاین گاز تاپی TAPI Gas trans...  Afghanistan       0
#
# Year  2018.0  2019.0  2020.0  2021.0
# 0          4       4       0       0
# 1          1       0       0       0
# 2          4       0       0       0
# 3          4       0       0       0
# 4         13       0       0       0
# ..       ...     ...     ...     ...
# 81         0       2       0       0
# 82         3       1       0       0
# 83         1       0       0       0
# 84         0       2       0       0
# 85         1       0       0       0
#
# [86 rows x 7 columns]

# %%
missing_companies_count_grp = missing_companies.groupby(['Company', 'Country', 'Year'])['Company'].count().reset_index(name='Number of Instances')
missing_companies_count_grp
# Out:
#                                               Company      Country    Year  \
# 0                          Abid Hassan Zadran Limited  Afghanistan  2018.0
# 1                          Abid Hassan Zadran Limited  Afghanistan  2019.0
# 2   Add new rows as necessary, right click the row...    Argentina  2018.0
# 3    Afghan Shiinink, Mines Extraction and Processing  Afghanistan  2018.0
# 4     Afghan Shinink, Mines Extraction and Processing  Afghanistan  2018.0
# ..                                                ...          ...     ...
# 94                 محمد یونس ولد محمد عیسی, محمد یونس  Afghanistan  2018.0
# 95                 محمد یونس ولد محمد عیسی, محمد یونس  Afghanistan  2019.0
# 96  نصب ومنتاژیک دستگاه ریگریشن محمد سمیع Mohammad...  Afghanistan  2018.0
# 97                            واثق ولد ملنگ خان, واثق  Afghanistan  2019.0
# 98  پروژه انتقال پایپ لاین گاز تاپی TAPI Gas trans...  Afghanistan  2018.0
#
#     Number of Instances
# 0                     4
# 1                     4
# 2                     1
# 3                     4
# 4                     4
# ..                  ...
# 94                    3
# 95                    1
# 96                    1
# 97                    2
# 98                    1
#
# [99 rows x 4 columns]

# %%
# Check the number of instances the missing companies appear in the Company data per year for Afghanistan
missing_companies_count_pt[missing_companies_count_pt['Country'] == 'Afghanistan']
# Out:
# Year                                            Company      Country  2017.0  \
# 0                            Abid Hassan Zadran Limited  Afghanistan       0
# 2      Afghan Shiinink, Mines Extraction and Processing  Afghanistan       0
# 3       Afghan Shinink, Mines Extraction and Processing  Afghanistan       0
# 4                     Afghan Talc Limited Joint Venture  Afghanistan       0
# 5                                         Amania Mining  Afghanistan       0
# ..                                                  ...          ...     ...
# 81                      محمد عیسی ولد آغا گل, محمد عیسی  Afghanistan       0
# 82                   محمد یونس ولد محمد عیسی, محمد یونس  Afghanistan       0
# 83    نصب ومنتاژیک دستگاه ریگریشن محمد سمیع Mohammad...  Afghanistan       0
# 84                              واثق ولد ملنگ خان, واثق  Afghanistan       0
# 85    پروژه انتقال پایپ لاین گاز تاپی TAPI Gas trans...  Afghanistan       0
#
# Year  2018.0  2019.0  2020.0  2021.0
# 0          4       4       0       0
# 2          4       0       0       0
# 3          4       0       0       0
# 4         13       0       0       0
# 5          0     804       0       0
# ..       ...     ...     ...     ...
# 81         0       2       0       0
# 82         3       1       0       0
# 83         1       0       0       0
# 84         0       2       0       0
# 85         1       0       0       0
#
# [72 rows x 7 columns]

# %%
missing_companies_count_grp[missing_companies_count_grp['Country'] == 'Afghanistan']
# Out:
#                                               Company      Country    Year  \
# 0                          Abid Hassan Zadran Limited  Afghanistan  2018.0
# 1                          Abid Hassan Zadran Limited  Afghanistan  2019.0
# 3    Afghan Shiinink, Mines Extraction and Processing  Afghanistan  2018.0
# 4     Afghan Shinink, Mines Extraction and Processing  Afghanistan  2018.0
# 5                   Afghan Talc Limited Joint Venture  Afghanistan  2018.0
# ..                                                ...          ...     ...
# 94                 محمد یونس ولد محمد عیسی, محمد یونس  Afghanistan  2018.0
# 95                 محمد یونس ولد محمد عیسی, محمد یونس  Afghanistan  2019.0
# 96  نصب ومنتاژیک دستگاه ریگریشن محمد سمیع Mohammad...  Afghanistan  2018.0
# 97                            واثق ولد ملنگ خان, واثق  Afghanistan  2019.0
# 98  پروژه انتقال پایپ لاین گاز تاپی TAPI Gas trans...  Afghanistan  2018.0
#
#     Number of Instances
# 0                     4
# 1                     4
# 3                     4
# 4                     4
# 5                    13
# ..                  ...
# 94                    3
# 95                    1
# 96                    1
# 97                    2
# 98                    1
#
# [80 rows x 4 columns]

# %%
# Check the number of instances the missing companies appear in the Company data per year for Afghanistan in 2019
missing_companies_count_grp[missing_companies_count_grp['Year'] == '2019']
# Out:
# Empty DataFrame
# Columns: [Company, Country, Year, Number of Instances]
# Index: []

# %%
# Missing company instances per country
missing_companies.groupby('Country').size().reset_index(name='Instances per country')
# Out:
#           Country  Instances per country
# 0     Afghanistan                   1745
# 1         Albania                     23
# 2       Argentina                      1
# 3        Cameroon                      1
# 4   Cote d'Ivoire                      7
# 5         Germany                     14
# 6        Mongolia                      2
# 7  United Kingdom                     92

# %%
# Missing company instances per year
missing_companies.groupby('Year').size().reset_index(name='Instances per year')
# Out:
#      Year  Instances per year
# 0  2017.0                  23
# 1  2018.0                 148
# 2  2019.0                1609
# 3  2020.0                   1
# 4  2021.0                  92

# %%
# Missing company instances per country and year
print("Missing company instances per country and year")
missing_companies.pivot_table(index=['Country'], columns='Year', values='Company', aggfunc='count', fill_value=0).reset_index()
# Out:
# Missing company instances per country and year
# Year         Country  2017.0  2018.0  2019.0  2020.0  2021.0
# 0        Afghanistan       0     129    1601       0       0
# 1            Albania      11      12       0       0       0
# 2          Argentina       0       1       0       0       0
# 3           Cameroon       1       0       0       0       0
# 4      Cote d'Ivoire       7       0       0       0       0
# 5            Germany       4       4       5       1       0
# 6           Mongolia       0       2       0       0       0
# 7     United Kingdom       0       0       0       0      92

# %%
# Now let's look at unique companies
missing_companies_unique = missing_companies.drop_duplicates(subset=['Company', 'Country']).reset_index(drop=True)
missing_companies_unique
# Out:
#                                               Company  \
# 0                          Abid Hassan Zadran Limited
# 1    Afghan Shiinink, Mines Extraction and Processing
# 2     Afghan Shinink, Mines Extraction and Processing
# 3                   Afghan Talc Limited Joint Venture
# 4                                Arif Shahaab Limited
# ..                                                ...
# 89  Any additional information that is not eligibl...
# 90    Unilateral Disclosure for Other Minerals sector
# 91     Unilateral Disclosure for Gems and Jade sector
# 92  Social contributions - not received by governm...
# 93                              Royal Dutch Shell plc
#
#                            Government entity  \
# 0   Ministry of Finance (Customs Department)
# 1   Ministry of Finance (Customs Department)
# 2   Ministry of Finance (Customs Department)
# 3   Ministry of Finance (Customs Department)
# 4   Ministry of Finance (Customs Department)
# ..                                       ...
# 89                                       NaN
# 90                                       NaN
# 91                                       NaN
# 92                                       NaN
# 93  Her Majesty’s Revenue and Customs (HMRC)
#
#                                   Revenue stream name Levied on project (Y/N)  \
# 0                                         Export Duty                      No
# 1                                         Export Duty                      No
# 2                                         Export Duty                      No
# 3                                         Export Duty                      No
# 4                                         Export Duty                      No
# ..                                                ...                     ...
# 89                                                NaN                     NaN
# 90                                                NaN                     NaN
# 91                                                NaN                     NaN
# 92                                                NaN                     NaN
# 93  Ring Fence CT and Supplementary Charge (RFCT &...          Not applicable
#
#    Reported by project (Y/N)    Project name Reporting currency  \
# 0                         No             NaN                AFN
# 1                         No             NaN                AFN
# 2                         No             NaN                AFN
# 3                         No             NaN                AFN
# 4                         No             NaN                AFN
# ..                       ...             ...                ...
# 89                       NaN             NaN                NaN
# 90                       MCD  Customs Duties          604935287
# 91                       MCD  Customs Duties          424622051
# 92                       NaN             NaN                NaN
# 93            Not applicable             NaN                GBP
#
#     Revenue value Payment made in-kind (Y/N) In-kind volume (if applicable)  \
# 0       1192667.0                         No                 Not applicable
# 1         35222.0                         No                 Not applicable
# 2         61336.0                         No                 Not applicable
# 3        316251.0                         No                 Not applicable
# 4       1085044.0                         No                 Not applicable
# ..            ...                        ...                            ...
# 89            NaN                        NaN                            NaN
# 90            NaN                        NaN                            NaN
# 91            NaN                        NaN                            NaN
# 92            NaN                        NaN                            NaN
# 93    -49928652.0             Not applicable                 Not applicable
#
#    Unit (if applicable) Comments         Country ISO Code    Year  Start Date  \
# 0        Not applicable      NaN     Afghanistan      AFG  2018.0  2017-12-21
# 1        Not applicable      NaN     Afghanistan      AFG  2018.0  2017-12-21
# 2        Not applicable      NaN     Afghanistan      AFG  2018.0  2017-12-21
# 3        Not applicable      NaN     Afghanistan      AFG  2018.0  2017-12-21
# 4        Not applicable      NaN     Afghanistan      AFG  2018.0  2017-12-21
# ..                  ...      ...             ...      ...     ...         ...
# 89                  NaN      NaN             NaN      NaN     NaN         NaN
# 90                  NaN      NaN             NaN      NaN     NaN         NaN
# 91                  NaN      NaN             NaN      NaN     NaN         NaN
# 92                  NaN      NaN             NaN      NaN     NaN         NaN
# 93       Not applicable      NaN  United Kingdom      GBR  2021.0  2021-01-01
#
#       End Date
# 0   2018-12-20
# 1   2018-12-20
# 2   2018-12-20
# 3   2018-12-20
# 4   2018-12-20
# ..         ...
# 89         NaN
# 90         NaN
# 91         NaN
# 92         NaN
# 93  2021-12-31
#
# [94 rows x 17 columns]

# %%
# Count number of instances the unique missing companies appear in the Company data per year
print("Number of instances the unique missing companies appear in the Company data per year")
missing_companies_unique_count_grp = missing_companies.groupby(['Company', 'Country', 'Year'])['Company'].count().reset_index(name='Number of Instances')
missing_companies_unique_count_grp
# Out:
# Number of instances the unique missing companies appear in the Company data per year
#                                               Company      Country    Year  \
# 0                          Abid Hassan Zadran Limited  Afghanistan  2018.0
# 1                          Abid Hassan Zadran Limited  Afghanistan  2019.0
# 2   Add new rows as necessary, right click the row...    Argentina  2018.0
# 3    Afghan Shiinink, Mines Extraction and Processing  Afghanistan  2018.0
# 4     Afghan Shinink, Mines Extraction and Processing  Afghanistan  2018.0
# ..                                                ...          ...     ...
# 94                 محمد یونس ولد محمد عیسی, محمد یونس  Afghanistan  2018.0
# 95                 محمد یونس ولد محمد عیسی, محمد یونس  Afghanistan  2019.0
# 96  نصب ومنتاژیک دستگاه ریگریشن محمد سمیع Mohammad...  Afghanistan  2018.0
# 97                            واثق ولد ملنگ خان, واثق  Afghanistan  2019.0
# 98  پروژه انتقال پایپ لاین گاز تاپی TAPI Gas trans...  Afghanistan  2018.0
#
#     Number of Instances
# 0                     4
# 1                     4
# 2                     1
# 3                     4
# 4                     4
# ..                  ...
# 94                    3
# 95                    1
# 96                    1
# 97                    2
# 98                    1
#
# [99 rows x 4 columns]

# %%
# Number of unique companies per country that appear in the Company data but not in the Reporting companies list 
missing_companies_unique_count_grp.pivot_table(index=['Country'], values='Company', aggfunc='nunique', fill_value=0, dropna=False)
# Out:
#                 Company
# Country
# Afghanistan          72
# Albania               5
# Argentina             1
# Cameroon              1
# Cote d'Ivoire         3
# Germany               2
# Mongolia              1
# United Kingdom        1

# %%
missing_companies[missing_companies['Country'] == "Cote d'Ivoire"]['Company'].nunique(dropna=False)
# Out:
# 3

# %%
missing_companies_unique_count_grp[missing_companies_unique_count_grp['Country'] == "Cote d'Ivoire"]
# Out:
#                                               Company        Country    Year  \
# 12                                   Autres acheteurs  Cote d'Ivoire  2017.0
# 13  Autres sociétés non incluses dans le périmètre...  Cote d'Ivoire  2017.0
# 30                              LA MANCHA CI (France)  Cote d'Ivoire  2017.0
#
#     Number of Instances
# 12                    1
# 13                    2
# 30                    4

# %%
# Number of unique companies per year that appear in the Company data but not in the Reporting companies list 
missing_companies_unique_count_grp.pivot_table(index=['Year'], values='Company', aggfunc='nunique', fill_value=0, dropna=False)
# Out:
#         Company
# Year
# 2017.0        9
# 2018.0       33
# 2019.0       55
# 2020.0        1
# 2021.0        1

# %%
missing_companies[missing_companies['Year'] == "2017"]['Company'].nunique(dropna=False)
# Out:
# 0

# %%
missing_companies_unique_count_grp[missing_companies_unique_count_grp['Year'] == "2017"]
# Out:
# Empty DataFrame
# Columns: [Company, Country, Year, Number of Instances]
# Index: []

# %% [markdown]
# ### Consistent company name-company ID pair over time
#
# #### Expectations
# - We expect that the pairing of company names with their corresponding company IDs remain consistent over time.
# - This expectation is founded on the assumption that company names and IDs serve as stable and reliable identifiers for companies, ensuring their continuity and uniqueness over time.
#
# #### Assumptions
# - Each company name is assumed to be consistently associated with a specific company ID across different years.
# - Company IDs are assumed to be unique and not reassigned to different companies over time.
#
# #### Results

# %%
# List company names per country with the ids they have for the year

pt_name_id_over_time = df_part_3a.pivot_table(index=['Full company name','Country'], columns='Year', values='Company ID number', aggfunc='first', fill_value=0)

# %%
print("List company names per country with the ids they have for the year")
pt_name_id_over_time
# Out:
# List company names per country with the ids they have for the year
# Year                                                     2017        2018  \
# Full company name                         Country
# "BEAT GENERATION" SHPK                    Albania           0  L42423012I
# "Balkan Green Energy" sh.p.k( ish ESEGEI) Albania           0  K71624026M
# "Chaarat Kapan" CJSC                      Armenia           0     9416902
# "D & A" Sh.P.K                            Albania           0  K11829502V
# "DITEKO" sh.p.k                           Albania           0  K92108022E
# ...                                                       ...         ...
# “Teghout” CJSC                            Armenia           0     2700773
# “Vardani Zartonk” LLC                     Armenia           0     9414399
# “Vayk Gold” LLC                           Armenia           0      114369
# “Zangezur Copper-Molybdenum Combine” CJSC Armenia           0     9400818
# ”DITEKO” sh.p.k                           Albania  K92108022E           0
#
# Year                                                  2019 2020 2021
# Full company name                         Country
# "BEAT GENERATION" SHPK                    Albania        0    0    0
# "Balkan Green Energy" sh.p.k( ish ESEGEI) Albania        0    0    0
# "Chaarat Kapan" CJSC                      Armenia  9416902    0    0
# "D & A" Sh.P.K                            Albania        0    0    0
# "DITEKO" sh.p.k                           Albania        0    0    0
# ...                                                    ...  ...  ...
# “Teghout” CJSC                            Armenia  2700773    0    0
# “Vardani Zartonk” LLC                     Armenia  9414399    0    0
# “Vayk Gold” LLC                           Armenia   114369    0    0
# “Zangezur Copper-Molybdenum Combine” CJSC Armenia  9400818    0    0
# ”DITEKO” sh.p.k                           Albania        0    0    0
#
# [2756 rows x 5 columns]

# %%
# Define a function to check if all non-zero values are the same in a row
def check_same_nonzero(row):
    nonzero_values = row[row != 0]
    return len(nonzero_values) == 0 or len(set(nonzero_values)) == 1

# Apply the function row-wise to check if values are the same
result = pt_name_id_over_time.apply(check_same_nonzero, axis=1)

# Filter rows where the result is False
rows_with_false_result = pt_name_id_over_time[~result]

print('Companies with changing/different IDs over time')
rows_with_false_result.sort_values(by=['Full company name', 'Country'])
# Out:
# Companies with changing/different IDs over time
# Year                                                                       2017  \
# Full company name                        Country
# ABOURACHID Mining                        Chad                  Not communicated
# AGBAOU GOLD OPERATIONS                   Cote d'Ivoire                1273929 F
# Apache Corporation                       United Kingdom                       0
# Belema Oil Producing Limited             Nigeria                  Not available
# Breedon Group PLC                        United Kingdom                       0
# CADERAC. SA                              Cote d'Ivoire                9910850 P
# CGCOC Group                              Chad                  Not communicated
# CapeOmega AS                             Norway                       913776712
# Cemex UK Materials Ltd                   United Kingdom                       0
# Chad construction Materials S.A          Chad                  Not communicated
# Cliveden Petroleum                       Chad                  Not communicated
# DNO North Sea (Norge) AS                 Norway                               0
# DTP                                      Chad                  Not communicated
# Dubri Oil Company Limited                Nigeria                        RC92967
# ETEP                                     Chad                  Not communicated
# Energia Limited                          Nigeria                       RC424454
# Equinor Nigeria Energy Company Limited   Nigeria                       RC186901
# ExxonMobil International Ltd             United Kingdom                       0
# Famfa Oil Limited                        Nigeria                       RC172534
# Frontier Oil Limited                     Nigeria                       RC411784
# GS CALTEX SINGAPORE PTE. LTD.            Iraq                    Not applicable
# Glencore Energy UK Limited               Chad                  Not communicated
# Glencore Exploration (DOB/DOI)           Chad                  Not communicated
# Glencore Exploration (Doséo/Borogop)     Chad                  Not communicated
# HEC Lanabregas                           Albania                     J62005002O
# Holcim (Deutschland) GmbH                Germany                      HRB 66680
# INEOS Industries                         United Kingdom                       0
# Jinziang Quarry Co. Ltd                  Nigeria                      RC1143506
# MASHAK PETROLEUM                         Chad                  Not communicated
# Manejem Company Ltd                      Chad                  Not communicated
# Meige International                      Chad                                NC
# Moni Pulo Limited                        Nigeria                       RC183333
# Neconde Energy Limited                   Nigeria                        RC20841
# Network Exploration & Production Limited Nigeria                  Not available
# Oriental Energy Resources Limited        Nigeria                       RC153400
# PGNiG Upstream Norway AS                 Norway                               0
# Petra Quarries Ltd                       Nigeria                       RC744300
# Petronas                                 Chad                  Not communicated
# Pillar Oil Limited                       Nigeria                       RC316743
# Platform Petroleum Limited               Nigeria                  Not available
# Purechem Industries Limited              Nigeria                       RC115657
# ROXGOLD SANU SA                          Burkina Faso                         0
# SAGE North Sea Ltd                       United Kingdom                       0
# SOGEA SATOM                              Chad                  Not communicated
# SOGEM                                    Chad                  Not communicated
# Seplat Petroleum Development Company     Nigeria                       RC824838
# Severn Sands Group Ltd                   United Kingdom                       0
# Shoreline Natural Resources Limited      Nigeria                       RC927144
# Star Deep Water Petroleum Limited        Nigeria                       RC299998
# TEKTON MINERAL                           Chad                  Not communicated
# TOTAL E & P                              Cote d'Ivoire   1218746 Q\r\n1110267 G
# TULLOW CI                                Cote d'Ivoire                1647352 K
# The Banks Group                          United Kingdom                       0
# Waldorf Production UK Ltd                United Kingdom                       0
# Zeberced Limited                         Nigeria                       RC699920
#
# Year                                                                                       2018  \
# Full company name                        Country
# ABOURACHID Mining                        Chad                                     Not available
# AGBAOU GOLD OPERATIONS                   Cote d'Ivoire                                 1273929F
# Apache Corporation                       United Kingdom                                 4614761
# Belema Oil Producing Limited             Nigeria                                        1087839
# Breedon Group PLC                        United Kingdom                                       0
# CADERAC. SA                              Cote d'Ivoire                                 9910850P
# CGCOC Group                              Chad                                     Not available
# CapeOmega AS                             Norway                                       913776712
# Cemex UK Materials Ltd                   United Kingdom                                 4895833
# Chad construction Materials S.A          Chad                                     Not available
# Cliveden Petroleum                       Chad                                     Not available
# DNO North Sea (Norge) AS                 Norway                                      989399071
# DTP                                      Chad                                     Not available
# Dubri Oil Company Limited                Nigeria                                          92967
# ETEP                                     Chad                                     Not available
# Energia Limited                          Nigeria                                         424454
# Equinor Nigeria Energy Company Limited   Nigeria                                         186901
# ExxonMobil International Ltd             United Kingdom                                  207426
# Famfa Oil Limited                        Nigeria                                         172534
# Frontier Oil Limited                     Nigeria                                         411784
# GS CALTEX SINGAPORE PTE. LTD.            Iraq                                          FC022220
# Glencore Energy UK Limited               Chad                                     Not available
# Glencore Exploration (DOB/DOI)           Chad                                     Not available
# Glencore Exploration (Doséo/Borogop)     Chad                                     Not available
# HEC Lanabregas                           Albania                                     L41918001E
# Holcim (Deutschland) GmbH                Germany                                      HRB 66680
# INEOS Industries                         United Kingdom  SC200459, 09121775, 06981897, 10660338
# Jinziang Quarry Co. Ltd                  Nigeria                                        1143506
# MASHAK PETROLEUM                         Chad                                     Not available
# Manejem Company Ltd                      Chad                                     Not available
# Meige International                      Chad                                     Not available
# Moni Pulo Limited                        Nigeria                                         183333
# Neconde Energy Limited                   Nigeria                                         923655
# Network Exploration & Production Limited Nigeria                                         403841
# Oriental Energy Resources Limited        Nigeria                                         153400
# PGNiG Upstream Norway AS                 Norway                                      991317155
# Petra Quarries Ltd                       Nigeria                                         744300
# Petronas                                 Chad                                     Not available
# Pillar Oil Limited                       Nigeria                                         316743
# Platform Petroleum Limited               Nigeria                                         415507
# Purechem Industries Limited              Nigeria                                         115657
# ROXGOLD SANU SA                          Burkina Faso                                 00060700T
# SAGE North Sea Ltd                       United Kingdom                                       0
# SOGEA SATOM                              Chad                                     Not available
# SOGEM                                    Chad                                     Not available
# Seplat Petroleum Development Company     Nigeria                                         824838
# Severn Sands Group Ltd                   United Kingdom                                       0
# Shoreline Natural Resources Limited      Nigeria                                         927144
# Star Deep Water Petroleum Limited        Nigeria                                         299998
# TEKTON MINERAL                           Chad                                     Not available
# TOTAL E & P                              Cote d'Ivoire                   1110267 G\r\n1645585 U
# TULLOW CI                                Cote d'Ivoire                     1647352K\r\n0730077M
# The Banks Group                          United Kingdom                                11269831
# Waldorf Production UK Ltd                United Kingdom                                       0
# Zeberced Limited                         Nigeria                                         699920
#
# Year                                                                                       2019  \
# Full company name                        Country
# ABOURACHID Mining                        Chad                                                 0
# AGBAOU GOLD OPERATIONS                   Cote d'Ivoire                                        0
# Apache Corporation                       United Kingdom                                 4614761
# Belema Oil Producing Limited             Nigeria                                              0
# Breedon Group PLC                        United Kingdom                                       0
# CADERAC. SA                              Cote d'Ivoire                                        0
# CGCOC Group                              Chad                                                 0
# CapeOmega AS                             Norway                                       995152142
# Cemex UK Materials Ltd                   United Kingdom                                 4895833
# Chad construction Materials S.A          Chad                                                 0
# Cliveden Petroleum                       Chad                                                 0
# DNO North Sea (Norge) AS                 Norway                                       989399071
# DTP                                      Chad                                                 0
# Dubri Oil Company Limited                Nigeria                                              0
# ETEP                                     Chad                                                 0
# Energia Limited                          Nigeria                                              0
# Equinor Nigeria Energy Company Limited   Nigeria                                              0
# ExxonMobil International Ltd             United Kingdom                                  207426
# Famfa Oil Limited                        Nigeria                                              0
# Frontier Oil Limited                     Nigeria                                              0
# GS CALTEX SINGAPORE PTE. LTD.            Iraq                                                 0
# Glencore Energy UK Limited               Chad                                                 0
# Glencore Exploration (DOB/DOI)           Chad                                                 0
# Glencore Exploration (Doséo/Borogop)     Chad                                                 0
# HEC Lanabregas                           Albania                                              0
# Holcim (Deutschland) GmbH                Germany                                      HRB 66680
# INEOS Industries                         United Kingdom  SC200459, 09121775, 06981897, 10660338
# Jinziang Quarry Co. Ltd                  Nigeria                                              0
# MASHAK PETROLEUM                         Chad                                                 0
# Manejem Company Ltd                      Chad                                                 0
# Meige International                      Chad                                                 0
# Moni Pulo Limited                        Nigeria                                              0
# Neconde Energy Limited                   Nigeria                                              0
# Network Exploration & Production Limited Nigeria                                              0
# Oriental Energy Resources Limited        Nigeria                                              0
# PGNiG Upstream Norway AS                 Norway                                       991317155
# Petra Quarries Ltd                       Nigeria                                              0
# Petronas                                 Chad                                                 0
# Pillar Oil Limited                       Nigeria                                              0
# Platform Petroleum Limited               Nigeria                                              0
# Purechem Industries Limited              Nigeria                                              0
# ROXGOLD SANU SA                          Burkina Faso                                 00060700T
# SAGE North Sea Ltd                       United Kingdom                                FC033971
# SOGEA SATOM                              Chad                                                 0
# SOGEM                                    Chad                                                 0
# Seplat Petroleum Development Company     Nigeria                                              0
# Severn Sands Group Ltd                   United Kingdom                                       0
# Shoreline Natural Resources Limited      Nigeria                                              0
# Star Deep Water Petroleum Limited        Nigeria                                              0
# TEKTON MINERAL                           Chad                                                 0
# TOTAL E & P                              Cote d'Ivoire                                        0
# TULLOW CI                                Cote d'Ivoire                                        0
# The Banks Group                          United Kingdom                                11269831
# Waldorf Production UK Ltd                United Kingdom                                       0
# Zeberced Limited                         Nigeria                                              0
#
# Year                                                                                       2020  \
# Full company name                        Country
# ABOURACHID Mining                        Chad                                                 0
# AGBAOU GOLD OPERATIONS                   Cote d'Ivoire                                        0
# Apache Corporation                       United Kingdom                                 4614761
# Belema Oil Producing Limited             Nigeria                                              0
# Breedon Group PLC                        United Kingdom                                   98465
# CADERAC. SA                              Cote d'Ivoire                                        0
# CGCOC Group                              Chad                                                 0
# CapeOmega AS                             Norway                                               0
# Cemex UK Materials Ltd                   United Kingdom                                 4895833
# Chad construction Materials S.A          Chad                                                 0
# Cliveden Petroleum                       Chad                                                 0
# DNO North Sea (Norge) AS                 Norway                                               0
# DTP                                      Chad                                                 0
# Dubri Oil Company Limited                Nigeria                                              0
# ETEP                                     Chad                                                 0
# Energia Limited                          Nigeria                                              0
# Equinor Nigeria Energy Company Limited   Nigeria                                              0
# ExxonMobil International Ltd             United Kingdom                                  207426
# Famfa Oil Limited                        Nigeria                                              0
# Frontier Oil Limited                     Nigeria                                              0
# GS CALTEX SINGAPORE PTE. LTD.            Iraq                                                 0
# Glencore Energy UK Limited               Chad                                                 0
# Glencore Exploration (DOB/DOI)           Chad                                                 0
# Glencore Exploration (Doséo/Borogop)     Chad                                                 0
# HEC Lanabregas                           Albania                                              0
# Holcim (Deutschland) GmbH                Germany                                    HRB 139 449
# INEOS Industries                         United Kingdom  SC200459, 09121775, 06981897, 10660338
# Jinziang Quarry Co. Ltd                  Nigeria                                              0
# MASHAK PETROLEUM                         Chad                                                 0
# Manejem Company Ltd                      Chad                                                 0
# Meige International                      Chad                                                 0
# Moni Pulo Limited                        Nigeria                                              0
# Neconde Energy Limited                   Nigeria                                              0
# Network Exploration & Production Limited Nigeria                                              0
# Oriental Energy Resources Limited        Nigeria                                              0
# PGNiG Upstream Norway AS                 Norway                                               0
# Petra Quarries Ltd                       Nigeria                                              0
# Petronas                                 Chad                                                 0
# Pillar Oil Limited                       Nigeria                                              0
# Platform Petroleum Limited               Nigeria                                              0
# Purechem Industries Limited              Nigeria                                              0
# ROXGOLD SANU SA                          Burkina Faso                                00060700 T
# SAGE North Sea Ltd                       United Kingdom                                FC033971
# SOGEA SATOM                              Chad                                                 0
# SOGEM                                    Chad                                                 0
# Seplat Petroleum Development Company     Nigeria                                              0
# Severn Sands Group Ltd                   United Kingdom                                10696315
# Shoreline Natural Resources Limited      Nigeria                                              0
# Star Deep Water Petroleum Limited        Nigeria                                              0
# TEKTON MINERAL                           Chad                                                 0
# TOTAL E & P                              Cote d'Ivoire                                        0
# TULLOW CI                                Cote d'Ivoire                                        0
# The Banks Group                          United Kingdom                                11269831
# Waldorf Production UK Ltd                United Kingdom                                11957078
# Zeberced Limited                         Nigeria                                              0
#
# Year                                                                                 2021
# Full company name                        Country
# ABOURACHID Mining                        Chad                                           0
# AGBAOU GOLD OPERATIONS                   Cote d'Ivoire                                  0
# Apache Corporation                       United Kingdom  07720972\r\n04614761\r\nFC005975
# Belema Oil Producing Limited             Nigeria                                        0
# Breedon Group PLC                        United Kingdom                      Jersey 98465
# CADERAC. SA                              Cote d'Ivoire                                  0
# CGCOC Group                              Chad                                           0
# CapeOmega AS                             Norway                                         0
# Cemex UK Materials Ltd                   United Kingdom                            658390
# Chad construction Materials S.A          Chad                                           0
# Cliveden Petroleum                       Chad                                           0
# DNO North Sea (Norge) AS                 Norway                                         0
# DTP                                      Chad                                           0
# Dubri Oil Company Limited                Nigeria                                        0
# ETEP                                     Chad                                           0
# Energia Limited                          Nigeria                                        0
# Equinor Nigeria Energy Company Limited   Nigeria                                        0
# ExxonMobil International Ltd             United Kingdom              05458042\r\n00207426
# Famfa Oil Limited                        Nigeria                                        0
# Frontier Oil Limited                     Nigeria                                        0
# GS CALTEX SINGAPORE PTE. LTD.            Iraq                                           0
# Glencore Energy UK Limited               Chad                                           0
# Glencore Exploration (DOB/DOI)           Chad                                           0
# Glencore Exploration (Doséo/Borogop)     Chad                                           0
# HEC Lanabregas                           Albania                                        0
# Holcim (Deutschland) GmbH                Germany                                        0
# INEOS Industries                         United Kingdom  SC200459\r\n10660338\r\n09121775
# Jinziang Quarry Co. Ltd                  Nigeria                                        0
# MASHAK PETROLEUM                         Chad                                           0
# Manejem Company Ltd                      Chad                                           0
# Meige International                      Chad                                           0
# Moni Pulo Limited                        Nigeria                                        0
# Neconde Energy Limited                   Nigeria                                        0
# Network Exploration & Production Limited Nigeria                                        0
# Oriental Energy Resources Limited        Nigeria                                        0
# PGNiG Upstream Norway AS                 Norway                                         0
# Petra Quarries Ltd                       Nigeria                                        0
# Petronas                                 Chad                                           0
# Pillar Oil Limited                       Nigeria                                        0
# Platform Petroleum Limited               Nigeria                                        0
# Purechem Industries Limited              Nigeria                                        0
# ROXGOLD SANU SA                          Burkina Faso                                   0
# SAGE North Sea Ltd                       United Kingdom                          BR019059
# SOGEA SATOM                              Chad                                           0
# SOGEM                                    Chad                                           0
# Seplat Petroleum Development Company     Nigeria                                        0
# Severn Sands Group Ltd                   United Kingdom                           1675002
# Shoreline Natural Resources Limited      Nigeria                                        0
# Star Deep Water Petroleum Limited        Nigeria                                        0
# TEKTON MINERAL                           Chad                                           0
# TOTAL E & P                              Cote d'Ivoire                                  0
# TULLOW CI                                Cote d'Ivoire                                  0
# The Banks Group                          United Kingdom                           1247725
# Waldorf Production UK Ltd                United Kingdom                           5030838
# Zeberced Limited                         Nigeria                                        0

# %% [markdown]
# ### Government entities that appear in the Government revenues (Part 4) must also appear in the Reporting government entities list (Part 3b)
#
# #### Expectations
# - Government entities in the Government revenues list must appear in the Reporting government entities list and vice versa
#
# #### Assumptions
# - Government entities that report their revenues must have corresponding entries in the Reporting government entities list
#
# #### Results

# %%
# Get list of unique government entities in the Government revenues and Reporting government entities list

govt_entities_in_revenues = df_part_4[['Government entity', 'Country']].drop_duplicates().reset_index(drop=True)
govt_entities_in_revenues
# Out:
#                                      Government entity      Country
# 0             National Environmental Protection Agency  Afghanistan
# 1             Ministry of Finance (Customs Department)  Afghanistan
# 2    Ministry of Mines and Petroleum (Revenue Depar...  Afghanistan
# 3             Ministry of Finance (Revenue Department)  Afghanistan
# 4                     Bureau of Internal Revenue (BIR)  Philippines
# ..                                                 ...          ...
# 283                                  Ministry of Lands       Zambia
# 284                      Environmental Protection Fund       Zambia
# 285                                           ZCCM- IH       Zambia
# 286                                                IDC       Zambia
# 287                                                MoF       Zambia
#
# [288 rows x 2 columns]

# %%
govt_entities_in_report = df_part_3b[['Full name of agency', 'Country']].drop_duplicates().reset_index(drop=True)
govt_entities_in_report
# Out:
#                                    Full name of agency      Country
# 0             Ministry of Finance (Revenue Department)  Afghanistan
# 1             Ministry of Finance (Customs Department)  Afghanistan
# 2    Ministry of Mines and Petroleum (Revenue Depar...  Afghanistan
# 3             National Environmental Protection Agency  Afghanistan
# 4                    Ministry of Industry and Commerce  Afghanistan
# ..                                                 ...          ...
# 334                      Environmental Protection Fund       Zambia
# 335                                  Ministry of Lands       Zambia
# 336                                           ZCCM- IH       Zambia
# 337                                                IDC       Zambia
# 338                                                MoF       Zambia
#
# [339 rows x 2 columns]

# %%
govt_entities_merged_left = pd.merge(govt_entities_in_revenues, govt_entities_in_report, left_on=['Government entity', 'Country'], right_on=['Full name of agency', 'Country'], how='left', indicator=True, )
govt_entities_merged_left
# Out:
#                                      Government entity      Country  \
# 0             National Environmental Protection Agency  Afghanistan
# 1             Ministry of Finance (Customs Department)  Afghanistan
# 2    Ministry of Mines and Petroleum (Revenue Depar...  Afghanistan
# 3             Ministry of Finance (Revenue Department)  Afghanistan
# 4                     Bureau of Internal Revenue (BIR)  Philippines
# ..                                                 ...          ...
# 283                                  Ministry of Lands       Zambia
# 284                      Environmental Protection Fund       Zambia
# 285                                           ZCCM- IH       Zambia
# 286                                                IDC       Zambia
# 287                                                MoF       Zambia
#
#                                    Full name of agency _merge
# 0             National Environmental Protection Agency   both
# 1             Ministry of Finance (Customs Department)   both
# 2    Ministry of Mines and Petroleum (Revenue Depar...   both
# 3             Ministry of Finance (Revenue Department)   both
# 4                     Bureau of Internal Revenue (BIR)   both
# ..                                                 ...    ...
# 283                                  Ministry of Lands   both
# 284                      Environmental Protection Fund   both
# 285                                           ZCCM- IH   both
# 286                                                IDC   both
# 287                                                MoF   both
#
# [288 rows x 4 columns]

# %%
print("Entities that are in the Government revenues list but not in the Government entities list")
govt_entities_not_in_report = govt_entities_merged_left[govt_entities_merged_left['_merge'] == 'left_only'].drop(columns=['_merge'])
govt_entities_not_in_report
# Out:
# Entities that are in the Government revenues list but not in the Government entities list
#                                      Government entity  \
# 21                                                 NaN
# 25                                                 NaN
# 59                 Direction Générale des impôts (DGI)
# 65                                              Autres
# 73                 Direction des Recettes Provinciales
# 83                 Ministerio de Energía y Minas (MEM)
# 237                              Tax Revenue Authority
# 259  Les delegations speciales des communes et pref...
#
#                           Country Full name of agency
# 21                        Albania                 NaN
# 25                      Argentina                 NaN
# 59                  Cote d'Ivoire                 NaN
# 65                  Cote d'Ivoire                 NaN
# 73   Democratic Republic of Congo                 NaN
# 83             Dominican Republic                 NaN
# 237                    Seychelles                 NaN
# 259                          Togo                 NaN

# %%
govt_entities_merged_right = pd.merge(govt_entities_in_revenues, govt_entities_in_report, left_on=['Government entity', 'Country'], right_on=['Full name of agency', 'Country'], how='right', indicator=True)
govt_entities_merged_right
# Out:
#                                      Government entity      Country  \
# 0             Ministry of Finance (Revenue Department)  Afghanistan
# 1             Ministry of Finance (Customs Department)  Afghanistan
# 2    Ministry of Mines and Petroleum (Revenue Depar...  Afghanistan
# 3             National Environmental Protection Agency  Afghanistan
# 4                                                  NaN  Afghanistan
# ..                                                 ...          ...
# 334                      Environmental Protection Fund       Zambia
# 335                                  Ministry of Lands       Zambia
# 336                                           ZCCM- IH       Zambia
# 337                                                IDC       Zambia
# 338                                                MoF       Zambia
#
#                                    Full name of agency      _merge
# 0             Ministry of Finance (Revenue Department)        both
# 1             Ministry of Finance (Customs Department)        both
# 2    Ministry of Mines and Petroleum (Revenue Depar...        both
# 3             National Environmental Protection Agency        both
# 4                    Ministry of Industry and Commerce  right_only
# ..                                                 ...         ...
# 334                      Environmental Protection Fund        both
# 335                                  Ministry of Lands        both
# 336                                           ZCCM- IH        both
# 337                                                IDC        both
# 338                                                MoF        both
#
# [339 rows x 4 columns]

# %%
print("Entities that are in the Government entities list but not in the Government revenues list")
govt_entities_not_in_revenues = govt_entities_merged_right[govt_entities_merged_right['_merge'] == 'right_only'].drop(columns=['_merge']).reset_index(drop=True)
govt_entities_not_in_revenues
# Out:
# Entities that are in the Government entities list but not in the Government revenues list
#    Government entity                       Country  \
# 0                NaN                   Afghanistan
# 1                NaN                   Philippines
# 2                NaN                   Philippines
# 3                NaN                   Philippines
# 4                NaN                       Albania
# 5                NaN                       Albania
# 6                NaN                     Argentina
# 7                NaN                  Burkina Faso
# 8                NaN                  Burkina Faso
# 9                NaN                          Chad
# 10               NaN                          Chad
# 11               NaN                          Chad
# 12               NaN                          Chad
# 13               NaN                 Cote d'Ivoire
# 14               NaN                 Cote d'Ivoire
# 15               NaN                 Cote d'Ivoire
# 16               NaN  Democratic Republic of Congo
# 17               NaN  Democratic Republic of Congo
# 18               NaN  Democratic Republic of Congo
# 19               NaN  Democratic Republic of Congo
# 20               NaN            Dominican Republic
# 21               NaN                      Ethiopia
# 22               NaN                         Ghana
# 23               NaN                         Ghana
# 24               NaN                         Ghana
# 25               NaN                         Ghana
# 26               NaN                         Ghana
# 27               NaN                         Ghana
# 28               NaN                         Ghana
# 29               NaN                         Ghana
# 30               NaN                         Ghana
# 31               NaN                         Ghana
# 32               NaN                         Ghana
# 33               NaN                         Ghana
# 34               NaN                         Ghana
# 35               NaN                     Guatemala
# 36               NaN                        Guyana
# 37               NaN                        Guyana
# 38               NaN                          Iraq
# 39               NaN                          Iraq
# 40               NaN                          Iraq
# 41               NaN                       Liberia
# 42               NaN                          Mali
# 43               NaN                    Mauritania
# 44               NaN                    Mauritania
# 45               NaN                    Mauritania
# 46               NaN                    Mauritania
# 47               NaN                       Nigeria
# 48               NaN         Republic of the Congo
# 49               NaN         Republic of the Congo
# 50               NaN                       Senegal
# 51               NaN                       Senegal
# 52               NaN                       Senegal
# 53               NaN                    Seychelles
# 54               NaN                    Seychelles
# 55               NaN                    Seychelles
# 56               NaN                          Togo
# 57               NaN                          Togo
# 58               NaN                          Togo
#
#                                   Full name of agency
# 0                   Ministry of Industry and Commerce
# 1           Department of Budget and Management (DBM)
# 2              Philippine Natioanl Oil Company (PNOC)
# 3   Philippine Minding Development Corporation (PDMC)
# 4   Electric energy distribution system operator (...
# 5   Electric Energy Distribution System Operator (...
# 6   Secretaría de Minería (SEMIN), Ministerio de D...
# 7            Autres bénéficiaires (Paiements sociaux)
# 8                                     Agence de l'eau
# 9   Direction Générale des Services de Douanes et ...
# 10                             Ministère des Finances
# 11                                    Commune de Doba
# 12                                Commune de Koudalwa
# 13  Direction des Participations et de la Privatis...
# 14                                             Others
# 15  Société pour le Développement Minier de la Côt...
# 16                     Banque Centrale du Congo (BCC)
# 17  Centre d’Évaluation, d’Expertise et de Certifi...
# 18        Ministère provincial des Mines du Nord-Kivu
# 19                 Direction des RecettesProvinciales
# 20                                 Tesorería Nacional
# 21                          Ministry of Finance (MoF)
# 22            Ministry of Lands and Natural Resources
# 23                                 Ministry of Energy
# 24                   Tarkwa Nsuaem Municipal Assembly
# 25              Prestea Huni Valley District Assembly
# 26                  Bibiani/Ahwiaso District Assembly
# 27                      Sefwi Wiaso District Assembly
# 28                    Asutifi North District Assembly
# 29             Birim North District Assembly Assembly
# 30               Wassa Amenfi East Municipal Assembly
# 31             Upper Denkyira West  District Assembly
# 32                    Amansie South District Assembly
# 33                     Amansie West District Assembly
# 34                  Amansie Central District Assembly
# 35       Vicepresidencia de la República de Guatemala
# 36  National Industrial and Commercial Investments...
# 37                          National Insurance Scheme
# 38                            Oil Exploration Company
# 39                        State Oil Marketing Company
# 40                 State Oil Marketing Company (SOMO)
# 41            National Oil Company of Liberia (NOCAL)
# 42     Institut National de Prévoyance Sociale (INPS)
# 43               Direction Générale des Douanes (DGD)
# 44                 Direction Générale des Mines (DGM)
# 45                Banque Centrale de Mauritanie (BCM)
# 46   Société Nationale Industrielle et Minière (SNIM)
# 47  Nigeria - Sao Tome & Principe Joint Developmen...
# 48          Direction des Ressources Naturelles (DRN)
# 49                 Direction Générale des Mines (DGM)
# 50                   Caisse de Sécurité Sociale (CSS)
# 51  Institution de prévoyance retraite du Sénégal ...
# 52  Institution de Prévoyance Retraite du Sénégal ...
# 53  THE ASSOCIATION FOR THE EXTRACTIVE INDUSTRIES ...
# 54  Ministry of Finance, Trade and the Blue Econom...
# 55                Seychelles Revenue Commission (SRC)
# 56  Les delegations speciales des communes et pref...
# 57                           Togolaise des Eaux (TdE)
# 58     Communes et préfectures des localités minières

# %%
df_part_3b[df_part_3b['Full name of agency']=='Department of Budget and Management (DBM)']
# Out:
#                           Full name of agency        Agency type  \
# 13  Department of Budget and Management (DBM)  Central goverment
#
#    ID number (if applicable) Total reported      Country ISO Code    Year  \
# 13           000-449-457-000            NaN  Philippines      PHL  2018.0
#
#     Start Date    End Date
# 13  2018-01-01  2018-12-31

# %%
df_part_4[df_part_4['Government entity']=='Department of Budget and Management (DBM)']
# Out:
# Empty DataFrame
# Columns: [GFS Classification, Sector, Revenue stream name, Government entity, Revenue value, Currency, Country, ISO Code, Year, Start Date, End Date]
# Index: []

# %%
print("Number of Government entities not in the Government revenues list per country")
govt_entities_not_in_revenues.groupby('Country')['Full name of agency'].count().reset_index(name='Number of entities')
# Out:
# Number of Government entities not in the Government revenues list per country
#                          Country  Number of entities
# 0                    Afghanistan                   1
# 1                        Albania                   2
# 2                      Argentina                   1
# 3                   Burkina Faso                   2
# 4                           Chad                   4
# 5                  Cote d'Ivoire                   3
# 6   Democratic Republic of Congo                   4
# 7             Dominican Republic                   1
# 8                       Ethiopia                   1
# 9                          Ghana                  13
# 10                     Guatemala                   1
# 11                        Guyana                   2
# 12                          Iraq                   3
# 13                       Liberia                   1
# 14                          Mali                   1
# 15                    Mauritania                   4
# 16                       Nigeria                   1
# 17                   Philippines                   3
# 18         Republic of the Congo                   2
# 19                       Senegal                   3
# 20                    Seychelles                   3
# 21                          Togo                   3

# %% [markdown]
# ## Use-cases to validate

# %% [markdown]
# ### How has the extractives industry evolved over time in country X? How much is the volume extracted over time? How much revenue is generated?

# %% [markdown]
# ### IMPORTANT: Some countries (e.g. Norway) report blank revenue values as -. This makes the field not read as a number and makes working with the data difficult.

# %%
# Revenue per country based on Company data
df_part_5_revenues = pd.read_csv(path.join(file_dir, "Part 5 - Company data.csv"))

df_part_5_revenues['Revenue value'] = pd.to_numeric(df_part_5_revenues['Revenue value'], errors='raise')

# df_part_5_revenues['Revenue value'] = df_part_5_revenues['Revenue value'].str.replace(',', '').astype(float)

# df_part_5_revenues['Revenue value'] = pd.to_numeric(df_part_5_revenues['Revenue value'], errors='raise')

# df_part_5_revenues.groupby(['Country', 'Year'])['Revenue value'].sum().reset_index()

# Check if revenue values are all numbers
# pd.to_numeric(df_part_5_revenues['Revenue value'], errors='coerce').notna()
# df_part_5_revenues['Revenue value'].convert_dtypes()

df_part_5_revenues['Revenue value'].dtype

# df_part_5_revenues['Revenue value'] = pd.to_numeric(df_part_5_revenues['Revenue value'], errors='raise')
# Out:
# dtype('float64')

# %%
df_part_5_revenues
# Out:
#                                                  Company  \
# 0                            North Coal Enterprise (NCE)
# 1                            North Coal Enterprise (NCE)
# 2                            North Coal Enterprise (NCE)
# 3                            North Coal Enterprise (NCE)
# 4      Habib Shahab Talc and Marble exploitation and ...
# ...                                                  ...
# 33039                          MAAMBA COLLIERIES LIMITED
# 33040                          MAAMBA COLLIERIES LIMITED
# 33041                          MAAMBA COLLIERIES LIMITED
# 33042                          MAAMBA COLLIERIES LIMITED
# 33043                          MAAMBA COLLIERIES LIMITED
#
#                                        Government entity  \
# 0      Ministry of Mines and Petroleum (Revenue Depar...
# 1      Ministry of Mines and Petroleum (Revenue Depar...
# 2      Ministry of Mines and Petroleum (Revenue Depar...
# 3      Ministry of Mines and Petroleum (Revenue Depar...
# 4      Ministry of Mines and Petroleum (Revenue Depar...
# ...                                                  ...
# 33039                    Zambian Revenue Authority (ZRA)
# 33040                                     Local Councils
# 33041                                     Local Councils
# 33042                                  Ministry of Lands
# 33043                                  Ministry of Lands
#
#                             Revenue stream name Levied on project (Y/N)  \
# 0                                     Royalties                     Yes
# 1                                     Royalties                     Yes
# 2                                     Royalties                     Yes
# 3                                     Royalties                     Yes
# 4                     Penalties of Late Payment                     NaN
# ...                                         ...                     ...
# 33039          Excise Duty - Electrical  Energy                      No
# 33040                      Annual Business Fees                      No
# 33041                            Property Rates                      No
# 33042                               Ground Rent                      No
# 33043  Others-Invitation to Treat / Title Deeds                      No
#
#       Reported by project (Y/N) Project name Reporting currency  \
# 0                           Yes   EXP 1/2014                AFN
# 1                           Yes   EXP 1/2014                AFN
# 2                           Yes   EXP 1/2014                AFN
# 3                           Yes   EXP 1/2014                AFN
# 4                           NaN          NaN                AFN
# ...                         ...          ...                ...
# 33039                        No          NaN                ZMW
# 33040                        No          NaN                ZMW
# 33041                        No          NaN                ZMW
# 33042                        No          NaN                ZMW
# 33043                        No          NaN                ZMW
#
#        Revenue value Payment made in-kind (Y/N)  \
# 0        442801100.0                         No
# 1        386169944.0                         No
# 2        336623658.0                         No
# 3        300000000.0                         No
# 4               18.0                        NaN
# ...              ...                        ...
# 33039     66946749.0                         No
# 33040       311691.0                         No
# 33041      1200199.0                         No
# 33042        86562.0                         No
# 33043      1069732.0                         No
#
#       In-kind volume (if applicable) Unit (if applicable) Comments  \
# 0                     Not applicable       Not applicable      NaN
# 1                     Not applicable       Not applicable      NaN
# 2                     Not applicable       Not applicable      NaN
# 3                     Not applicable       Not applicable      NaN
# 4                                NaN                  NaN      NaN
# ...                              ...                  ...      ...
# 33039                            NaN                  NaN      NaN
# 33040                            NaN                  NaN      NaN
# 33041                            NaN                  NaN      NaN
# 33042                            NaN                  NaN      NaN
# 33043                            NaN                  NaN      NaN
#
#            Country ISO Code    Year  Start Date    End Date
# 0      Afghanistan      AFG  2018.0  2017-12-21  2018-12-20
# 1      Afghanistan      AFG  2018.0  2017-12-21  2018-12-20
# 2      Afghanistan      AFG  2018.0  2017-12-21  2018-12-20
# 3      Afghanistan      AFG  2018.0  2017-12-21  2018-12-20
# 4      Afghanistan      AFG  2018.0  2017-12-21  2018-12-20
# ...            ...      ...     ...         ...         ...
# 33039       Zambia      ZMB  2018.0  2018-01-01  2018-12-31
# 33040       Zambia      ZMB  2018.0  2018-01-01  2018-12-31
# 33041       Zambia      ZMB  2018.0  2018-01-01  2018-12-31
# 33042       Zambia      ZMB  2018.0  2018-01-01  2018-12-31
# 33043       Zambia      ZMB  2018.0  2018-01-01  2018-12-31
#
# [33044 rows x 17 columns]

# %%
total_revenue_per_country_per_year = df_part_5_revenues.groupby(['Country', 'Year', 'Reporting currency'])['Revenue value'].sum().reset_index()

#Set the year column to be a string
total_revenue_per_country_per_year['Year'] = total_revenue_per_country_per_year['Year'].astype(str).str.replace(r'\.0$', '', regex=True)

total_revenue_per_country_per_year
# Out:
#            Country  Year Reporting currency  Revenue value
# 0      Afghanistan  2018                AFN   4.804506e+09
# 1      Afghanistan  2019                AFN   4.265284e+09
# 2          Albania  2017                ALL   1.614886e+10
# 3          Albania  2017                USD   2.189620e+05
# 4          Albania  2018                ALL   1.822660e+10
# ..             ...   ...                ...            ...
# 70  United Kingdom  2019                GBP   1.503146e+09
# 71  United Kingdom  2020                GBP   2.550391e+08
# 72  United Kingdom  2021                GBP   9.898815e+08
# 73          Zambia  2017                ZMW   8.600124e+09
# 74          Zambia  2018                ZMW   1.118396e+10
#
# [75 rows x 4 columns]

# %%
total_revenue_per_country_per_year_pt = total_revenue_per_country_per_year.pivot_table(index=['Country', 'Reporting currency'], columns='Year', values='Revenue value', aggfunc='sum', fill_value=0).style.format('{:,.2f}')
total_revenue_per_country_per_year_pt
# Out:
# <style type="text/css">
# </style>
# <table id="T_cf9e2">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Year</th>
#       <th id="T_cf9e2_level0_col0" class="col_heading level0 col0" >2017</th>
#       <th id="T_cf9e2_level0_col1" class="col_heading level0 col1" >2018</th>
#       <th id="T_cf9e2_level0_col2" class="col_heading level0 col2" >2019</th>
#       <th id="T_cf9e2_level0_col3" class="col_heading level0 col3" >2020</th>
#       <th id="T_cf9e2_level0_col4" class="col_heading level0 col4" >2021</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="index_name level1" >Reporting currency</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf9e2_level0_row0" class="row_heading level0 row0" >Afghanistan</th>
#       <th id="T_cf9e2_level1_row0" class="row_heading level1 row0" >AFN</th>
#       <td id="T_cf9e2_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_cf9e2_row0_col1" class="data row0 col1" >4,804,506,352.00</td>
#       <td id="T_cf9e2_row0_col2" class="data row0 col2" >4,265,283,832.00</td>
#       <td id="T_cf9e2_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_cf9e2_row0_col4" class="data row0 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row1" class="row_heading level0 row1" rowspan="2">Albania</th>
#       <th id="T_cf9e2_level1_row1" class="row_heading level1 row1" >ALL</th>
#       <td id="T_cf9e2_row1_col0" class="data row1 col0" >16,148,860,065.00</td>
#       <td id="T_cf9e2_row1_col1" class="data row1 col1" >18,226,600,760.00</td>
#       <td id="T_cf9e2_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_cf9e2_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_cf9e2_row1_col4" class="data row1 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level1_row2" class="row_heading level1 row2" >USD</th>
#       <td id="T_cf9e2_row2_col0" class="data row2 col0" >218,962.00</td>
#       <td id="T_cf9e2_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_cf9e2_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_cf9e2_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_cf9e2_row2_col4" class="data row2 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row3" class="row_heading level0 row3" >Argentina</th>
#       <th id="T_cf9e2_level1_row3" class="row_heading level1 row3" >ARS</th>
#       <td id="T_cf9e2_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_cf9e2_row3_col1" class="data row3 col1" >52,123,232,635.87</td>
#       <td id="T_cf9e2_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_cf9e2_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_cf9e2_row3_col4" class="data row3 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row4" class="row_heading level0 row4" >Armenia</th>
#       <th id="T_cf9e2_level1_row4" class="row_heading level1 row4" >AMD</th>
#       <td id="T_cf9e2_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_cf9e2_row4_col1" class="data row4 col1" >79,528,828,359.34</td>
#       <td id="T_cf9e2_row4_col2" class="data row4 col2" >85,427,456,909.00</td>
#       <td id="T_cf9e2_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_cf9e2_row4_col4" class="data row4 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row5" class="row_heading level0 row5" >Burkina Faso</th>
#       <th id="T_cf9e2_level1_row5" class="row_heading level1 row5" >XOF</th>
#       <td id="T_cf9e2_row5_col0" class="data row5 col0" >143,446,403,692.00</td>
#       <td id="T_cf9e2_row5_col1" class="data row5 col1" >108,352,706,471.00</td>
#       <td id="T_cf9e2_row5_col2" class="data row5 col2" >100,310,250,892.00</td>
#       <td id="T_cf9e2_row5_col3" class="data row5 col3" >178,994,800,000.00</td>
#       <td id="T_cf9e2_row5_col4" class="data row5 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row6" class="row_heading level0 row6" >Cameroon</th>
#       <th id="T_cf9e2_level1_row6" class="row_heading level1 row6" >XAF</th>
#       <td id="T_cf9e2_row6_col0" class="data row6 col0" >428,111,382,954.00</td>
#       <td id="T_cf9e2_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_cf9e2_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_cf9e2_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_cf9e2_row6_col4" class="data row6 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row7" class="row_heading level0 row7" >Chad</th>
#       <th id="T_cf9e2_level1_row7" class="row_heading level1 row7" >USD</th>
#       <td id="T_cf9e2_row7_col0" class="data row7 col0" >547,448,408.00</td>
#       <td id="T_cf9e2_row7_col1" class="data row7 col1" >1,003,136,734.00</td>
#       <td id="T_cf9e2_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_cf9e2_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_cf9e2_row7_col4" class="data row7 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row8" class="row_heading level0 row8" >Cote d'Ivoire</th>
#       <th id="T_cf9e2_level1_row8" class="row_heading level1 row8" >XOF</th>
#       <td id="T_cf9e2_row8_col0" class="data row8 col0" >279,785,538,194.00</td>
#       <td id="T_cf9e2_row8_col1" class="data row8 col1" >193,151,957,509.00</td>
#       <td id="T_cf9e2_row8_col2" class="data row8 col2" >0.00</td>
#       <td id="T_cf9e2_row8_col3" class="data row8 col3" >0.00</td>
#       <td id="T_cf9e2_row8_col4" class="data row8 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row9" class="row_heading level0 row9" >Democratic Republic of Congo</th>
#       <th id="T_cf9e2_level1_row9" class="row_heading level1 row9" >USD</th>
#       <td id="T_cf9e2_row9_col0" class="data row9 col0" >1,665,052,954.00</td>
#       <td id="T_cf9e2_row9_col1" class="data row9 col1" >0.00</td>
#       <td id="T_cf9e2_row9_col2" class="data row9 col2" >0.00</td>
#       <td id="T_cf9e2_row9_col3" class="data row9 col3" >0.00</td>
#       <td id="T_cf9e2_row9_col4" class="data row9 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row10" class="row_heading level0 row10" >Dominican Republic</th>
#       <th id="T_cf9e2_level1_row10" class="row_heading level1 row10" >DOP</th>
#       <td id="T_cf9e2_row10_col0" class="data row10 col0" >0.00</td>
#       <td id="T_cf9e2_row10_col1" class="data row10 col1" >10,597,199,438.00</td>
#       <td id="T_cf9e2_row10_col2" class="data row10 col2" >11,465,485,432.00</td>
#       <td id="T_cf9e2_row10_col3" class="data row10 col3" >23,757,997,600.00</td>
#       <td id="T_cf9e2_row10_col4" class="data row10 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row11" class="row_heading level0 row11" >Ethiopia</th>
#       <th id="T_cf9e2_level1_row11" class="row_heading level1 row11" >ETB</th>
#       <td id="T_cf9e2_row11_col0" class="data row11 col0" >1,777,453,984.00</td>
#       <td id="T_cf9e2_row11_col1" class="data row11 col1" >0.00</td>
#       <td id="T_cf9e2_row11_col2" class="data row11 col2" >0.00</td>
#       <td id="T_cf9e2_row11_col3" class="data row11 col3" >0.00</td>
#       <td id="T_cf9e2_row11_col4" class="data row11 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row12" class="row_heading level0 row12" >Germany</th>
#       <th id="T_cf9e2_level1_row12" class="row_heading level1 row12" >EUR</th>
#       <td id="T_cf9e2_row12_col0" class="data row12 col0" >476,662,365.00</td>
#       <td id="T_cf9e2_row12_col1" class="data row12 col1" >644,027,705.00</td>
#       <td id="T_cf9e2_row12_col2" class="data row12 col2" >499,546,672.00</td>
#       <td id="T_cf9e2_row12_col3" class="data row12 col3" >196,636,734.00</td>
#       <td id="T_cf9e2_row12_col4" class="data row12 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e2_level0_row13" class="row_heading level0 row13" rowspan="2

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### How many years of data does each country have?

# %%
df_part_5.groupby('Country')['Year'].nunique().reset_index(name='Years of data')
# Out:
#                          Country  Years of data
# 0                    Afghanistan              2
# 1                        Albania              2
# 2                      Argentina              1
# 3                        Armenia              2
# 4                   Burkina Faso              4
# 5                       Cameroon              1
# 6                           Chad              2
# 7                  Cote d'Ivoire              2
# 8   Democratic Republic of Congo              1
# 9             Dominican Republic              3
# 10                      Ethiopia              1
# 11                       Germany              4
# 12                         Ghana              3
# 13                        Guyana              1
# 14                          Iraq              2
# 15                       Liberia              2
# 16                    Madagascar              2
# 17                          Mali              2
# 18                    Mauritania              1
# 19                        Mexico              2
# 20                      Mongolia              3
# 21                    Mozambique              1
# 22                       Myanmar              1
# 23                       Nigeria              2
# 24                        Norway              3
# 25                   Philippines              1
# 26         Republic of the Congo              1
# 27                       Senegal              2
# 28                      Suriname              1
# 29                      Tanzania              1
# 30                          Togo              2
# 31           Trinidad and Tobago              2
# 32                       Ukraine              4
# 33                United Kingdom              4
# 34                        Zambia              2

# %%
df_part_5.groupby('Country')['Year'].nunique().reset_index(name='Years of data').sort_values(by=['Years of data'], ascending=False)
# Out:
#                          Country  Years of data
# 33                United Kingdom              4
# 32                       Ukraine              4
# 4                   Burkina Faso              4
# 11                       Germany              4
# 24                        Norway              3
# 9             Dominican Republic              3
# 12                         Ghana              3
# 20                      Mongolia              3
# 0                    Afghanistan              2
# 16                    Madagascar              2
# 31           Trinidad and Tobago              2
# 30                          Togo              2
# 27                       Senegal              2
# 23                       Nigeria              2
# 19                        Mexico              2
# 1                        Albania              2
# 17                          Mali              2
# 15                       Liberia              2
# 7                  Cote d'Ivoire              2
# 3                        Armenia              2
# 6                           Chad              2
# 34                        Zambia              2
# 14                          Iraq              2
# 22                       Myanmar              1
# 10                      Ethiopia              1
# 8   Democratic Republic of Congo              1
# 25                   Philippines              1
# 18                    Mauritania              1
# 21                    Mozambique              1
# 28                      Suriname              1
# 29                      Tanzania              1
# 13                        Guyana              1
# 5                       Cameroon              1
# 2                      Argentina              1
# 26         Republic of the Congo              1

# %%
df_part_5_a = df_part_5.copy()

df_part_5_a['data_exists'] = 'x'

# List of years from 2017 to 2022
years = list(range(2017, 2023))

# Create a table with 0s and 1s indicating the presence of a report for each country and year
data_exists = df_part_5_a.pivot_table(index='Country', columns='Year', values='data_exists', aggfunc='max', fill_value='')
data_exists = data_exists.reindex(columns=years, fill_value='')

data_exists
# Out:
# Year                         2017 2018 2019 2020 2021 2022
# Country
# Afghanistan                          x    x
# Albania                         x    x
# Argentina                            x
# Armenia                              x    x
# Burkina Faso                    x    x    x    x
# Cameroon                        x
# Chad                            x    x
# Cote d'Ivoire                   x    x
# Democratic Republic of Congo    x
# Dominican Republic                   x    x    x
# Ethiopia                        x
# Germany                         x    x    x    x
# Ghana                           x    x    x
# Guyana                               x
# Iraq                            x    x
# Liberia                              x    x
# Madagascar                      x    x
# Mali                            x    x
# Mauritania                      x
# Mexico                          x    x
# Mongolia                             x    x    x
# Mozambique                                x
# Myanmar                              x
# Nigeria                         x    x
# Norway                          x    x    x
# Philippines                          x
# Republic of the Congo           x
# Senegal                              x    x
# Suriname                        x
# Tanzania                             x
# Togo                            x    x
# Trinidad and Tobago             x    x
# Ukraine                         x    x    x    x
# United Kingdom                       x    x    x    x
# Zambia                          x    x
